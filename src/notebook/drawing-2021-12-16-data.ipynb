# %%
import matplotlib.pyplot as plt
import networkx as nx
import hypernetx as hnx
import numpy as np
import pandas as pd
import os
import argparse

# %% [markdown]
# ## hypergraph vis

# %%
parser = argparse.ArgumentParser()
args = parser.parse_args(args=[])
args.src = '../data/csv/AMERICAN ECONOMIC REVIEW.csv'
args.year = ['2017']
args.size = 10
args.seed = 0

df = pd.read_csv(args.src, index_col=None)

if args.year:
    df = df.loc[df['DBYear'].isin(args.year), :]

# convert name to id
colName = ['Fullname', 'Country', 'FullOrgName']
clusterCenter = [(args.size*30, -args.size*30), (0, args.size*50), (-args.size*30, -args.size*30)]
dirc = [(args.size*5, args.size*5), (0, -args.size*5), (-args.size*5, args.size*5)]
nickName = ['Researcher', 'Country', 'Organization']

# add edges
df_sub = df.sample(n=args.size, random_state=args.seed)
hyperedges = dict(zip(df_sub.index, list(zip(*[df_sub[col] for col in colName]))))
#for col in colName:
#    hyperedges[col] = list(df_sub[col].unique())

pos = {}
for col, center, d in zip(colName, clusterCenter, dirc):
    for i, name in enumerate(df_sub[col].unique()):
        # USA is so fat that it will affect other edges
        # thus we isolate its position to bottom right
        if name == 'USA':
            pos[name] = (0, -args.size*100)
        else:
            pos[name] = (center[0]+d[0]*i, center[1]+d[1]*i)

H = hnx.Hypergraph(hyperedges)
plt.figure(figsize=(10, 10))
hnx.draw(H, pos=pos, with_edge_labels=False, edge_labels=df_sub['ArticleNumber'])
plt.show()

# %% [markdown]
# ## run all journal & years

# %%
f_path = [f'{x}.csv' for x in range(2015, 2020)]
nickname = [str(x) for x in range(2015, 2020)]
#['AMERICAN ECONOMIC REVIEW', 'JOURNAL OF POLITICAL ECONOMY', 'Econometrica', 'REVIEW OF ECONOMIC STUDIES']
# !pwd
# Out:
# /Users/robert1003/git/2020_NARLabs_proposal/src

# %%
import os

for f, n in zip(f_path, nickname):
    df = pd.read_csv(f'../data/2021-12-16/csv/{f}')
    journal_list = list(df['journaltitle'].unique())
    for j in journal_list:
        df_tmp = df[df['journaltitle'] == j]
        df_tmp.to_csv('./tmp.csv')
        s = f"python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/{n} {j}.csv'"
        print(s)
        os.system(s)
# Out:
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 ECONOMETRIC REVIEWS.csv'
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 JOURNAL OF POPULATION ECONOMICS.csv'
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 APPLIED ECONOMICS.csv'
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 APPLIED ECONOMICS LETTERS.csv'
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 POST-SOVIET AFFAIRS.csv'
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 CONTEMPORARY ECONOMIC POLICY.csv'
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 ECONOMIC INQUIRY.csv'
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 WORLD DEVELOPMENT.csv'
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 DEFENCE AND PEACE ECONOMICS.csv'
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out 'out/2015 HEALTH ECONOMICS.csv'
# ...

# %%
for f, n in zip(f_path, nickname):
    s = f"python3 csv_calc_eigenvalue.py --src '../data/2021-12-16/csv/{f}' --out 'out/{f.strip('.csv')}_all.csv'"
    print(s)
    os.system(s)
# Out:
# python3 csv_calc_eigenvalue.py --src '../data/2021-12-16/csv/2015.csv' --out 'out/2015_all.csv'
# python3 csv_calc_eigenvalue.py --src '../data/2021-12-16/csv/2016.csv' --out 'out/2016_all.csv'
# python3 csv_calc_eigenvalue.py --src '../data/2021-12-16/csv/2017.csv' --out 'out/2017_all.csv'
# python3 csv_calc_eigenvalue.py --src '../data/2021-12-16/csv/2018.csv' --out 'out/2018_all.csv'
# python3 csv_calc_eigenvalue.py --src '../data/2021-12-16/csv/2019.csv' --out 'out/2019_all.csv'

# %% [markdown]
# # 2021-12-17
# ## consider top k journal only

# %%
journal_ranking = pd.read_csv('../data/ranking.csv', sep=';')
journal_ranking = journal_ranking[['Title', 'Country', 'Region', 'Categories']]
journal_ranking['Title'] = journal_ranking['Title'].apply(lambda x: x.upper())
journal_ranking.head()
# Out:
#                             Title         Country            Region  \
# 0  QUARTERLY JOURNAL OF ECONOMICS  United Kingdom    Western Europe
# 1    JOURNAL OF POLITICAL ECONOMY   United States  Northern America
# 2              JOURNAL OF FINANCE  United Kingdom    Western Europe
# 3        AMERICAN ECONOMIC REVIEW   United States  Northern America
# 4                    ECONOMETRICA  United Kingdom    Western Europe
#
#                                           Categories
# 0                    Economics and Econometrics (Q1)
# 1                    Economics and Econometrics (Q1)
# 2  Accounting (Q1); Economics and Econometrics (Q...
# 3                    Economics and Econometrics (Q1)
# 4                    Economics and Econometrics (Q1)

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 5))
for i in range(2015, 2020):
    f = f'{i}.csv'
    topk = 50
    df = pd.read_csv(f'../data/2021-12-16/csv/{f}', index_col=0)
    js = list(journal_ranking.iloc[:topk, :]['Title'])
    df[df['journaltitle'].isin(js)].to_csv('./tmp.csv')
    os.system('rm result.csv')
    s = f"python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out result.csv"
    print(s)
    os.system(s)
    
    res = pd.read_csv('./result.csv')
    tw = res[res['country'] == 'Taiwan']
    china = res[res['country'] == 'Peoples R China']

    print(i)
    print(tw.describe())
    print(china.describe())

    
    axs[i-2015].hist(np.log10(china['centrality']), bins=20, density=True, label=f'China ({china["centrality"].mean():.2})')
    axs[i-2015].hist(np.log10(tw['centrality']), bins=20, density=True, label=f'Taiwan ({tw["centrality"].mean():.2})')
    axs[i-2015].set_title(f'{i}')
    axs[i-2015].legend()

plt.suptitle('density histogram of log10(centrality)')    
plt.show()
# Out:
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out result.csv
# 2015
#          centrality
# count  1.700000e+01
# mean   9.424342e-10
# std    4.121656e-10
# min    6.859327e-10
# 25%    6.859327e-10
# 50%    6.869870e-10
# 75%    1.372919e-09
# max    2.061224e-09
#          centrality
# count  1.560000e+02
# mean   3.947127e-05
# std    2.194309e-04
# min    6.498272e-09
# 25%    6.533372e-09
# 50%    6.826865e-09
# 75%    7.492210e-09
# max    1.541384e-03
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out result.csv
# 2016
#          centrality
# count  1.000000e+01
# mean   1.275481e-18
# std    1.065439e-18
# min    1.889519e-19
# 25%    4.714599e-19
# 50%    9.601515e-19
# 75%    2.043683e-18
# max    3.014964e-18
#          centrality
# count  1.270000e+02
# mean   4.361241e-05
# std    1.632347e-04
# min    2.289249e-09
# 25%    2.294038e-09
# 50%    2.305348e-09
# 75%    4.581687e-09
# max    1.038451e-03
# ...

# %%
i=2018
f = f'{i}.csv'
topk = 50
df = pd.read_csv(f'../data/2021-12-16/csv/{f}', index_col=0)
js = list(journal_ranking.iloc[:topk, :]['Title'])
df[df['journaltitle'].isin(js)].to_csv('./tmp.csv')
os.system('rm result.csv')
s = f"python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out result_2018.csv"
print(s)
os.system(s)
# Out:
# python3 csv_calc_eigenvalue.py --src 'tmp.csv' --out result_2018.csv
# 0

# %%
# Out:
#          centrality
# count  2.000000e+00
# mean   5.307019e-18
# std    1.947621e-18
# min    3.929844e-18
# 25%    4.618431e-18
# 50%    5.307019e-18
# 75%    5.995607e-18
# max    6.684195e-18
#          centrality
# count  3.800000e+01
# mean   7.027854e-05
# std    2.590404e-04
# min    4.953631e-09
# 25%    4.960267e-09
# 50%    5.269490e-09
# 75%    5.866151e-09
# max    1.332413e-03

# %%
fig, axs = plt.subplots(1, 5, figsize=(20, 5))
for i in range(2015, 2020):
    df = pd.read_csv(f'out/{i}_all.csv')
    tw = df[df['country'] == 'Taiwan']
    china = df[df['country'] == 'Peoples R China']
    
    axs[i-2015].hist(np.log10(china['centrality']), bins=20, density=True, label=f'China ({china["centrality"].mean():.2})')
    axs[i-2015].hist(np.log10(tw['centrality']), bins=20, density=True, label=f'Taiwan ({tw["centrality"].mean():.2})')
    axs[i-2015].set_title(f'{i}')
    axs[i-2015].legend()
    
plt.suptitle('density histogram of log10(centrality)')
plt.show()

# %%
tw.describe()
# Out:
#          centrality
# count  5.380000e+02
# mean   4.486006e-07
# std    5.978762e-06
# min    7.990161e-11
# 25%    7.993992e-11
# 50%    8.008078e-11
# 75%    1.598351e-10
# max    8.139910e-05

# %%
china.describe()
# Out:
#          centrality
# count  1.870000e+03
# mean   3.344541e-06
# std    2.913304e-05
# min    5.141425e-10
# 25%    5.152735e-10
# 50%    5.204631e-10
# 75%    1.029540e-09
# max    7.230194e-04

# %%
df = pd.read_csv('out/2015.csv_all.csv')
#plt.plot(np.log10(df['centrality']))
plt.figure(figsize=(20, 5))
plt.bar(range(len(df[df['centrality'] > 1e-3])), np.log10(df[df['centrality'] > 1e-3]['centrality']))
print(list(df[df['centrality'] > 1e-3]['name']))
# Out:
# ['USA', 'NBER', 'Harvard Univ', 'World Bank', 'Stanford Univ', 'Univ Calif Berkeley', 'Cornell Univ', 'Univ Chicago', 'Univ Wisconsin', 'Univ Illinois', 'Int Monetary Fund', 'Duke Univ', 'Natl Bur Econ Res', 'MIT', 'Northwestern Univ', 'Univ N Carolina', 'Columbia Univ', 'NYU', 'Univ Michigan', 'Univ Penn', 'Michigan State Univ', 'Univ Calif Davis', 'Univ Minnesota', 'Princeton Univ', 'Yale Univ', 'Univ Maryland', 'Texas A&M Univ', 'Boston Univ', 'Univ So Calif', 'Arizona State Univ', 'Ohio State Univ', 'Univ Calif Los Angeles', 'Indiana Univ', 'Univ Texas Austin', 'Penn State Univ', 'Int Food Policy Res Inst', 'Univ Washington', 'Carnegie Mellon Univ', 'Univ Colorado', 'George Mason Univ', 'Purdue Univ', 'Univ Florida', 'Univ Calif San Diego', 'Georgia State Univ', 'Florida State Univ', 'Univ Connecticut', 'Iowa State Univ', 'Washington Univ', 'Univ Tennessee', 'Georgia Inst Technol', 'Univ Georgia', 'Univ Missouri', 'Rutgers State Univ', 'George Washington Univ', 'Georgetown Univ',
# ...

# %%
df
# Out:
#          centrality                    name        group
# 0      9.966263e-01                     USA      Country
# 1      3.171141e-02                    NBER  FullOrgName
# 2      2.263205e-02            Harvard Univ  FullOrgName
# 3      1.603016e-02              World Bank  FullOrgName
# 4      1.552022e-02           Stanford Univ  FullOrgName
# ...             ...                     ...          ...
# 38919  1.540717e-20     Stankeviciene, Asta     Fullname
# 38920  7.720037e-21        Aniunas, Povilas     Fullname
# 38921  6.290856e-21    Maskeliunas, Saulius     Fullname
# 38922  3.702715e-21        Nausedaite, Reda     Fullname
# 38923  1.394122e-21  Eidenmueller, Thorsten     Fullname
#
# [38924 rows x 3 columns]

# %%
for y in range(2015, 2020):
    path = f'../data/2021-12-16/csv/{y}.csv'
    df = pd.read_csv(path, index_col=0)
    #for j in list(df['journaltitle'].unique()):
    journal_list = list(df['journaltitle'].unique())
    plt.bar(range(len(journal_list)), [df[df['journaltitle'] == j]['PaperTitle'].unique().shape[0] for j in journal_list])
    plt.title(y)
    plt.show()

# %%
plt.bar?

# %% [markdown]
# ## store result into single csv

# %%
df = pd.DataFrame(columns=['centrality', 'name', 'group', 'year', 'journal'])
for f in os.listdir('./out'):
    if '_' in f:
        continue
        
    _df = pd.read_csv('./out/{}'.format(f))
    tot = f.strip('csv').split(' ')
    year = tot[0]
    journal = ' '.join(tot[1:])
    #year = f.strip('.csv').split('_')
    _df['year'] = year
    _df['journal'] = journal
    df = df.merge(_df, how='outer')

df.to_csv('all_centrality_by_year.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3fc71b55d834> in <module>
#      11     _df['year'] = year
#      12     _df['journal'] = journal
# ---> 13     df = df.merge(_df, how='outer')
#      14
#      15 df.to_csv('all_centrality_by_year.csv')
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7948         from pandas.core.reshape.merge import merge
#    7949
# -> 7950         return merge(
#    7951             self,
#    7952             right,
#
# ~/.pyenv/versions/3.8.5/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      87         validate=validate,
#      88     )
# ...

# %%
df
# Out:
#         centrality                   name        group  year  \
# 0     9.773390e-01                    USA      Country  2017
# 1     1.636040e-01                   NBER  FullOrgName  2017
# 2     5.139606e-02                    MIT  FullOrgName  2017
# 3     4.602251e-02           Harvard Univ  FullOrgName  2017
# 4     4.067859e-02          Stanford Univ  FullOrgName  2017
# ...            ...                    ...          ...   ...
# 6866  1.840660e-18                  Japan      Country   all
# 6867  1.523125e-18        Noguchi, Yuichi     Fullname   all
# 6868  1.314932e-18  Preinerstorfer, David     Fullname   all
# 6869  8.368454e-19       Demuynck, Thomas     Fullname   all
# 6870  1.062813e-20              Univ Oslo  FullOrgName   all
#
#                        journal
# 0     AMERICAN ECONOMIC REVIEW
# 1     AMERICAN ECONOMIC REVIEW
# 2     AMERICAN ECONOMIC REVIEW
# 3     AMERICAN ECONOMIC REVIEW
# 4     AMERICAN ECONOMIC REVIEW
# ...                        ...
# ...

# %% [markdown]
# ## plot centrality and ranking graph per journal

# %%
def draw(col, col2, topk, year, nickname):
    # retrieve topk from each year
    sheets = []
    for y in year:
        _df = pd.read_csv('./out/{}_{}.csv'.format(nickname, y))
        _df = _df.loc[_df['group'] == col, :].reset_index()
        sheets.append(_df)

    name_topks = set()
    for sheet in sheets:
        name_topks.update(sheet[:topk]['name'])

    # retrieve rank
    rks = {}
    for name in name_topks:
        if col2 == 'rank':
            rk = [sheet.loc[sheet['name'] == name, :].index for sheet in sheets]
            rks[name] = [r[0]+1 if len(r) > 0 else -1 for r in rk]
        else:
            rk = [sheet.loc[sheet['name'] == name, col2] for sheet in sheets]
            rks[name] = [r.iloc[0] if len(r) > 0 else -1 for r in rk]
                    
        
    # plot
    plt.figure(figsize=(8, 5))
    for name in name_topks:
        # USA's centrality is too high
        if name == 'USA' and col2 == 'centrality':
            continue
        res = []
        x = []
        for i, r in enumerate(rks[name]):
            if r > 0:
                res.append(r)
                x.append(i)
        plt.plot(x, res, '-o', label=name)

    plt.title(nickname+' '+col+' '+col2)
    plt.xticks(range(len(year)), year)
    plt.legend(bbox_to_anchor=(1,1), loc="upper left")
    if col2 == 'rank':
        plt.gca().invert_yaxis()
    plt.show()

# %%
draw('Fullname', 'centrality', 2, range(2015, 2020), 'AMERICAN ECONOMIC REVIEW')
draw('Country', 'centrality', 3, range(2015, 2020), 'AMERICAN ECONOMIC REVIEW')

draw('Fullname', 'centrality', 2, range(2015, 2020), 'JOURNAL OF POLITICAL ECONOMY')
draw('Country', 'centrality', 3, range(2015, 2020), 'JOURNAL OF POLITICAL ECONOMY')

draw('Fullname', 'centrality', 2, range(2015, 2020), 'REVIEW OF ECONOMIC STUDIES')
draw('Country', 'centrality', 3, range(2015, 2020), 'REVIEW OF ECONOMIC STUDIES')

draw('Fullname', 'centrality', 5, ['all'], 'Econometrica')
draw('Country', 'centrality', 5, ['all'], 'Econometrica')

# %%
draw('Fullname', 'rank', 2, range(2015, 2020), 'AMERICAN ECONOMIC REVIEW')
draw('Country', 'rank', 3, range(2015, 2020), 'AMERICAN ECONOMIC REVIEW')

draw('Fullname', 'rank', 2, range(2015, 2020), 'JOURNAL OF POLITICAL ECONOMY')
draw('Country', 'rank', 3, range(2015, 2020), 'JOURNAL OF POLITICAL ECONOMY')

draw('Fullname', 'rank', 2, range(2015, 2020), 'REVIEW OF ECONOMIC STUDIES')
draw('Country', 'rank', 3, range(2015, 2020), 'REVIEW OF ECONOMIC STUDIES')

draw('Fullname', 'rank', 5, ['all'], 'Econometrica')
draw('Country', 'rank', 5, ['all'], 'Econometrica')
