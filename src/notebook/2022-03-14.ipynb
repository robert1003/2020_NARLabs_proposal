# %%
import os
import pandas as pd
import numpy as np
from collections import defaultdict
from tqdm.notebook import tqdm

# %% [markdown]
# ### hyperparam

# %%
year = 2019

# %%
df = pd.read_csv(f'../result_{year}.csv')

# %%
df.head()
# Out:
#    centrality                                         name         group  \
# 0    0.991648                                          USA       Country
# 1    0.050982                                         NBER   FullOrgName
# 2    0.026058                            WORLD DEVELOPMENT  journaltitle
# 3    0.023323                            APPLIED ECONOMICS  journaltitle
# 4    0.023008  JOURNAL OF ECONOMIC BEHAVIOR & ORGANIZATION  journaltitle
#
#   country organization
# 0     NaN          NaN
# 1     USA          NaN
# 2     NaN          NaN
# 3     NaN          NaN
# 4     NaN          NaN

# %% [markdown]
# ### Country ranking

# %%
topk = 10
country = df[df['group'] == 'Country']
country.head(topk)
# Out:
#      centrality             name    group country organization
# 0      0.991648              USA  Country     NaN          NaN
# 128    0.004464  Peoples R China  Country     NaN          NaN
# 254    0.002145          England  Country     NaN          NaN
# 278    0.001827          Germany  Country     NaN          NaN
# 362    0.001212        Australia  Country     NaN          NaN
# 368    0.001142            Italy  Country     NaN          NaN
# 437    0.000875           France  Country     NaN          NaN
# 462    0.000748            Spain  Country     NaN          NaN
# 488    0.000723           Canada  Country     NaN          NaN
# 546    0.000565      Netherlands  Country     NaN          NaN

# %% [markdown]
# ### journal ranking

# %%
# centrality & h-index & impact_factor
topk = 10
journal = df[df['group'] == 'journaltitle'].reset_index()
journal = journal.drop(columns=['country', 'organization', 'index'])

# impact factor
impact_factor = pd.read_csv('../impact_factor/simple.csv')
h_index = pd.read_csv('../impact_factor/hindex.csv')

def ff(_df):
    def f(x):
        try:
            if type(x) is str:
                res = _df[_df['Journal'].apply(lambda y: x.lower() in y.lower())]
                return res.iloc[0][0]
            else:
                return np.nan
        except Exception as e:
            return np.nan
    return f

journal['impact_factor_optimal_rank'] = journal['name'].apply(ff(impact_factor))
journal['h_index_optimal_rank'] = journal['name'].apply(ff(h_index))

journal.head(topk)
# Out:
#    centrality                                         name         group  \
# 0    0.026058                            WORLD DEVELOPMENT  journaltitle
# 1    0.023323                            APPLIED ECONOMICS  journaltitle
# 2    0.023008  JOURNAL OF ECONOMIC BEHAVIOR & ORGANIZATION  journaltitle
# 3    0.021245               JOURNAL OF FINANCIAL ECONOMICS  journaltitle
# 4    0.020849                     AMERICAN ECONOMIC REVIEW  journaltitle
# 5    0.018919                  REVIEW OF FINANCIAL STUDIES  journaltitle
# 6    0.018888                    APPLIED ECONOMICS LETTERS  journaltitle
# 7    0.016649                            ECONOMICS LETTERS  journaltitle
# 8    0.015431                  JOURNAL OF CONSUMER AFFAIRS  journaltitle
# 9    0.014778           ENVIRONMENTAL & RESOURCE ECONOMICS  journaltitle
#
#    impact_factor_optimal_rank  h_index_optimal_rank
# 0                       112.0                  34.0
# 1                        18.0                  49.0
# 2                       117.0                  44.0
# 3                         5.0                   6.0
# 4                         8.0                   1.0
# 5                         7.0                  14.0
# 6                       470.0                 210.0
# 7                       183.0                  39.0
# 8                       667.0                 668.0
# 9                       130.0                 110.0

# %%
journal.sort_values(by=['impact_factor_optimal_rank']).head(topk)
# Out:
#      centrality                              name         group  \
# 129    0.002278    QUARTERLY JOURNAL OF ECONOMICS  journaltitle
# 245    0.000522              JOURNAL OF ECONOMICS  journaltitle
# 147    0.001773    JOURNAL OF ECONOMIC LITERATURE  journaltitle
# 203    0.001033        JOURNAL OF ECONOMIC GROWTH  journaltitle
# 3      0.021245    JOURNAL OF FINANCIAL ECONOMICS  journaltitle
# 39     0.006962  JOURNAL OF ECONOMIC PERSPECTIVES  journaltitle
# 5      0.018919       REVIEW OF FINANCIAL STUDIES  journaltitle
# 4      0.020849          AMERICAN ECONOMIC REVIEW  journaltitle
# 16     0.011486      JOURNAL OF POLITICAL ECONOMY  journaltitle
# 18     0.011383                JOURNAL OF FINANCE  journaltitle
#
#      impact_factor_optimal_rank  h_index_optimal_rank
# 129                         1.0                   2.0
# 245                         1.0                   2.0
# 147                         2.0                  12.0
# 203                         4.0                  58.0
# 3                           5.0                   6.0
# 39                          6.0                  10.0
# 5                           7.0                  14.0
# 4                           8.0                   1.0
# 16                          9.0                   4.0
# 18                         10.0                   3.0

# %%
journal.sort_values(by=['h_index_optimal_rank']).head(topk)
# Out:
#      centrality                                name         group  \
# 4      0.020849            AMERICAN ECONOMIC REVIEW  journaltitle
# 245    0.000522                JOURNAL OF ECONOMICS  journaltitle
# 129    0.002278      QUARTERLY JOURNAL OF ECONOMICS  journaltitle
# 18     0.011383                  JOURNAL OF FINANCE  journaltitle
# 16     0.011486        JOURNAL OF POLITICAL ECONOMY  journaltitle
# 3      0.021245      JOURNAL OF FINANCIAL ECONOMICS  journaltitle
# 11     0.013726          REVIEW OF ECONOMIC STUDIES  journaltitle
# 64     0.004805       JOURNAL OF MONETARY ECONOMICS  journaltitle
# 39     0.006962    JOURNAL OF ECONOMIC PERSPECTIVES  journaltitle
# 23     0.010246  REVIEW OF ECONOMICS AND STATISTICS  journaltitle
#
#      impact_factor_optimal_rank  h_index_optimal_rank
# 4                           8.0                   1.0
# 245                         1.0                   2.0
# 129                         1.0                   2.0
# 18                         10.0                   3.0
# 16                          9.0                   4.0
# 3                           5.0                   6.0
# 11                         11.0                   7.0
# 64                         12.0                   8.0
# 39                          6.0                  10.0
# 23                         20.0                  11.0

# %%
journal_rk = journal

# %% [markdown]
# ### author ranking

# %%
topk = 10
author = df[df['group'] == 'Fullname']
author.head(topk)
# Out:
#      centrality                     name     group country  \
# 319    0.001461  Bahmani-Oskooee, Mohsen  Fullname     USA
# 344    0.001248           Wohar, Mark E.  Fullname     USA
# 382    0.001133         Hassan, M. Kabir  Fullname     USA
# 421    0.000931          Goel, Rajeev K.  Fullname     USA
# 449    0.000826         Baltagi, Badi H.  Fullname     USA
# 466    0.000733              Samek, Anya  Fullname     USA
# 472    0.000728  Hewings, Geoffrey J. D.  Fullname     USA
# 476    0.000727       Hammoudeh, Shawkat  Fullname     USA
# 477    0.000727      Johnston, Robert J.  Fullname     USA
# 517    0.000624       Munger, Michael C.  Fullname     USA
#
#             organization
# 319       Univ Wisconsin
# 344        Univ Nebraska
# 382     Univ New Orleans
# 421  Illinois State Univ
# 449        Syracuse Univ
# 466  Univ Southern Calif
# 472        Univ Illinois
# 476          Drexel Univ
# 477           Clark Univ
# 517            Duke Univ

# %% [markdown]
# ### author ranking by country

# %%
countries = df[df['group'] == 'Country']['name'].tolist()
for country in countries:
    print(country)
    print('centrality = ', df[df['name'] == country]['centrality'].iloc[0], sep='')
    authors = df[(df['country'] == country) & (df['group'] == 'Fullname')]
    print(authors.sort_values(by='centrality', ascending=False).head())
    print('-'*50)
# Out:
# USA
# centrality = 0.9916481863234224
#      centrality                     name     group country  \
# 319    0.001461  Bahmani-Oskooee, Mohsen  Fullname     USA
# 344    0.001248           Wohar, Mark E.  Fullname     USA
# 382    0.001133         Hassan, M. Kabir  Fullname     USA
# 421    0.000931          Goel, Rajeev K.  Fullname     USA
# 449    0.000826         Baltagi, Badi H.  Fullname     USA
#
#             organization
# 319       Univ Wisconsin
# 344        Univ Nebraska
# 382     Univ New Orleans
# 421  Illinois State Univ
# 449        Syracuse Univ
# --------------------------------------------------
# Peoples R China
# centrality = 0.004464139862145678
#       centrality            name     group          country  \
# 9451    0.000019  Wang, Shouyang  Fullname  Peoples R China
# 9453    0.000019        Ma, Feng  Fullname  Peoples R China
# 9479    0.000018    Lin, Boqiang  Fullname  Peoples R China
# 9638    0.000011       Yin, Libo  Fullname  Peoples R China
# 9684    0.000010    Wei, Yi-Ming  Fullname  Peoples R China
#
#                   organization
# 9451          Chinese Acad Sci
# 9453   Southwest Jiaotong Univ
# 9479               Xiamen Univ
# 9638  Cent Univ Finance & Econ
# 9684      Beijing Inst Technol
# --------------------------------------------------
# England
# centrality = 0.0021453814397650486
#       centrality                  name     group  country       organization
# 9544    0.000015        Sugden, Robert  Fullname  England   Univ East Anglia
# 9829    0.000008    Cartwright, Edward  Fullname  England   De Montfort Univ
# 9845    0.000007       Machin, Stephen  Fullname  England    London Sch Econ
# 9889    0.000007      Urquhart, Andrew  Fullname  England       Univ Reading
# 9914    0.000007  Lau, Chi Keung Marco  Fullname  England  Univ Huddersfield
# --------------------------------------------------
# Germany
# centrality = 0.0018273313354522066
#       centrality               name     group  country   organization
# 9850    0.000007   Potrafke, Niklas  Fullname  Germany    Univ Munich
# 9903    0.000007  Stadelmann, David  Fullname  Germany  Univ Bayreuth
# 9921    0.000007    Eichner, Thomas  Fullname  Germany     Univ Hagen
# 9922    0.000007   Pethig, Ruediger  Fullname  Germany    Univ Siegen
# 9959    0.000006    Dilme, Francesc  Fullname  Germany      Univ Bonn
# --------------------------------------------------
# Australia
# centrality = 0.0012121006785301115
#       centrality                      name     group    country  \
# 9474    0.000018  Churchill, Sefa Awaworyi  Fullname  Australia
# 9688    0.000010            Smyth, Russell  Fullname  Australia
# 9730    0.000009            Nguyen, Jeremy  Fullname  Australia
# 9736    0.000009       Selvanathan, Saroja  Fullname  Australia
# 9781    0.000008           Ivanovski, Kris  Fullname  Australia
#
#                 organization
# 9474               RMIT Univ
# 9688             Monash Univ
# 9730  Swinburne Univ Technol
# 9736           Griffith Univ
# 9781             Monash Univ
# --------------------------------------------------
# Italy
# centrality = 0.0011423432482987402
#        centrality                   name     group country  \
# 9823     0.000008  Battigalli, Pierpaolo  Fullname   Italy
# 9934     0.000007     Piccolo, Salvatore  Fullname   Italy
# 9988     0.000006        Pagnozzi, Marco  Fullname   Italy
# 10071    0.000006         Biggeri, Mario  Fullname   Italy
# 10080    0.000006  Caporin, Massimiliano  Fullname   Italy
#
#                   organization
# 9823              Bocconi Univ
# 9934              Univ Bergamo
# 9988   Univ Napoli Federico II
# 10071            Univ Florence
# 10080               Univ Padua
# --------------------------------------------------
# France
# centrality = 0.0008745539713262133
#        centrality                         name     group country  \
# 9396     0.000023         Tiwari, Aviral Kumar  Fullname  France
# 9788     0.000008            Boucekkine, Raouf  Fullname  France
# 9887     0.000007  Shahzad, Syed Jawad Hussain  Fullname  France
# 9966     0.000006               Roubaud, David  Fullname  France
# 10212    0.000005                Laguir, Issam  Fullname  France
#
#                    organization
# 9396   Montpellier Business Sch
# 9788         Aix Marseille Univ
# 9887   Montpellier Business Sch
# 9966   Montpellier Business Sch
# 10212  Montpellier Business Sch
# --------------------------------------------------
# Spain
# centrality = 0.0007479854769063415
#        centrality                      name     group country    organization
# 9968     0.000006  Alberiko Gil-Alana, Luis  Fullname   Spain    Univ Navarra
# 9971     0.000006        Gil-Alana, Luis A.  Fullname   Spain    Univ Navarra
# 10030    0.000006              Ayllon, Sara  Fullname   Spain     Univ Girona
# 10073    0.000006         Gomez-Puig, Marta  Fullname   Spain  Univ Barcelona
# 10117    0.000005   Picazo-Tadeo, Andres J.  Fullname   Spain   Univ Valencia
# --------------------------------------------------
# Canada
# centrality = 0.0007233817374136798
#        centrality                  name     group country       organization
# 10082    0.000006       Punjabi, Bharat  Fullname  Canada       Univ Toronto
# 10143    0.000005     Jenkins, Glenn P.  Fullname  Canada        Queens Univ
# 10180    0.000005    Trudeau, Christian  Fullname  Canada       Univ Windsor
# 10183    0.000005  Lloyd-Smith, Patrick  Fullname  Canada  Univ Saskatchewan
# 10234    0.000005     Amodio, Francesco  Fullname  Canada        McGill Univ
# --------------------------------------------------
# Netherlands
# centrality = 0.0005646300091025707
#        centrality                   name     group      country  \
# 9949     0.000006    van Doorslaer, Eddy  Fullname  Netherlands
# 10201    0.000005     Van De Ven, Jeroen  Fullname  Netherlands
# 10243    0.000005            Heufer, Jan  Fullname  Netherlands
# 10247    0.000005  Kantorowicz, Jaroslaw  Fullname  Netherlands
# 10397    0.000004   van Dijk, Mathijs A.  Fullname  Netherlands
#
#          organization
# 9949     Erasmus Univ
# 10201  Univ Amsterdam
# 10243    Erasmus Univ
# 10247     Leiden Univ
# 10397    Erasmus Univ
# --------------------------------------------------
# South Korea
# centrality = 0.0004462427879230545
#        centrality             name     group      country       organization
# 9839     0.000008  Yoon, Seong-Min  Fullname  South Korea    Pusan Natl Univ
# 9944     0.000006     Kim, Minjung  Fullname  South Korea      Wonkwang Univ
# 9972     0.000006   Kim, Bong Hwan  Fullname  South Korea    Seoul Natl Univ
# 10362    0.000004    Lin, Shu-Chin  Fullname  South Korea  Sungkyunkwan Univ
# 10503    0.000004  Hwang, Sangyeon  Fullname  South Korea  Incheon Natl Univ
# --------------------------------------------------
# Japan
# centrality = 0.0004436643767616551
#        centrality               name     group country        organization
# 9871     0.000007       Kotani, Koji  Fullname   Japan  Kochi Univ Technol
# 10046    0.000006     Kinkyo, Takuji  Fullname   Japan           Kobe Univ
# 10163    0.000005  Saijo, Tatsuyoshi  Fullname   Japan  Kochi Univ Technol
# 10321    0.000005    Takeuchi, Kenji  Fullname   Japan           Kobe Univ
# 10491    0.000004    Otsuka, Keijiro  Fullname   Japan           Kobe Univ
# --------------------------------------------------
# Switzerland
# centrality = 0.00034239837778746814
#        centrality                name     group      country     organization
# 10084    0.000006     Fuster, Andreas  Fullname  Switzerland  Swiss Natl Bank
# 10094    0.000005         Asri, Viola  Fullname  Switzerland      Univ Zurich
# 10095    0.000005      Adams, Timothy  Fullname  Switzerland        Univ Bern
# 10096    0.000005  Gerber, Jean-David  Fullname  Switzerland        Univ Bern
# 10375    0.000004      Michaely, Roni  Fullname  Switzerland      Univ Geneva
# --------------------------------------------------
# Sweden
# centrality = 0.00029914672581922143
#        centrality               name     group country          organization
# 9854     0.000007   Gerdtham, Ulf-G.  Fullname  Sweden             Lund Univ
# 9920     0.000007  Uddin, Gazi Salah  Fullname  Sweden        Linkoping Univ
# 10097    0.000005    Andersson, Anna  Fullname  Sweden  Swedish Univ Agr Sci
# 10437    0.000004       Nilsson, Pia  Fullname  Sweden        Jonkoping Univ
# 10442    0.000004    Metzger, Daniel  Fullname  Sweden    Stockholm Sch Econ
# --------------------------------------------------
# India
# centrality = 0.0002922130487860089
#        centrality                   name     group country  \
# 10158    0.000005            Jain, Tarun  Fullname   India
# 10537    0.000004         Pathak, Rajesh  Fullname   India
# 10658    0.000004  Soundararajan, Vidhya  Fullname   India
# 11429    0.000003     Mitra, Manipushpak  Fullname   India
# 11599    0.000003      Pradhan, Rudra P.  Fullname   India
#
#                            organization
# 10158               Indian Sch Business
# 10537               Goa Inst Management
# 10658  Indian Inst Management Bangalore
# 11429                  Indian Stat Inst
# 11599               Indian Inst Technol
# --------------------------------------------------
# Brazil
# centrality = 0.00023462658360413888
#        centrality                          name     group country  \
# 11161    0.000003            Goncalves, Eduardo  Fullname  Brazil
# 11529    0.000003  de Mendonca, Helder Ferreira  Fullname  Brazil
# 11640    0.000003                Strassburg, B.  Fullname  Brazil
# 11647    0.000003              Mattos, Enlinson  Fullname  Brazil
# 11648    0.000003                 Toni, Fabiano  Fullname  Brazil
#
#                 organization
# 11161  Univ Fed Juiz de Fora
# 11529    Fluminense Fed Univ
# 11640   Int Inst Sustainabil
# 11647     Getulio Vargas Fdn
# 11648          Univ Brasilia
# --------------------------------------------------
# Turkey
# centrality = 0.00021726719132970717
#        centrality                     name     group country  \
# 10734    0.000003              Ertac, Seda  Fullname  Turkey
# 10820    0.000003           Yildiz, Yilmaz  Fullname  Turkey
# 10864    0.000003  Erkan, B. Burcak Basbug  Fullname  Turkey
# 10891    0.000003           Demiroglu, Cem  Fullname  Turkey
# 10958    0.000003        Gurdal, Mehmet Y.  Fullname  Turkey
#
#                 organization
# 10734               Koc Univ
# 10820         Hacettepe Univ
# 10864  Middle East Tech Univ
# 10891               Koc Univ
# 10958          Bogazici Univ
# --------------------------------------------------
# Taiwan
# centrality = 0.0002076484982761116
#        centrality               name     group country  \
# 10250    0.000005    Chiang, Shu-Mei  Fullname  Taiwan
# 10251    0.000005     Liu, Hung-Chun  Fullname  Taiwan
# 10399    0.000004  Lee, Chien-Chiang  Fullname  Taiwan
# 11093    0.000003     Chen, Ting-Cih  Fullname  Taiwan
# 11219    0.000003       Hsieh, Joyce  Fullname  Taiwan
#
#                       organization
# 10250   Lunghwa Univ Sci & Technol
# 10251  Minghsin Univ Sci & Technol
# 10399        Natl Sun Yat Sen Univ
# 11093                 Tamkang Univ
# 11219                 Tamkang Univ
# --------------------------------------------------
# Norway
# centrality = 0.0001976661042487728
#        centrality               name     group country  \
# 10943    0.000003       Krumer, Alex  Fullname  Norway
# 11715    0.000003   Holden, Stein T.  Fullname  Norway
# 11716    0.000003       Bezu, Sosina  Fullname  Norway
# 11721    0.000003  Lorena Ruano, Ana  Fullname  Norway
# 11724    0.000003      Tvedten, Inge  Fullname  Norway
#
#                   organization
# 10943          Molde Univ Coll
# 11715  Norwegian Univ Life Sci
# 11716  Norwegian Univ Life Sci
# 11721              Univ Bergen
# 11724       Chr Michelsen Inst
# --------------------------------------------------
# New Zealand
# centrality = 0.00018646431803850903
#        centrality                  name     group      country  \
# 9991     0.000006          Frijns, Bart  Fullname  New Zealand
# 9992     0.000006  Tourani-Rad, Alireza  Fullname  New Zealand
# 10093    0.000005              Li, Leon  Fullname  New Zealand
# 10103    0.000005          Balli, Faruk  Fullname  New Zealand
# 10357    0.000004       Haug, Alfred A.  Fullname  New Zealand
#
#                 organization
# 9991   Auckland Univ Technol
# 9992   Auckland Univ Technol
# 10093           Univ Waikato
# 10103            Massey Univ
# 10357             Univ Otago
# --------------------------------------------------
# Austria
# centrality = 0.00017650285245771063
#        centrality                    name     group  country  \
# 9867     0.000007     Kerschbamer, Rudolf  Fullname  Austria
# 10241    0.000005          Kopel, Michael  Fullname  Austria
# 10775    0.000003          Lackner, Mario  Fullname  Austria
# 11090    0.000003           Loretz, Simon  Fullname  Austria
# 11222    0.000003  Guentner, Jochen H. F.  Fullname  Austria
#
#                     organization
# 9867              Univ Innsbruck
# 10241    Karl Franzens Univ Graz
# 10775  Johannes Kepler Univ Linz
# 11090     Austrian Inst Econ Res
# 11222  Johannes Kepler Univ Linz
# --------------------------------------------------
# Belgium
# centrality = 0.0001742889660085881
#        centrality                name     group  country  \
# 10567    0.000004       Wang, Hwachyi  Fullname  Belgium
# 10568    0.000004       Lauwers, Dirk  Fullname  Belgium
# 11217    0.000003       Delarue, Erik  Fullname  Belgium
# 11438    0.000003  De Weerdt, Joachim  Fullname  Belgium
# 11663    0.000003       Meyfroidt, P.  Fullname  Belgium
#
#                  organization
# 10567              Univ Ghent
# 10568              Univ Ghent
# 11217  Katholieke Univ Leuven
# 11438  Katholieke Univ Leuven
# 11663   Catholic Univ Louvain
# --------------------------------------------------
# Singapore
# centrality = 0.0001709980682797199
#        centrality                  name     group    country  \
# 9919     0.000007   Riyanto, Yohanes E.  Fullname  Singapore
# 10022    0.000006            Ang, B. W.  Fullname  Singapore
# 10064    0.000006        Sing, Tien Foo  Fullname  Singapore
# 10298    0.000005  Lam, Jasmine Siu Lee  Fullname  Singapore
# 10388    0.000004               Su, Bin  Fullname  Singapore
#
#                organization
# 9919   Nanyang Technol Univ
# 10022   Natl Univ Singapore
# 10064   Natl Univ Singapore
# 10298  Nanyang Technol Univ
# 10388   Natl Univ Singapore
# --------------------------------------------------
# Portugal
# centrality = 0.00016054421822340022
#        centrality                  name     group   country  \
# 10149    0.000005   Vasconcelos, Helder  Fullname  Portugal
# 10260    0.000005  Teixeira, Joao C. A.  Fullname  Portugal
# 10286    0.000005      Marreiros, Helia  Fullname  Portugal
# 10324    0.000005       Guimaraes, Luis  Fullname  Portugal
# 10672    0.000004         Brito, Duarte  Fullname  Portugal
#
#                    organization
# 10149                Univ Porto
# 10260               Univ Azores
# 10286  Univ Catolica Portuguesa
# 10324                Univ Porto
# 10672          Univ Nova Lisboa
# --------------------------------------------------
# Scotland
# centrality = 0.000148877248820203
#        centrality                 name     group   country    organization
# 10105    0.000005       Ryan, Casey M.  Fullname  Scotland  Univ Edinburgh
# 10737    0.000003  Comerford, David A.  Fullname  Scotland   Univ Stirling
# 10744    0.000003         Hanley, Nick  Fullname  Scotland    Univ Glasgow
# 10985    0.000003       Kiso, Takahiko  Fullname  Scotland   Univ Aberdeen
# 11439    0.000003      Phimister, Euan  Fullname  Scotland   Univ Aberdeen
# --------------------------------------------------
# Poland
# centrality = 0.00013511747478716396
#        centrality                 name     group country  \
# 9877     0.000007  Czajkowski, Mikolaj  Fullname  Poland
# 10528    0.000004  Mikutowski, Mateusz  Fullname  Poland
# 10529    0.000004     Krawczyk, Michal  Fullname  Poland
# 10698    0.000004       Goczek, Lukasz  Fullname  Poland
# 10707    0.000004   Marcjasz, Grzegorz  Fullname  Poland
#
#                       organization
# 9877                   Univ Warsaw
# 10528  Poznan Univ Econ & Business
# 10529                  Univ Warsaw
# 10698                  Univ Warsaw
# 10707   Wroclaw Univ Sci & Technol
# --------------------------------------------------
# Chile
# centrality = 0.00013487168677003462
#        centrality                   name     group country  \
# 10398    0.000004            Sauma, Enzo  Fullname   Chile
# 10689    0.000004  de Dios Ortuzar, Juan  Fullname   Chile
# 11228    0.000003      Rosende, Catalina  Fullname   Chile
# 11538    0.000003       Claro, Sebastian  Fullname   Chile
# 11752    0.000003         Livert, Felipe  Fullname   Chile
#
#                          organization
# 10398  Pontificia Univ Catolica Chile
# 10689  Pontificia Univ Catolica Chile
# 11228  Pontificia Univ Catolica Chile
# 11538  Pontificia Univ Catolica Chile
# 11752            Univ Alberto Hurtado
# --------------------------------------------------
# Finland
# centrality = 0.00012425876846010846
#        centrality                           name     group  country  \
# 10408    0.000004                   Karhinen, S.  Fullname  Finland
# 10462    0.000004                  Grobys, Klaus  Fullname  Finland
# 10643    0.000004               Pehkonen, Jaakko  Fullname  Finland
# 10986    0.000003             Ollikainen, Markku  Fullname  Finland
# 11281    0.000003  Kopsakangas-Savolainen, Maria  Fullname  Finland
#
#          organization
# 10408       Univ Oulu
# 10462      Univ Vaasa
# 10643  Univ Jyvaskyla
# 10986   Univ Helsinki
# 11281       Univ Oulu
# --------------------------------------------------
# Israel
# centrality = 0.00011293605617025018
#        centrality           name     group country           organization
# 10873    0.000003  Azar, Ofer H.  Fullname  Israel  Ben Gurion Univ Negev
# 10950    0.000003  Heller, Yuval  Fullname  Israel          Bar Ilan Univ
# 10987    0.000003      Kan, Iddo  Fullname  Israel  Hebrew Univ Jerusalem
# 11149    0.000003   Arbel, Yuval  Fullname  Israel   Western Galilee Coll
# 11493    0.000003  Yaniv, Gideon  Fullname  Israel             Ariel Univ
# --------------------------------------------------
# Greece
# centrality = 0.00010190282012261076
#        centrality                   name     group country  \
# 10011    0.000006     Petrakis, Emmanuel  Fullname  Greece
# 10128    0.000005  Plakandaras, Vasilios  Fullname  Greece
# 12643    0.000002           Benos, Nikos  Fullname  Greece
# 12644    0.000002        Zotou, Stefania  Fullname  Greece
# 12981    0.000002      Loukaki, Kalliopi  Fullname  Greece
#
#                  organization
# 10011              Univ Crete
# 10128  Democritus Univ Thrace
# 12643           Univ Ioannina
# 12644           Univ Ioannina
# 12981             Univ Athens
# --------------------------------------------------
# South Africa
# centrality = 9.921728242150306e-05
#        centrality                       name     group       country  \
# 10596    0.000004          Piraino, Patrizio  Fullname  South Africa
# 11706    0.000003             Munene, Daniel  Fullname  South Africa
# 11759    0.000003              Smit, Suzanne  Fullname  South Africa
# 11760    0.000003  Musango, Josephine Kaviti  Fullname  South Africa
# 11761    0.000003              Kovacic, Zora  Fullname  South Africa
#
#             organization
# 10596     Univ Cape Town
# 11706     Univ Cape Town
# 11759  Stellenbosch Univ
# 11760  Stellenbosch Univ
# 11761  Stellenbosch Univ
# --------------------------------------------------
# Denmark
# centrality = 8.903110417222168e-05
#        centrality                   name     group  country  \
# 10283    0.000005          Morin, Annaig  Fullname  Denmark
# 10459    0.000004          Tierney, Ryan  Fullname  Denmark
# 11496    0.000003         Jinkins, David  Fullname  Denmark
# 11770    0.000003  Ulriksen, Marianne S.  Fullname  Denmark
# 12546    0.000002          Nonejad, Nima  Fullname  Denmark
#
#                   organization
# 10283  Copenhagen Business Sch
# 10459    Univ Southern Denmark
# 11496  Copenhagen Business Sch
# 11770    Univ Southern Denmark
# 12546             Aalborg Univ
# --------------------------------------------------
# Ireland
# centrality = 7.965060764453962e-05
#        centrality                         name     group  country  \
# 10001    0.000006                  Boysen, Ole  Fullname  Ireland
# 10681    0.000004               Conlon, Thomas  Fullname  Ireland
# 11775    0.000003           Mbelu, Asithandile  Fullname  Ireland
# 11776    0.000003           Bresnihan, Patrick  Fullname  Ireland
# 12215    0.000003  Papavassiliou, Vassilios G.  Fullname  Ireland
#
#               organization
# 10001     Univ Coll Dublin
# 10681     Univ Coll Dublin
# 11775  Trinity Coll Dublin
# 11776  Trinity Coll Dublin
# 12215     Univ Coll Dublin
# --------------------------------------------------
# Mexico
# centrality = 7.464523211084086e-05
#        centrality                    name     group country  \
# 10239    0.000005  Garduno-Rivera, Rafael  Fullname  Mexico
# 10743    0.000003        Dominguez, Diego  Fullname  Mexico
# 10953    0.000003          Menna, Lorenzo  Fullname  Mexico
# 11016    0.000003       Ibarra, Carlos A.  Fullname  Mexico
# 11605    0.000003              Ros, Jaime  Fullname  Mexico
#
#                     organization
# 10239                       CIDE
# 10743                       ITAM
# 10953               Banco Mexico
# 11016       Univ Americas Puebla
# 11605  Univ Nacl Autonoma Mexico
# --------------------------------------------------
# U Arab Emirates
# centrality = 7.368120888143246e-05
#        centrality                        name     group          country  \
# 10076    0.000006                Umar, Zaghum  Fullname  U Arab Emirates
# 10319    0.000005  Karathanasopoulos, Andreas  Fullname  U Arab Emirates
# 11638    0.000003         Gaibulloev, Khusrav  Fullname  U Arab Emirates
# 12069    0.000003            Maydybura, Alina  Fullname  U Arab Emirates
# 12751    0.000002               Tasneem, Dina  Fullname  U Arab Emirates
#
#             organization
# 10076         Zayed Univ
# 10319         Univ Dubai
# 11638  Amer Univ Sharjah
# 12069         Univ Dubai
# 12751  Amer Univ Sharjah
# --------------------------------------------------
# Romania
# centrality = 7.199063441513328e-05
#        centrality                        name     group  country  \
# 10282    0.000005  Albulescu, Claudiu Tiberiu  Fullname  Romania
# 12675    0.000002                 Budz, Sonia  Fullname  Romania
# 12757    0.000002            Krutwig, Michael  Fullname  Romania
# 12758    0.000002              Starosta, Kejo  Fullname  Romania
# 12767    0.000002         Comes, Calin-Adrian  Fullname  Romania
#
#                                    organization
# 10282                   Politehn Univ Timisoara
# 12675               Bucharest Univ Econ Studies
# 12757               Bucharest Univ Econ Studies
# 12758               Bucharest Univ Econ Studies
# 12767  Univ Med Pharm Sci & Technol Tirgu Mures
# --------------------------------------------------
# Vietnam
# centrality = 6.740598526022735e-05
#        centrality              name     group  country  \
# 10538    0.000004  Salisu, Afees A.  Fullname  Vietnam
# 11737    0.000003     de Haan, Stef  Fullname  Vietnam
# 11746    0.000003      Vo, Thang T.  Fullname  Vietnam
# 11780    0.000003          Nhung Vu  Fullname  Vietnam
# 11781    0.000003      Vu Hoang Nam  Fullname  Vietnam
#
#                      organization
# 10538          Ton Duc Thang Univ
# 11737               CIAT Asia Off
# 11746  Univ Econ Ho Chi Minh City
# 11780      Vietnamese German Univ
# 11781          Foreign Trade Univ
# --------------------------------------------------
# Colombia
# centrality = 6.415037046768691e-05
#        centrality                     name     group   country  \
# 11636    0.000003            Cramer, Laura  Fullname  Colombia
# 11691    0.000003  Bonilla-Mejia, Leonardo  Fullname  Colombia
# 11733    0.000003         Bene, Christophe  Fullname  Colombia
# 11734    0.000003         Prager, Steve D.  Fullname  Colombia
# 11735    0.000003             Lamotte, Lea  Fullname  Colombia
#
#                 organization
# 11636  Int Ctr Trop Agr CIAT
# 11691           Banco Republ
# 11733       Int Ctr Trop Agr
# 11734       Int Ctr Trop Agr
# 11735       Int Ctr Trop Agr
# --------------------------------------------------
# Czech Republic
# centrality = 5.799064740220118e-05
#        centrality                  name     group         country  \
# 10405    0.000004  Kristoufek, Ladislav  Fullname  Czech Republic
# 11050    0.000003        Lyocsa, Stefan  Fullname  Czech Republic
# 12803    0.000002         Vavrek, Roman  Fullname  Czech Republic
# 13606    0.000002     Stanek, Rostislav  Fullname  Czech Republic
# 13607    0.000002         Krcal, Ondrej  Fullname  Czech Republic
#
#               organization
# 10405  Charles Univ Prague
# 11050         Masaryk Univ
# 12803    Tech Univ Liberec
# 13606         Masaryk Univ
# 13607         Masaryk Univ
# --------------------------------------------------
# Pakistan
# centrality = 5.371023447029428e-05
#        centrality            name     group   country  \
# 11793    0.000003  Chaudhry, Azam  Fullname  Pakistan
# 11794    0.000003    Wadho, Waqar  Fullname  Pakistan
# 12548    0.000002   Munir, Kashif  Fullname  Pakistan
# 12549    0.000002     Riaz, Nimra  Fullname  Pakistan
# 12777    0.000002     Riaz, Yasir  Fullname  Pakistan
#
#                      organization
# 11793             Lahore Sch Econ
# 11794             Lahore Sch Econ
# 12548            Univ Cent Punjab
# 12549            Univ Cent Punjab
# 12777  Lahore Univ Management Sci
# --------------------------------------------------
# Hungary
# centrality = 5.066143317290507e-05
#        centrality             name     group  country            organization
# 12815    0.000002      Dombi, Akos  Fullname  Hungary      Eotvos Lorand Univ
# 12816    0.000002    Dedak, Istvan  Fullname  Hungary  Eszterhazy Karoly Univ
# 12944    0.000002  Zrubka, Zsombor  Fullname  Hungary  Corvinus Univ Budapest
# 13167    0.000002    Pentek, Marta  Fullname  Hungary  Corvinus Univ Budapest
# 13168    0.000002  Gulacsi, Laszlo  Fullname  Hungary  Corvinus Univ Budapest
# --------------------------------------------------
# Argentina
# centrality = 4.281750701955744e-05
#        centrality               name     group    country  \
# 12286    0.000003    Elias, Julio J.  Fullname  Argentina
# 12958    0.000002    Sigman, Mariano  Fullname  Argentina
# 12959    0.000002  Galvez, Ramiro H.  Fullname  Argentina
# 12960    0.000002      Shalom, Diego  Fullname  Argentina
# 12961    0.000002      Freira, Lucia  Fullname  Argentina
#
#                  organization
# 12286               Univ CEMA
# 12958  Univ Torcuato Di Tella
# 12959  Univ Torcuato Di Tella
# 12960  Univ Torcuato Di Tella
# 12961  Univ Torcuato Di Tella
# --------------------------------------------------
# Malaysia
# centrality = 4.101683444028122e-05
#        centrality                    name     group   country  \
# 10264    0.000005       Nair, Mahendhiran  Fullname  Malaysia
# 13836    0.000002          Lee, Chew Ging  Fullname  Malaysia
# 13837    0.000002  Khiew, Danny Nam Chien  Fullname  Malaysia
# 13838    0.000002       Furuoka, Fumitaka  Fullname  Malaysia
# 17173    0.000001  Nesadurai, Helen E. S.  Fullname  Malaysia
#
#                           organization
# 10264             Monash Univ Malaysia
# 13836  Univ Nottingham Malaysia Campus
# 13837  Univ Nottingham Malaysia Campus
# 13838                      Univ Malaya
# 17173             Monash Univ Malaysia
# --------------------------------------------------
# Tunisia
# centrality = 3.979964853197239e-05
#        centrality                  name     group  country  \
# 12275    0.000003     Ben Kheder, Sonia  Fullname  Tunisia
# 12805    0.000002  Madani, Mohamed Arbi  Fullname  Tunisia
# 12817    0.000002        Soussou, Karim  Fullname  Tunisia
# 12818    0.000002      Omri, Abdelwahed  Fullname  Tunisia
# 12823    0.000002        Jammazi, Rania  Fullname  Tunisia
#
#                  organization
# 12275              Univ Tunis
# 12805              Univ Tunis
# 12817              Univ Tunis
# 12818              Univ Tunis
# 12823  Natl Sch Comp Sci ENSI
# --------------------------------------------------
# Iran
# centrality = 3.9421519239094295e-05
#        centrality                    name     group country  \
# 12543    0.000002         Movaghari, Hadi  Fullname    Iran
# 12819    0.000002  Farani, Ahmad Yaghoubi  Fullname    Iran
# 12820    0.000002           Karimi, Saeid  Fullname    Iran
# 12821    0.000002            Izadi, Nasim  Fullname    Iran
# 12824    0.000002           Ataei, Pouria  Fullname    Iran
#
#                organization
# 12543  Tarbiat Modares Univ
# 12819      Bu Ali Sina Univ
# 12820      Bu Ali Sina Univ
# 12821      Bu Ali Sina Univ
# 12824  Tarbiat Modares Univ
# --------------------------------------------------
# Wales
# centrality = 3.529466432397609e-05
#        centrality                        name     group country  organization
# 10161    0.000005             Blackaby, David  Fullname   Wales  Swansea Univ
# 10677    0.000004                Mann, Samuel  Fullname   Wales  Swansea Univ
# 12841    0.000002                  Wong, Woon  Fullname   Wales  Univ Cardiff
# 13784    0.000002           Abdel-Latif, Hany  Fullname   Wales  Swansea Univ
# 14401    0.000002  Nikolopoulos, Konstantinos  Fullname   Wales   Bangor Univ
# --------------------------------------------------
# Luxembourg
# centrality = 3.428496620699564e-05
#        centrality                name     group     country  \
# 10650    0.000004   Neugebauer, Tibor  Fullname  Luxembourg
# 11738    0.000003  Lepinteur, Anthony  Fullname  Luxembourg
# 11754    0.000003     Tenikue, Michel  Fullname  Luxembourg
# 12596    0.000002      Greiff, Samuel  Fullname  Luxembourg
# 12853    0.000002        Ninka, Eniel  Fullname  Luxembourg
#
#                               organization
# 10650                      Univ Luxembourg
# 11738                      Univ Luxembourg
# 11754  Luxembourg Inst Socioecon Res LISER
# 12596                      Univ Luxembourg
# 12853                    SOGETI Luxembourg
# --------------------------------------------------
# Kenya
# centrality = 3.4015835228661656e-05
#        centrality                     name     group country  \
# 10110    0.000005     Wossen, Tesfamicheal  Fullname   Kenya
# 10557    0.000004              Low, Jan W.  Fullname   Kenya
# 11531    0.000003          Shapiro, Jeremy  Fullname   Kenya
# 11703    0.000003        Jensen, Nathaniel  Fullname   Kenya
# 11785    0.000003  Ambole, Lorraine Amollo  Fullname   Kenya
#
#                  organization
# 10110                    IITA
# 10557          Int Potato Ctr
# 11531   Busara Ctr Behav Econ
# 11703  Int Livestock Res Inst
# 11785            Univ Nairobi
# --------------------------------------------------
# Russia
# centrality = 3.284639461485459e-05
#        centrality               name     group country  \
# 14532    0.000002  Karpov, Alexander  Fullname  Russia
# 15751    0.000001        Pozo, David  Fullname  Russia
# 15752    0.000001     Bialek, Janusz  Fullname  Russia
# 15753    0.000001    Churkin, Andrey  Fullname  Russia
# 15755    0.000001    Korgin, Nikolay  Fullname  Russia
#
#                                organization
# 14532         Natl Res Univ Higher Sch Econ
# 15751  Skolkovo Inst Sci & Technol Skoltech
# 15752  Skolkovo Inst Sci & Technol Skoltech
# 15753  Skolkovo Inst Sci & Technol Skoltech
# 15755                      Russian Acad Sci
# --------------------------------------------------
# Ethiopia
# centrality = 2.7453685228376972e-05
#        centrality                    name     group   country  \
# 11695    0.000003       Bezabih, Mintewab  Fullname  Ethiopia
# 11701    0.000003       Gebrehiwot, Tagel  Fullname  Ethiopia
# 11804    0.000003       Geebreyesus, Mulu  Fullname  Ethiopia
# 11805    0.000003          Ginbo, Tsegaye  Fullname  Ethiopia
# 11808    0.000003  Teklewold, Hailemariam  Fullname  Ethiopia
#
#                  organization
# 11695  Ethiopian Dev Res Inst
# 11701  Ethiopian Dev Res Inst
# 11804                    EDRI
# 11805                    EDRI
# 11808  Ethiopian Dev Res Inst
# --------------------------------------------------
# Thailand
# centrality = 2.6288806336948678e-05
#        centrality                        name     group   country  \
# 11755    0.000003        Limwattananon, Supon  Fullname  Thailand
# 12863    0.000002          Suchintabandid, S.  Fullname  Thailand
# 12864    0.000002             Danswasvong, T.  Fullname  Thailand
# 13701    0.000002  Chatjuthamard, Pattanaporn  Fullname  Thailand
# 13703    0.000002         Chintrakarn, Pandej  Fullname  Thailand
#
#              organization
# 11755      Khon Kaen Univ
# 12863  Chulalongkorn Univ
# 12864  Chulalongkorn Univ
# 13701  Chulalongkorn Univ
# 13703                MUIC
# --------------------------------------------------
# North Ireland
# centrality = 2.459372401489798e-05
#        centrality                     name     group        country  \
# 11814    0.000003  Rondon-Sulbaran, Janeet  Fullname  North Ireland
# 11815    0.000003         Brennan, Michael  Fullname  North Ireland
# 13027    0.000002        Dimico, Arcangelo  Fullname  North Ireland
# 13823    0.000002          Turner, John D.  Fullname  North Ireland
# 13824    0.000002         Campbell, Gareth  Fullname  North Ireland
#
#               organization
# 11814          Ulster Univ
# 11815          Ulster Univ
# 13027  Queens Univ Belfast
# 13823  Queens Univ Belfast
# 13824  Queens Univ Belfast
# --------------------------------------------------
# Nigeria
# centrality = 2.3627493461031283e-05
#        centrality                     name     group  country  \
# 12808    0.000002   Olofin, Sodik Adejonwo  Fullname  Nigeria
# 12809    0.000002      Olayeni, Richard O.  Fullname  Nigeria
# 12876    0.000002    Awe, Olushina Olawale  Fullname  Nigeria
# 13832    0.000002  Olayeni, Olaolu Richard  Fullname  Nigeria
# 17477    0.000001       Adewuyi, Adeolu O.  Fullname  Nigeria
#
#                organization
# 12808  Obafemi Awolowo Univ
# 12809  Obafemi Awolowo Univ
# 12876           Anchor Univ
# 13832  Obafemi Awolowo Univ
# 17477           Univ Ibadan
# --------------------------------------------------
# Indonesia
# centrality = 2.306723182699403e-05
#        centrality                         name     group    country  \
# 11807    0.000003               Jagau, Yusurum  Fullname  Indonesia
# 11812    0.000003              Asnawi, Rosyani  Fullname  Indonesia
# 11813    0.000003              Irawan, Bambang  Fullname  Indonesia
# 13204    0.000002  Yudhistira, Muhammad Halley  Fullname  Indonesia
# 13842    0.000002        Maulana, Rifqi Alfian  Fullname  Indonesia
#
#              organization
# 11807  Univ Palangka Raya
# 11812          Univ Jambi
# 11813          Univ Jambi
# 13204      Univ Indonesia
# 13842      Univ Indonesia
# --------------------------------------------------
# Peru
# centrality = 2.0766558403542946e-05
#        centrality                name     group country  \
# 11810    0.000003     Larson, Anne M.  Fullname    Peru
# 11818    0.000003     Scurrah, Martin  Fullname    Peru
# 13243    0.000002  Natividad, Gabriel  Fullname    Peru
# 14483    0.000002   Jaramillo, Miguel  Fullname    Peru
# 16783    0.000001     Cueto, Santiago  Fullname    Peru
#
#                         organization
# 11810                            CIP
# 11818         Inst Estudios Peruanos
# 13243                     Univ Piura
# 14483                   Grp Anal Dev
# 16783  Pontificia Univ Catolica Peru
# --------------------------------------------------
# Qatar
# centrality = 2.0719607529808307e-05
#        centrality                   name     group country     organization
# 10824    0.000003        Goaied, Mohamed  Fullname   Qatar       Qatar Univ
# 12849    0.000002  Elgammal, Mohammed M.  Fullname   Qatar       Qatar Univ
# 13019    0.000002          Temimi, Akram  Fullname   Qatar       Qatar Univ
# 13793    0.000002  Ben Ali, Mohamed Sami  Fullname   Qatar       Qatar Univ
# 13843    0.000002         Abuzayed, Bana  Fullname   Qatar  Qatar Univ Doha
# --------------------------------------------------
# Cyprus
# centrality = 2.062816929993071e-05
#        centrality                  name     group country  \
# 10753    0.000003   Xefteris, Dimitrios  Fullname  Cyprus
# 10828    0.000003  Nishiotis, George P.  Fullname  Cyprus
# 11878    0.000003    Milidonis, Andreas  Fullname  Cyprus
# 12979    0.000002  Makrominas, Michalis  Fullname  Cyprus
# 12980    0.000002      Samatas, Andreas  Fullname  Cyprus
#
#                       organization
# 10753                  Univ Cyprus
# 10828                  Univ Cyprus
# 11878                  Univ Cyprus
# 12979        Frederick Univ Cyprus
# 12980  TeleThade DJ Int Consulting
# --------------------------------------------------
# Saudi Arabia
# centrality = 2.041892701652851e-05
#        centrality                name     group       country  \
# 12874    0.000002       Aloui, Chaker  Fullname  Saudi Arabia
# 13848    0.000002  Kadasah, Nasser A.  Fullname  Saudi Arabia
# 15432    0.000001          Dua, Rubal  Fullname  Saudi Arabia
# 15668    0.000001     Galkin, Philipp  Fullname  Saudi Arabia
# 15669    0.000001     Rioux, Bertrand  Fullname  Saudi Arabia
#
#                                        organization
# 12874                            Prince Sultan Univ
# 13848                           King Abdulaziz Univ
# 15432  King Abdullah Petr Studies & Res Ctr KAPSARC
# 15668          King Abdullah Petr Studies & Res Ctr
# 15669          King Abdullah Petr Studies & Res Ctr
# --------------------------------------------------
# Slovenia
# centrality = 1.9444481004178452e-05
#        centrality             name     group   country    organization
# 12854    0.000002       Beko, Jani  Fullname  Slovenia    Univ Maribor
# 12855    0.000002    Fister, Dusan  Fullname  Slovenia    Univ Maribor
# 12856    0.000002  Jagric, Timotej  Fullname  Slovenia    Univ Maribor
# 12873    0.000002    Beznec, Peter  Fullname  Slovenia  Ctr Hlth & Dev
# 17736    0.000001       Spruk, Rok  Fullname  Slovenia  Univ Ljubljana
# --------------------------------------------------
# Ghana
# centrality = 1.841644590757676e-05
#        centrality                  name     group country     organization
# 11819    0.000003  Dzanku, Fred Mawunyo  Fullname   Ghana       Univ Ghana
# 13015    0.000002           Dadzie, Sam  Fullname   Ghana  Univ Cape Coast
# 14895    0.000002     Sulemana, Iddisah  Fullname   Ghana       Univ Ghana
# 14982    0.000002     Adom, Philip Kofi  Fullname   Ghana            GIMPA
# 17124    0.000001     Osei-Akoto, Isaac  Fullname   Ghana       Univ Ghana
# --------------------------------------------------
# Liechtenstein
# centrality = 1.691860646425709e-05
#        centrality         name     group        country        organization
# 12832    0.000002   Kaiser, L.  Fullname  Liechtenstein  Univ Liechtenstein
# 12833    0.000002    Peter, G.  Fullname  Liechtenstein  Univ Liechtenstein
# 12834    0.000002   Veress, A.  Fullname  Liechtenstein  Univ Liechtenstein
# 12835    0.000002  Duenser, M.  Fullname  Liechtenstein  Univ Liechtenstein
# 12836    0.000002  Angerer, M.  Fullname  Liechtenstein  Univ Liechtenstein
# --------------------------------------------------
# Slovakia
# centrality = 1.6864083973206962e-05
#          centrality                        name     group   country  \
# 12884  2.406861e-06  Vozarova, Ivana Kravcakova  Fullname  Slovakia
# 12885  2.406861e-06          Kotulic, Rastislav  Fullname  Slovakia
# 12954  2.390304e-06               Vyrost, Tomas  Fullname  Slovakia
# 14539  1.718205e-06              Misecka, Tomas  Fullname  Slovakia
# 22676  5.539390e-07          Siebertova, Zuzana  Fullname  Slovakia
#
#                      organization
# 12884                 Univ Presov
# 12885                 Univ Presov
# 12954        Univ Econ Bratislava
# 14539             Slovak Univ Agr
# 22676  Council Budget Responsibil
# --------------------------------------------------
# Philippines
# centrality = 1.594306711663569e-05
#        centrality                       name     group      country  \
# 11817    0.000003                Balie, Jean  Fullname  Philippines
# 12276    0.000003  Biona, Jose Bienvenido M.  Fullname  Philippines
# 14126    0.000002             Park, Donghyun  Fullname  Philippines
# 16587    0.000001            Fillone, Alexis  Fullname  Philippines
# 16588    0.000001              Rith, Monorom  Fullname  Philippines
#
#             organization
# 11817  Int Rice Res Inst
# 12276   De La Salle Univ
# 14126     Asian Dev Bank
# 16587   De La Salle Univ
# 16588   De La Salle Univ
# --------------------------------------------------
# Egypt
# centrality = 1.5317628477349487e-05
#        centrality              name     group country     organization
# 10276    0.000005      Zaki, Chahir  Fullname   Egypt       Cairo Univ
# 12890    0.000002       Rizk, Reham  Fullname   Egypt     British Univ
# 13851    0.000002   Tooma, Eskandar  Fullname   Egypt  Amer Univ Cairo
# 13852    0.000002  Bassiouny, Aliaa  Fullname   Egypt  Amer Univ Cairo
# 17020    0.000001    Ramadan, Racha  Fullname   Egypt       Cairo Univ
# --------------------------------------------------
# Croatia
# centrality = 1.5202940437360171e-05
#          centrality              name     group  country       organization
# 14540  1.718038e-06      Coric, Bruno  Fullname  Croatia         Univ Split
# 16592  1.252217e-06  Brnjac, Nikolina  Fullname  Croatia        Univ Zagreb
# 19372  8.443243e-07    Tkalec, Marina  Fullname  Croatia          Inst Econ
# 19377  8.440576e-07     Vuksic, Goran  Fullname  Croatia  Inst Publ Finance
# 20577  6.901968e-07  Globan, Tomislav  Fullname  Croatia        Univ Zagreb
# --------------------------------------------------
# Uganda
# centrality = 1.439431687802471e-05
#        centrality               name     group country   organization
# 11797    0.000003     Buyana, Kareem  Fullname  Uganda  Makerere Univ
# 11798    0.000003      Lwasa, Shuaib  Fullname  Uganda  Makerere Univ
# 11799    0.000003   Sseviiri, Hakimu  Fullname  Uganda  Makerere Univ
# 11800    0.000003     Nsangi, Gloria  Fullname  Uganda  Makerere Univ
# 16717    0.000001  Alinda, Ronnie K.  Fullname  Uganda    Bank Uganda
# --------------------------------------------------
# Lebanon
# centrality = 1.437029834339027e-05
#        centrality              name     group  country  \
# 12065    0.000003        Fakih, Ali  Fullname  Lebanon
# 12452    0.000002       Bouri, Elie  Fullname  Lebanon
# 13029    0.000002  Arayssi, Mahmoud  Fullname  Lebanon
# 17502    0.000001  Ismail, Ahmad K.  Fullname  Lebanon
# 17503    0.000001     Daher, Mai M.  Fullname  Lebanon
#
#                        organization
# 12065            Lebanese Amer Univ
# 12452  Holy Spirit Univ Kaslik USEK
# 13029            Lebanese Amer Univ
# 17502              Amer Univ Beirut
# 17503              Amer Univ Beirut
# --------------------------------------------------
# Serbia
# centrality = 1.2647633629987693e-05
#        centrality                name     group country   organization
# 16590    0.000001      Tadic, Snezana  Fullname  Serbia  Univ Belgrade
# 16591    0.000001      Krstic, Mladen  Fullname  Serbia  Univ Belgrade
# 17720    0.000001     Maricic, Milica  Fullname  Serbia  Univ Belgrade
# 17721    0.000001    Glavic, Drazenko  Fullname  Serbia  Univ Belgrade
# 17722    0.000001  Milenkovic, Marina  Fullname  Serbia  Univ Belgrade
# --------------------------------------------------
# Kuwait
# centrality = 1.2393724104806324e-05
#        centrality                    name     group country  \
# 10339    0.000005     Kisswani, Khalid M.  Fullname  Kuwait
# 12141    0.000003          Harraf, Arezou  Fullname  Kuwait
# 12894    0.000002  Al-Jassar, Sulaiman A.  Fullname  Kuwait
# 16677    0.000001          Alnahedh, Saad  Fullname  Kuwait
# 17728    0.000001    Karaman, Abdullah S.  Fullname  Kuwait
#
#                   organization
# 10339  Gulf Univ Sci & Technol
# 12141            Box Hill Coll
# 12894              Kuwait Univ
# 16677              Kuwait Univ
# 17728    Amer Univ Middle East
# --------------------------------------------------
# Uruguay
# centrality = 1.2095595222200874e-05
#        centrality                     name     group  country  \
# 11822    0.000003         Vigorito, Andrea  Fullname  Uruguay
# 11823    0.000003          Bucheli, Marisa  Fullname  Uruguay
# 14289    0.000002        Gandelman, Nestor  Fullname  Uruguay
# 15910    0.000001  Pereyra, Juan Sebastian  Fullname  Uruguay
# 17481    0.000001    Muinelo-Gallo, Leonel  Fullname  Uruguay
#
#            organization
# 11822    Univ Republica
# 11823    Univ Republica
# 14289  Univ ORT Uruguay
# 15910    Univ Republica
# 17481    Univ Republica
# --------------------------------------------------
# Lithuania
# centrality = 1.196168724028714e-05
#          centrality                            name     group    country  \
# 12886  2.406653e-06                  Liepe, Zieduna  Fullname  Lithuania
# 15001  1.580903e-06               Balezentis, Tomas  Fullname  Lithuania
# 15772  1.424576e-06            Kazukauskas, Andrius  Fullname  Lithuania
# 22767  5.485237e-07  Zavadskas, Edmundas Kazimieras  Fullname  Lithuania
# 23556  5.048127e-07                Huettinger, Maik  Fullname  Lithuania
#
#                       organization
# 12886          Kaunas Univ Technol
# 15001                 Vilnius Univ
# 15772                 Vilnius Univ
# 22767  Vilnius Gediminas Tech Univ
# 23556   ISM Univ Management & Econ
# --------------------------------------------------
# Bangladesh
# centrality = 1.1012960658228436e-05
#          centrality                 name     group     country  \
# 11825  2.688207e-06      Hossain, Mahbub  Fullname  Bangladesh
# 12880  2.407029e-06    Basher, Syed Abul  Fullname  Bangladesh
# 12891  2.406354e-06      Robin, Iftekhar  Fullname  Bangladesh
# 21979  5.830138e-07  Azad, Md Abul Kalam  Fullname  Bangladesh
# 22696  5.533318e-07    Bakshi, Rejaul K.  Fullname  Bangladesh
#
#                organization
# 11825   Bangladesh Agr Univ
# 12880        East West Univ
# 12891  Cent Bank Bangladesh
# 21979  Islamic Univ Technol
# 22696         Univ Rajshahi
# --------------------------------------------------
# Nepal
# centrality = 9.66445438672756e-06
#        centrality                 name     group country  \
# 11828    0.000003     McDonald, Andrew  Fullname   Nepal
# 11838    0.000003          Karki, Emma  Fullname   Nepal
# 17201    0.000001    Manandhar, Dharma  Fullname   Nepal
# 17202    0.000001       Shrestha, Bhim  Fullname   Nepal
# 17203    0.000001  Yadav, Shyam Sundar  Fullname   Nepal
#
#                     organization
# 11828                       NARC
# 11838  Int Water Management Inst
# 17201      Mother Infant Res Act
# 17202      Mother Infant Res Act
# 17203      Mother Infant Res Act
# --------------------------------------------------
# Zimbabwe
# centrality = 8.924776264351774e-06
#          centrality                name     group   country  \
# 10111  5.380432e-06     Grundy, Isla M.  Fullname  Zimbabwe
# 12900  2.405285e-06  Bandara, Amarakoon  Fullname  Zimbabwe
# 17212  1.144924e-06  Mkodzongi, Grasian  Fullname  Zimbabwe
# 33138  7.568908e-08   Mazvimavi, Kizito  Fullname  Zimbabwe
#
#                                     organization
# 10111                              Univ Zimbabwe
# 12900                   United Nat Dev Programme
# 17212  Trop Africa Land & Nat Resources Res Inst
# 33138          Int Crops Res Inst Semi Arid Trop
# --------------------------------------------------
# Kazakhstan
# centrality = 8.270090551312253e-06
#          centrality                name     group     country  \
# ...
# 24775  4.383934e-07  Ghartey, Edward E.  Fullname  Jamaica
#
#                 organization
# 19312       Univ West Indies
# 23650  Univ West Indies Mona
# 24775       Univ West Indies
# --------------------------------------------------
# Bolivia
# centrality = 1.6342528217994844e-06
#          centrality              name     group  country  \
# 14979  1.591008e-06   Garron, Ignacio  Fullname  Bolivia
# 35028  2.170889e-08  Nogales, Ricardo  Fullname  Bolivia
# 35029  2.170889e-08   Cordova, Pamela  Fullname  Bolivia
# 37056  4.475079e-12   Urquidi, Manuel  Fullname  Bolivia
#
#                      organization
# 14979           Cent Bank Bolivia
# 35028      Univ Privada Boliviana
# 35029      Univ Privada Boliviana
# 37056  Banco Interamer Desarrollo
# --------------------------------------------------
# Bulgaria
# centrality = 1.6145412258761344e-06
#          centrality                   name     group   country  \
# 23574  5.037684e-07  Novossiolova, Tatyana  Fullname  Bulgaria
# 26109  3.530421e-07     Penchev, Pencho D.  Fullname  Bulgaria
# 30114  1.642626e-07        Petrova, Guenka  Fullname  Bulgaria
# 30121  1.640324e-07    Tachkov, Konstantin  Fullname  Bulgaria
# 30198  1.613780e-07       Neycheva, Mariya  Fullname  Bulgaria
#
#                  organization
# 23574     Ctr Study Democracy
# 26109  Univ Natl & World Econ
# 30114                Med Univ
# 30121          Med Univ Sofia
# 30198        Burgas Free Univ
# --------------------------------------------------
# Iceland
# centrality = 1.480899719917656e-06
#          centrality                            name     group  country  \
# 19424  8.355705e-07          Matthiasson, Thorolfur  Fullname  Iceland
# 24647  4.438311e-07  Sveinsson, Thorsteinn Sigurdur  Fullname  Iceland
# 30579  1.498222e-07             Egilsson, Jon Helgi  Fullname  Iceland
# 34217  3.808030e-08          Edvardsson, Ingi Runar  Fullname  Iceland
# 34218  3.808030e-08                Minelgaite, Inga  Fullname  Iceland
#
#             organization
# 19424       Univ Iceland
# 24647  Cent Bank Iceland
# 30579       Univ Iceland
# 34217       Univ Iceland
# 34218       Univ Iceland
# --------------------------------------------------
# Mongolia
# centrality = 1.4235886131713538e-06
#          centrality                      name     group   country  \
# 22223  5.715900e-07         Batmunkh, Khuslen  Fullname  Mongolia
# 22224  5.715900e-07   Luvsannyam, Davaajargal  Fullname  Mongolia
# 29865  1.725008e-07  Batchuluun, Altantsetseg  Fullname  Mongolia
# 32831  8.593473e-08          Bataa, Erdenebat  Fullname  Mongolia
# 33499  6.493785e-08         Doojav, Gan-Ochir  Fullname  Mongolia
#
#              organization
# 22223       Bank Mongolia
# 22224       Bank Mongolia
# 29865  Natl Univ Mongolia
# 32831  Natl Univ Mongolia
# 33499       Bank Mongolia
# --------------------------------------------------
# Malta
# centrality = 1.2818577177499196e-06
#          centrality                    name     group country organization
# 24771  4.385386e-07     Scicluna, Nicolanne  Fullname   Malta   Univ Malta
# 24772  4.385386e-07  Camilleri, Silvio John  Fullname   Malta   Univ Malta
# 24909  4.302204e-07        Briguglio, Marie  Fullname   Malta   Univ Malta
# --------------------------------------------------
# Azerbaijan
# centrality = 1.2124218954961777e-06
#          centrality                    name     group     country  \
# 22718  5.519508e-07         Hasanov, Rashad  Fullname  Azerbaijan
# 25183  4.118024e-07    Yesilirmak, Muharrem  Fullname  Azerbaijan
# 31900  1.080689e-07         Rahmanov, Ramiz  Fullname  Azerbaijan
# 32502  9.807858e-08  Nobari, Sabina Mirzaei  Fullname  Azerbaijan
# 34059  4.275840e-08           Abizada, Azar  Fullname  Azerbaijan
#
#                    organization
# 22718                  ADA Univ
# 25183                  ADA Univ
# 31900                 Cent Bank
# 32502  Azerbaijan Natl Acad Sci
# 34059                  ADA Univ
# --------------------------------------------------
# Niger
# centrality = 1.1438837772503064e-06
#        centrality               name     group country organization
# 17213    0.000001  Ouedraogo, Jerome  Fullname   Niger        UNECA
# --------------------------------------------------
# Armenia
# centrality = 1.1075288606697132e-06
#          centrality                name     group  country       organization
# 21903  5.859654e-07  Barseghyan, Gayane  Fullname  Armenia  Amer Univ Armenia
# 22831  5.430449e-07   Khachatryan, Knar  Fullname  Armenia  Amer Univ Armenia
# --------------------------------------------------
# Panama
# centrality = 7.944283084617845e-07
#          centrality                        name     group country  \
# 19783  7.924233e-07          Hall, Jefferson S.  Fullname  Panama
# 33471  6.603586e-08  de Sarralde, Santiago Diaz  Fullname  Panama
#
#                     organization
# 19783  Smithsonian Trop Res Inst
# 33471      Interamer Ctr Tax Adm
# --------------------------------------------------
# Costa Rica
# centrality = 6.206741807421912e-07
#          centrality                name     group     country  \
# 25241  4.075096e-07  Cardoza, Guillermo  Fullname  Costa Rica
# 28056  2.457205e-07    Hofmann, Claudia  Fullname  Costa Rica
#
#                        organization
# 25241  INCAE Business Sch La Garita
# 28056              Batalla Abogados
# --------------------------------------------------
# Venezuela
# centrality = 5.517805653395893e-07
#          centrality                 name     group    country  \
# 22719  5.518943e-07  Pagliacci, Carolina  Fullname  Venezuela
# 36999  1.826597e-11   Parravano, Antonio  Fullname  Venezuela
# 39196  2.685458e-20     Estrada, Ricardo  Fullname  Venezuela
#
#                   organization
# 22719      Cent Bank Venezuela
# 36999           Univ Los Andes
# 39196  CAF Dev Bank Latin Amer
# --------------------------------------------------
# Myanmar
# centrality = 5.322055394355431e-07
#          centrality         name     group  country            organization
# 23044  5.325853e-07  Phyo, Ei Ei  Fullname  Myanmar  Wisdom Garden Educ Ctr
# --------------------------------------------------
# Cambodia
# centrality = 5.107374794643098e-07
#          centrality            name     group   country  \
# 30865  1.417340e-07     Hui, Kelvin  Fullname  Cambodia
# 30866  1.417340e-07   Appelt, Bernd  Fullname  Cambodia
# 30867  1.417340e-07    Jacobs, Bart  Fullname  Cambodia
# 32555  9.659875e-08   Sann, Vathana  Fullname  Cambodia
# 36568  1.459272e-10  Lo, Veasnakiry  Fullname  Cambodia
#
#                                 organization
# 30865  Deutsch Gesell Int Zusammenarbeit GIZ
# 30866  Deutsch Gesell Int Zusammenarbeit GIZ
# 30867  Deutsch Gesell Int Zusammenarbeit GIZ
# 32555                Council Agr & Rural Dev
# 36568                            Minist Hlth
# --------------------------------------------------
# Montenegro
# centrality = 4.550525497365238e-07
#          centrality                name     group     country  \
# 34226  3.788919e-08   Jovovic, Radislav  Fullname  Montenegro
# 34228  3.788311e-08    Jovovic, Milorad  Fullname  Montenegro
# 34229  3.788311e-08    Radonjic, Milena  Fullname  Montenegro
# 34230  3.788311e-08   Radovic, Milivoje  Fullname  Montenegro
# 34231  3.788311e-08  Djuraskovic, Jovan  Fullname  Montenegro
#
#                  organization
# 34226      Mediterranean Univ
# 34228  Univ Montenegro Jovana
# 34229  Univ Montenegro Jovana
# 34230  Univ Montenegro Jovana
# 34231  Univ Montenegro Jovana
# --------------------------------------------------
# Kosovo
# centrality = 4.317534847428405e-07
#          centrality                 name     group country  \
# 29851  1.727285e-07        Mulliqi, Arta  Fullname  Kosovo
# 31902  1.080387e-07     Krasniqi, Besnik  Fullname  Kosovo
# 31903  1.080387e-07         Aliu, Fisnik  Fullname  Kosovo
# 34035  4.317067e-08  Krasniqi, Besnik A.  Fullname  Kosovo
# 36985  2.048656e-11        Sahiti, Fadil  Fullname  Kosovo
#
#                  organization
# 29851                UBT Coll
# 31902          Univ Prishtina
# 31903          Univ Prishtina
# 34035          Univ Prishtina
# 36985  Rochester Inst Technol
# --------------------------------------------------
# North Korea
# centrality = 3.8652474992603287e-07
#          centrality            name     group      country      organization
# 32549  9.667104e-08   Kim, Gang-Sok  Fullname  North Korea  Kim II Sung Univ
# 32550  9.667104e-08  Hwang, Sun-Hui  Fullname  North Korea  Kim II Sung Univ
# 32551  9.667104e-08      Ko, Un-Dok  Fullname  North Korea  Kim II Sung Univ
# 32552  9.667104e-08  Rim, Gwang-Nam  Fullname  North Korea  Kim II Sung Univ
# --------------------------------------------------
# Cuba
# centrality = 3.325669413388195e-07
#          centrality               name     group country    organization
# 26473  3.326942e-07  Echevarria, Dayma  Fullname    Cuba  Univ La Habana
# --------------------------------------------------
# Benin
# centrality = 2.989023166459383e-07
#          centrality                  name     group country  organization
# 27046  2.990259e-07  Lokonon, Boris O. K.  Fullname   Benin  Univ Parakou
# --------------------------------------------------
# Togo
# centrality = 2.9890231664489965e-07
#          centrality                      name     group country organization
# 27047  2.990259e-07  Egbendewe, Aklesso Y. G.  Fullname    Togo    Univ Lome
# --------------------------------------------------
# Papua N Guinea
# centrality = 2.0652066536537375e-07
#          centrality                      name     group         country  \
# 30876  1.416003e-07  Hombhanje, Francis Wanak  Fullname  Papua N Guinea
# 33497  6.501646e-08              Sofe, Ronald  Fullname  Papua N Guinea
#
#                          organization
# 30876                Divine Word Univ
# 33497  Papua New Guinea Natl Res Inst
# --------------------------------------------------
# Sierra Leone
# centrality = 1.9269624092292836e-07
#          centrality                  name     group       country organization
# 29271  1.927654e-07  Diallo, Fatoumata L.  Fullname  Sierra Leone         WAMA
# --------------------------------------------------
# Senegal
# centrality = 1.926962409215882e-07
#          centrality               name     group  country  \
# 29272  1.927654e-07  Diagne, Abdoulaye  Fullname  Senegal
# 35015  2.183689e-08      Marivoet, Wim  Fullname  Senegal
#
#                 organization
# 29272  Univ Cheikh Anta Diop
# 35015                  IFPRI
# --------------------------------------------------
# Bahrain
# centrality = 1.7281326556598597e-07
#          centrality           name     group  country             organization
# 32506  9.798134e-08    Aktan, Bora  Fullname  Bahrain             Univ Bahrain
# 33161  7.495240e-08  Alaabed, Alaa  Fullname  Bahrain  Islamic Int Rating Agcy
# --------------------------------------------------
# Rep of Georgia
# centrality = 1.6121155106861545e-07
#          centrality              name     group         country  \
# 30202  1.612454e-07  Torosyan, Karine  Fullname  Rep of Georgia
#
#                      organization
# 30202  Tbilisi State Univ Tbilisi
# --------------------------------------------------
# Burundi
# centrality = 1.414842249376733e-07
#          centrality                   name     group  country  organization
# 29014  2.049270e-07  Ndikubagenzi, Jacques  Fullname  Burundi  Univ Burundi
# --------------------------------------------------
# Moldova
# centrality = 9.791146664584652e-08
#          centrality               name     group  country  \
# 32507  9.796502e-08  Mihaila, Svetlana  Fullname  Moldova
#
#                     organization
# 32507  Acad Econ Studies Moldova
# --------------------------------------------------
# Albania
# centrality = 8.633670353868072e-08
#          centrality               name     group  country  \
# 34041  4.315524e-08       Lami, Endrit  Fullname  Albania
# 35038  2.163260e-08  Kapidani, Mariola  Fullname  Albania
# 35039  2.163260e-08       Luci, Edlira  Fullname  Albania
#
#                 organization
# 34041  Minist Finance & Econ
# 35038            Univ Tirana
# 35039            Univ Tirana
# --------------------------------------------------
# Laos
# centrality = 2.21107876844418e-08
#          centrality                    name     group country  \
# 34927  2.300399e-08  Kyophilavong, Phouphet  Fullname    Laos
# 36375  2.769832e-10       Suhardiman, Diana  Fullname    Laos
#
#                     organization
# 34927             Natl Univ Laos
# 36375  Int Water Management Inst
# --------------------------------------------------
# DEM REP CONGO
# centrality = 1.1144341727858348e-08
#          centrality                      name     group        country  \
# 35469  1.115477e-08  Dosa, Pacifique Mongongo  Fullname  DEM REP CONGO
#
#                  organization
# 35469  Univ Nouveaux Horizons
# --------------------------------------------------
# Iraq
# centrality = 9.102113109189967e-10
#          centrality            name     group country organization
# 36112  9.121532e-10  Taleb, Mushtaq  Fullname    Iraq   Univ Anbar
# --------------------------------------------------
# Dominican Rep
# centrality = 6.970965576682598e-10
#          centrality                        name     group        country  \
# 36149  7.281959e-10  Gomez-Luciano, Cristino A.  Fullname  Dominican Rep
#
#                                    organization
# 36149  Inst Especializado Estudios Super Loyola
# --------------------------------------------------
# Lesotho
# centrality = 2.3178730979265256e-18
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# New Caledonia
# centrality = 1.3728062043332248e-18
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# Botswana
# centrality = 8.175906135266929e-19
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# Georgia
# centrality = 7.427723710546892e-19
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# Timor-Leste
# centrality = 7.2366041364536055e-19
#          centrality                  name     group      country organization
# 38802  2.247209e-19  Martins, Pedro M. G.  Fullname  Timor-Leste   World Bank
# --------------------------------------------------
# San Marino
# centrality = 6.1403005155647165e-19
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# Algeria
# centrality = 3.5116970264687984e-19
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# BELARUS
# centrality = 3.2057929082590607e-19
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# Surinam
# centrality = 8.911713694947943e-20
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# Malawi
# centrality = 7.422330821590851e-20
#          centrality               name     group country organization
# 36088  1.110398e-09    Alene, Arega D.  Fullname  Malawi         IITA
# 36089  1.110398e-09      Manda, Julius  Fullname  Malawi         IITA
# 36190  5.552278e-10  Tufa, Adane Hirpa  Fullname  Malawi         IITA
# 36191  5.552278e-10    Akinwale, M. G.  Fullname  Malawi         IITA
# 36195  5.551706e-10     Tufa, Adane H.  Fullname  Malawi         IITA
# --------------------------------------------------
# North Macedonia
# centrality = 1.8489696367392713e-20
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# South Sudan
# centrality = 1.51337289816008e-20
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------

# %% [markdown]
# ### author ranking by organization

# %%
topk = 50
orgs = df[df['group'] == 'FullOrgName']['name'].tolist()[:topk]
for org in orgs:
    print(org)
    print('centrality = ', df[df['name'] == org]['centrality'].iloc[0], sep='')
    authors = df[(df['organization'] == org) & (df['group'] == 'Fullname')]
    print(authors.sort_values(by='centrality', ascending=False).head())
    print('-'*50)
# Out:
# NBER
# centrality = 0.050982293218899535
#      centrality              name     group country organization
# 609    0.000434     Currie, Janet  Fullname     USA         NBER
# 610    0.000433    Neumark, David  Fullname     USA         NBER
# 733    0.000328   Bernstein, Shai  Fullname     USA         NBER
# 734    0.000327        He, Zhiguo  Fullname     USA         NBER
# 735    0.000326  Morales, Eduardo  Fullname     USA         NBER
# --------------------------------------------------
# World Bank
# centrality = 0.021066145513592455
#      centrality              name     group country organization
# 613    0.000424  Deininger, Klaus  Fullname     USA   World Bank
# 614    0.000422   McKenzie, David  Fullname     USA   World Bank
# 740    0.000316       Islam, Asif  Fullname     USA   World Bank
# 744    0.000316     Molini, Vasco  Fullname     USA   World Bank
# 745    0.000316   Mattoo, Aaditya  Fullname     USA   World Bank
# --------------------------------------------------
# Int Monetary Fund
# centrality = 0.016819195526965054
#      centrality                        name     group country  \
# 629    0.000418                Berg, Andrew  Fullname     USA
# 742    0.000316       Presbitero, Andrea F.  Fullname     USA
# 760    0.000315  Tapsoba, Sampawende J. -A.  Fullname     USA
# 781    0.000313            Portillo, Rafael  Fullname     USA
# 788    0.000313              Adler, Gustavo  Fullname     USA
#
#           organization
# 629  Int Monetary Fund
# 742  Int Monetary Fund
# 760  Int Monetary Fund
# 781  Int Monetary Fund
# 788  Int Monetary Fund
# --------------------------------------------------
# Stanford Univ
# centrality = 0.016457248924507447
#      centrality                 name     group country   organization
# 621    0.000419      Wolak, Frank A.  Fullname     USA  Stanford Univ
# 631    0.000417       Rozelle, Scott  Fullname     USA  Stanford Univ
# 748    0.000316    Fafchamps, Marcel  Fullname     USA  Stanford Univ
# 753    0.000315  Lambert, Nicolas S.  Fullname     USA  Stanford Univ
# 759    0.000315  Jackson, Matthew O.  Fullname     USA  Stanford Univ
# --------------------------------------------------
# Univ Illinois
# centrality = 0.012755418408013041
#      centrality                       name     group country   organization
# 472    0.000728    Hewings, Geoffrey J. D.  Fullname     USA  Univ Illinois
# 635    0.000417  Nansen McCloskey, Deirdre  Fullname     USA  Univ Illinois
# 746    0.000316            Michelson, Hope  Fullname     USA  Univ Illinois
# 751    0.000315              Baylis, Kathy  Fullname     USA  Univ Illinois
# 755    0.000315      Arends-Kuenning, Mary  Fullname     USA  Univ Illinois
# --------------------------------------------------
# Univ Wisconsin
# centrality = 0.012529639936475451
#      centrality                     name     group country    organization
# 319    0.001461  Bahmani-Oskooee, Mohsen  Fullname     USA  Univ Wisconsin
# 554    0.000523       Fletcher, Jason M.  Fullname     USA  Univ Wisconsin
# 750    0.000315      Collins, J. Michael  Fullname     USA  Univ Wisconsin
# 761    0.000315             Shim, Soyeon  Fullname     USA  Univ Wisconsin
# 795    0.000313          Wright, Randall  Fullname     USA  Univ Wisconsin
# --------------------------------------------------
# Harvard Univ
# centrality = 0.012523809368221395
#       centrality                  name     group country  organization
# 619     0.000419         Li, Jianglong  Fullname     USA  Harvard Univ
# 741     0.000316      Shleifer, Andrei  Fullname     USA  Harvard Univ
# 756     0.000315      Kasy, Maximilian  Fullname     USA  Harvard Univ
# 798     0.000313  Kominers, Scott Duke  Fullname     USA  Harvard Univ
# 1159    0.000210      Brookins, Philip  Fullname     USA  Harvard Univ
# --------------------------------------------------
# MIT
# centrality = 0.012428751800003326
#      centrality                name     group country organization
# 639    0.000416         Zheng, Siqi  Fullname     USA          MIT
# 749    0.000315       Werning, Ivan  Fullname     USA          MIT
# 768    0.000314  Olken, Benjamin A.  Fullname     USA          MIT
# 774    0.000314     Fudenberg, Drew  Fullname     USA          MIT
# 776    0.000314     Acemoglu, Daron  Fullname     USA          MIT
# --------------------------------------------------
# Univ Chicago
# centrality = 0.011996971877048087
#       centrality                  name     group country  organization
# 769     0.000314        Czibor, Eszter  Fullname     USA  Univ Chicago
# 1116    0.000211       Ponti, Giovanni  Fullname     USA  Univ Chicago
# 1120    0.000211     Cong, Lin William  Fullname     USA  Univ Chicago
# 1135    0.000210  Colonnelli, Emanuele  Fullname     USA  Univ Chicago
# 1145    0.000210            Ma, Yueran  Fullname     USA  Univ Chicago
# --------------------------------------------------
# Univ Calif Berkeley
# centrality = 0.011900675472359951
#       centrality                   name     group country         organization
# 620     0.000419        Davis, Lucas W.  Fullname     USA  Univ Calif Berkeley
# 747     0.000316  Villas-Boas, Sofia B.  Fullname     USA  Univ Calif Berkeley
# 766     0.000314         Saez, Emmanuel  Fullname     USA  Univ Calif Berkeley
# 833     0.000312       Katz, Michael L.  Fullname     USA  Univ Calif Berkeley
# 1121    0.000211           Berck, Peter  Fullname     USA  Univ Calif Berkeley
# --------------------------------------------------
# Univ Michigan
# centrality = 0.010525843140830856
#       centrality                name     group country   organization
# 806     0.000312           Chen, Yan  Fullname     USA  Univ Michigan
# 1119    0.000211  Hausman, Joshua K.  Fullname     USA  Univ Michigan
# 1146    0.000210   Szymanski, Stefan  Fullname     USA  Univ Michigan
# 1191    0.000210       Raimi, Daniel  Fullname     USA  Univ Michigan
# 1349    0.000208        Fort, Rodney  Fullname     USA  Univ Michigan
# --------------------------------------------------
# Univ Penn
# centrality = 0.01021310319085808
#       centrality                 name     group country organization
# 782     0.000313  Dillenberger, David  Fullname     USA    Univ Penn
# 791     0.000313  Doraszelski, Ulrich  Fullname     USA    Univ Penn
# 1122    0.000211         Levit, Doron  Fullname     USA    Univ Penn
# 1143    0.000210   Bohren, J. Aislinn  Fullname     USA    Univ Penn
# 1177    0.000210    Opp, Christian C.  Fullname     USA    Univ Penn
# --------------------------------------------------
# Duke Univ
# centrality = 0.010107510764490112
#      centrality                      name     group country organization
# 517    0.000624        Munger, Michael C.  Fullname     USA    Duke Univ
# 616    0.000421  Pattanayak, Subhrendu K.  Fullname     USA    Duke Univ
# 642    0.000416           Marx, Leslie M.  Fullname     USA    Duke Univ
# 800    0.000313            Sexton, Steven  Fullname     USA    Duke Univ
# 847    0.000311                Li, Yating  Fullname     USA    Duke Univ
# --------------------------------------------------
# Ohio State Univ
# centrality = 0.01000409940551002
#      centrality                name     group country     organization
# 561    0.000522   Klaiber, H. Allen  Fullname     USA  Ohio State Univ
# 625    0.000418   Hanna, Sherman D.  Fullname     USA  Ohio State Univ
# 765    0.000314          Hou, Kewei  Fullname     USA  Ohio State Univ
# 767    0.000314  Conejo, Antonio J.  Fullname     USA  Ohio State Univ
# 801    0.000313      Yang, Huanxing  Fullname     USA  Ohio State Univ
# --------------------------------------------------
# Cornell Univ
# centrality = 0.008958942625127123
#       centrality                  name     group country  organization
# 519     0.000623          Kanbur, Ravi  Fullname     USA  Cornell Univ
# 841     0.000312  Ziebarth, Nicolas R.  Fullname     USA  Cornell Univ
# 1127    0.000211          Basu, Soumya  Fullname     USA  Cornell Univ
# 1128    0.000211         Easley, David  Fullname     USA  Cornell Univ
# 1171    0.000210         Huang, Darien  Fullname     USA  Cornell Univ
# --------------------------------------------------
# NYU
# centrality = 0.008844668125620053
#       centrality                     name     group country organization
# 560     0.000522             Cabral, Luis  Fullname     USA          NYU
# 1228    0.000209           Glimcher, Paul  Fullname     USA          NYU
# 1254    0.000209  Frechette, Guillaume R.  Fullname     USA          NYU
# 1257    0.000209         Kuchler, Theresa  Fullname     USA          NYU
# 1439    0.000208         Galichon, Alfred  Fullname     USA          NYU
# --------------------------------------------------
# Arizona State Univ
# centrality = 0.008839418436165343
#       centrality               name     group country        organization
# 754     0.000315  Aragon, George O.  Fullname     USA  Arizona State Univ
# 785     0.000313   Mueller, Valerie  Fullname     USA  Arizona State Univ
# 857     0.000311  Abbott, Joshua K.  Fullname     USA  Arizona State Univ
# 875     0.000311    Brada, Josef C.  Fullname     USA  Arizona State Univ
# 1170    0.000210        Liao, Chuan  Fullname     USA  Arizona State Univ
# --------------------------------------------------
# Univ N Carolina
# centrality = 0.008836225275424103
#       centrality                     name     group country     organization
# 564     0.000520          Link, Albert N.  Fullname     USA  Univ N Carolina
# 1105    0.000212              Gray, Clark  Fullname     USA  Univ N Carolina
# 1259    0.000209     van Hasselt, Martijn  Fullname     USA  Univ N Carolina
# 1312    0.000209                  Li, Fei  Fullname     USA  Univ N Carolina
# 1316    0.000208  Fruehwirth, Jane Cooley  Fullname     USA  Univ N Carolina
# --------------------------------------------------
# CEPR
# centrality = 0.008342563978650724
#       centrality               name     group country organization
# 1220    0.000209  Dasgupta, Sudipto  Fullname     USA         CEPR
# 1411    0.000208      Surico, Paolo  Fullname     USA         CEPR
# 1451    0.000208   Barnichon, Regis  Fullname     USA         CEPR
# 2750    0.000105    Pagel, Michaela  Fullname     USA         CEPR
# 2792    0.000105       Kung, Howard  Fullname     USA         CEPR
# --------------------------------------------------
# Natl Bur Econ Res
# centrality = 0.008215711989586356
#       centrality                name     group country       organization
# 780     0.000313   Ben-David, Itzhak  Fullname     USA  Natl Bur Econ Res
# 1233    0.000209     Bushnell, James  Fullname     USA  Natl Bur Econ Res
# 1341    0.000208   Pizer, William A.  Fullname     USA  Natl Bur Econ Res
# 1375    0.000208      Yogo, Motohiro  Fullname     USA  Natl Bur Econ Res
# 1495    0.000208  Newell, Richard G.  Fullname     USA  Natl Bur Econ Res
# --------------------------------------------------
# Purdue Univ
# centrality = 0.007702256896655348
#      centrality                 name     group country organization
# 555    0.000523    Cason, Timothy N.  Fullname     USA  Purdue Univ
# 622    0.000419      Lusk, Jayson L.  Fullname     USA  Purdue Univ
# 787    0.000313  Delgado, Michael S.  Fullname     USA  Purdue Univ
# 835    0.000312    Bauchet, Jonathan  Fullname     USA  Purdue Univ
# 883    0.000310      Martin, Stephen  Fullname     USA  Purdue Univ
# --------------------------------------------------
# Univ Texas Austin
# centrality = 0.007588939640548182
#       centrality                name     group country       organization
# 811     0.000312         Bhaskar, V.  Fullname     USA  Univ Texas Austin
# 1197    0.000209   Xiaolan, Mindy Z.  Fullname     USA  Univ Texas Austin
# 1356    0.000208    Thomas, Caroline  Fullname     USA  Univ Texas Austin
# 1576    0.000207  Traphagan, John W.  Fullname     USA  Univ Texas Austin
# 1583    0.000207         Han, Sukjin  Fullname     USA  Univ Texas Austin
# --------------------------------------------------
# Northwestern Univ
# centrality = 0.007366889239610484
#       centrality                 name     group country       organization
# 825     0.000312  Jayachandran, Seema  Fullname     USA  Northwestern Univ
# 878     0.000310      Powell, Michael  Fullname     USA  Northwestern Univ
# 1333    0.000208       Besanko, David  Fullname     USA  Northwestern Univ
# 1353    0.000208     Doepke, Matthias  Fullname     USA  Northwestern Univ
# 1464    0.000208    Deserranno, Erika  Fullname     USA  Northwestern Univ
# --------------------------------------------------
# Univ Southern Calif
# centrality = 0.007174711820424792
#       centrality                name     group country         organization
# 466     0.000733         Samek, Anya  Fullname     USA  Univ Southern Calif
# 815     0.000312    Angrisani, Marco  Fullname     USA  Univ Southern Calif
# 837     0.000312          Tan, Guofu  Fullname     USA  Univ Southern Calif
# 1232    0.000209  Zapatero, Fernando  Fullname     USA  Univ Southern Calif
# 1555    0.000207   Imrohoroglu, Ayse  Fullname     USA  Univ Southern Calif
# --------------------------------------------------
# Indiana Univ
# centrality = 0.007072238081288305
#       centrality                   name     group country  organization
# 618     0.000420       Walker, James M.  Fullname     USA  Indiana Univ
# 643     0.000416       Torrens, Gustavo  Fullname     USA  Indiana Univ
# 775     0.000314          Carley, Sanya  Fullname     USA  Indiana Univ
# 820     0.000312  Zirogiannis, Nikolaos  Fullname     USA  Indiana Univ
# 1108    0.000211     MacLean, Lauren M.  Fullname     USA  Indiana Univ
# --------------------------------------------------
# Penn State Univ
# centrality = 0.007064697893844386
#       centrality                     name     group country     organization
# 858     0.000311         Brent, Daniel A.  Fullname     USA  Penn State Univ
# 879     0.000310        Goetz, Stephan J.  Fullname     USA  Penn State Univ
# 1160    0.000210        Jiraporn, Pornsit  Fullname     USA  Penn State Univ
# 1185    0.000210       Lenkey, Stephen L.  Fullname     USA  Penn State Univ
# 1203    0.000209  Aradillas-Lopez, Andres  Fullname     USA  Penn State Univ
# --------------------------------------------------
# Columbia Univ
# centrality = 0.0070468924720200905
#       centrality              name     group country   organization
# 1217    0.000209     Che, Yeon-Koo  Fullname     USA  Columbia Univ
# 1298    0.000209          Gao, Qin  Fullname     USA  Columbia Univ
# 1306    0.000209     Kartik, Navin  Fullname     USA  Columbia Univ
# 1339    0.000208  Glasserman, Paul  Fullname     USA  Columbia Univ
# 1547    0.000207     Yared, Pierre  Fullname     USA  Columbia Univ
# --------------------------------------------------
# Michigan State Univ
# centrality = 0.006962200087818824
#      centrality            name     group country         organization
# 575    0.000518  Minetti, Raoul  Fullname     USA  Michigan State Univ
# 667    0.000414   Choi, Jay Pil  Fullname     USA  Michigan State Univ
# 762    0.000315  George, Justin  Fullname     USA  Michigan State Univ
# 813    0.000312  Skidmore, Mark  Fullname     USA  Michigan State Univ
# 911    0.000310  Wineman, Ayala  Fullname     USA  Michigan State Univ
# --------------------------------------------------
# Univ Maryland
# centrality = 0.006851268611455764
#       centrality              name     group country   organization
# 844     0.000311    Uler, Neslihan  Fullname     USA  Univ Maryland
# 845     0.000311    Alberini, Anna  Fullname     USA  Univ Maryland
# 1166    0.000210  Fresard, Laurent  Fullname     USA  Univ Maryland
# 1328    0.000208    Younes, Hannah  Fullname     USA  Univ Maryland
# 1345    0.000208      Qiu, Yueming  Fullname     USA  Univ Maryland
# --------------------------------------------------
# Georgetown Univ
# centrality = 0.006649748516767789
#      centrality                 name     group country     organization
# 626    0.000418        Desai, Raj M.  Fullname     USA  Georgetown Univ
# 632    0.000417       Sansone, Dario  Fullname     USA  Georgetown Univ
# 777    0.000314            Wen, Quan  Fullname     USA  Georgetown Univ
# 860    0.000311    Mayda, Anna Maria  Fullname     USA  Georgetown Univ
# 900    0.000310  Mukoyama, Toshihiko  Fullname     USA  Georgetown Univ
# --------------------------------------------------
# Univ Calif Los Angeles
# centrality = 0.006637747692094194
#       centrality                     name     group country  \
# 909     0.000310          Rigby, David L.  Fullname     USA
# 1218    0.000209   Hartman-Glaser, Barney  Fullname     USA
# 1414    0.000208  Subrahmanyam, Avanidhar  Fullname     USA
# 1717    0.000207      Weisburst, Emily K.  Fullname     USA
# 1756    0.000207              Golan, Roni  Fullname     USA
#
#                 organization
# 909   Univ Calif Los Angeles
# 1218  Univ Calif Los Angeles
# 1414  Univ Calif Los Angeles
# 1717  Univ Calif Los Angeles
# 1756  Univ Calif Los Angeles
# --------------------------------------------------
# Texas A&M Univ
# centrality = 0.006547960023843232
#       centrality              name     group country    organization
# 743     0.000316   Palma, Marco A.  Fullname     USA  Texas A&M Univ
# 772     0.000314  Eckel, Catherine  Fullname     USA  Texas A&M Univ
# 824     0.000312    Luco, Fernando  Fullname     USA  Texas A&M Univ
# 862     0.000311    Tian, Guoqiang  Fullname     USA  Texas A&M Univ
# 1172    0.000210      Rossi, Marco  Fullname     USA  Texas A&M Univ
# --------------------------------------------------
# Univ Georgia
# centrality = 0.006442276475804997
#       centrality                name     group country  organization
# 655     0.000414   Caetano, Gregorio  Fullname     USA  Univ Georgia
# 799     0.000313     Cude, Brenda J.  Fullname     USA  Univ Georgia
# 819     0.000312   Chatterjee, Swarn  Fullname     USA  Univ Georgia
# 885     0.000310  Bradford, W. David  Fullname     USA  Univ Georgia
# 1575    0.000207   Munneke, Henry J.  Fullname     USA  Univ Georgia
# --------------------------------------------------
# Fed Reserve Board
# centrality = 0.0063323153901365
#       centrality                name     group country       organization
# 669     0.000414     Nakata, Taisuke  Fullname     USA  Fed Reserve Board
# 1657    0.000207  Bodenstein, Martin  Fullname     USA  Fed Reserve Board
# 1663    0.000207     Guerrieri, Luca  Fullname     USA  Fed Reserve Board
# 1664    0.000207  Iacoviello, Matteo  Fullname     USA  Fed Reserve Board
# 1675    0.000207      Caldara, Dario  Fullname     USA  Fed Reserve Board
# --------------------------------------------------
# Univ Florida
# centrality = 0.0061338359923102
#       centrality                name     group country  organization
# 633     0.000417           Zhai, Wei  Fullname     USA  Univ Florida
# 810     0.000312       Wang, Baolian  Fullname     USA  Univ Florida
# 1129    0.000211      Kassas, Bachir  Fullname     USA  Univ Florida
# 1261    0.000209   Khachatryan, Hayk  Fullname     USA  Univ Florida
# 1266    0.000209  Morgan, Stephen N.  Fullname     USA  Univ Florida
# --------------------------------------------------
# Univ Colorado
# centrality = 0.006125154063762233
#       centrality                name     group country   organization
# 887     0.000310     Argys, Laura M.  Fullname     USA  Univ Colorado
# 1291    0.000209      McNown, Robert  Fullname     USA  Univ Colorado
# 1357    0.000208  Kaffine, Daniel T.  Fullname     USA  Univ Colorado
# 1764    0.000207   Carter, R. McKell  Fullname     USA  Univ Colorado
# 1846    0.000206        Luck, Philip  Fullname     USA  Univ Colorado
# --------------------------------------------------
# George Mason Univ
# centrality = 0.006009099341598028
#       centrality                    name     group country       organization
# 617     0.000420          Houser, Daniel  Fullname     USA  George Mason Univ
# 830     0.000312  McLaughlin, Patrick A.  Fullname     USA  George Mason Univ
# 848     0.000311        Mungan, Murat C.  Fullname     USA  George Mason Univ
# 912     0.000310  Hallett, Andrew Hughes  Fullname     USA  George Mason Univ
# 1423    0.000208          Stanley, Laura  Fullname     USA  George Mason Univ
# --------------------------------------------------
# Georgia State Univ
# centrality = 0.005702563952758163
#       centrality                name     group country        organization
# 849     0.000311      Chong, Alberto  Fullname     USA  Georgia State Univ
# 870     0.000311   Pesko, Michael F.  Fullname     USA  Georgia State Univ
# 1234    0.000209           Shi, Zhen  Fullname     USA  Georgia State Univ
# 1267    0.000209      Agarwal, Vikas  Fullname     USA  Georgia State Univ
# 1388    0.000208  Harrison, Glenn W.  Fullname     USA  Georgia State Univ
# --------------------------------------------------
# Univ Massachusetts
# centrality = 0.005482443565354656
#       centrality                       name     group country  \
# 834     0.000312         Stranlund, John K.  Fullname     USA
# 942     0.000309           Yoshihara, Naoki  Fullname     USA
# 1258    0.000209  de Oliveira, Angela C. M.  Fullname     USA
# 1304    0.000209            Chan, Nathan W.  Fullname     USA
# 1313    0.000209         Badgett, M. V. Lee  Fullname     USA
#
#             organization
# 834   Univ Massachusetts
# 942   Univ Massachusetts
# 1258  Univ Massachusetts
# 1304  Univ Massachusetts
# 1313  Univ Massachusetts
# --------------------------------------------------
# Univ Minnesota
# centrality = 0.005402430318961444
#       centrality                 name     group country    organization
# 809     0.000312        Serido, Joyce  Fullname     USA  Univ Minnesota
# 976     0.000309    Parisi, Francesco  Fullname     USA  Univ Minnesota
# 1214    0.000209     Rustichini, Aldo  Fullname     USA  Univ Minnesota
# 1314    0.000209       Winton, Andrew  Fullname     USA  Univ Minnesota
# 1512    0.000208  Herkenhoff, Kyle F.  Fullname     USA  Univ Minnesota
# --------------------------------------------------
# Univ Arizona
# centrality = 0.005396308357251061
#       centrality                  name     group country  organization
# 553     0.000524    Dufwenberg, Martin  Fullname     USA  Univ Arizona
# 863     0.000311  Noussair, Charles N.  Fullname     USA  Univ Arizona
# 1118    0.000211    Baldwin, Elizabeth  Fullname     USA  Univ Arizona
# 1299    0.000209       Rapoport, Amnon  Fullname     USA  Univ Arizona
# 1705    0.000207    Galvao, Antonio F.  Fullname     USA  Univ Arizona
# --------------------------------------------------
# Princeton Univ
# centrality = 0.005391316092431833
#       centrality              name     group country    organization
# 681     0.000413   Fleurbaey, Marc  Fullname     USA  Princeton Univ
# 1152    0.000210   Morris, Stephen  Fullname     USA  Princeton Univ
# 1154    0.000210  Ortoleva, Pietro  Fullname     USA  Princeton Univ
# 1193    0.000210    Matray, Adrien  Fullname     USA  Princeton Univ
# 1631    0.000207    Langan, Andrew  Fullname     USA  Princeton Univ
# --------------------------------------------------
# Univ Calif Davis
# centrality = 0.005176274589279422
#       centrality                 name     group country      organization
# 859     0.000311       Woo, Wing Thye  Fullname     USA  Univ Calif Davis
# 932     0.000309     Carter, Colin A.  Fullname     USA  Univ Calif Davis
# 1931    0.000206         Smith, Aaron  Fullname     USA  Univ Calif Davis
# 1972    0.000206  Swenson, Deborah L.  Fullname     USA  Univ Calif Davis
# 2740    0.000105     Rudnick, Jessica  Fullname     USA  Univ Calif Davis
# --------------------------------------------------
# Washington Univ
# centrality = 0.005088199248602959
#       centrality                     name     group country     organization
# 1288    0.000209         Roll, Stephen P.  Fullname     USA  Washington Univ
# 1347    0.000208       Sherraden, Michael  Fullname     USA  Washington Univ
# 1373    0.000208  Grinstein-Weiss, Michal  Fullname     USA  Washington Univ
# 1374    0.000208         Gottlieb, Daniel  Fullname     USA  Washington Univ
# 1772    0.000207         Sanchez, Juan M.  Fullname     USA  Washington Univ
# --------------------------------------------------
# Yale Univ
# centrality = 0.005069204680551051
#       centrality                   name     group country organization
# 673     0.000414       Samuelson, Larry  Fullname     USA    Yale Univ
# 1164    0.000210      Nordhaus, William  Fullname     USA    Yale Univ
# 1428    0.000208        Bergemann, Dirk  Fullname     USA    Yale Univ
# 1711    0.000207  Andrews, Donald W. K.  Fullname     USA    Yale Univ
# 1880    0.000206           Fair, Ray C.  Fullname     USA    Yale Univ
# --------------------------------------------------
# Univ Virginia
# centrality = 0.00506622914496525
#       centrality            name     group country   organization
# 867     0.000311  Young, Eric R.  Fullname     USA  Univ Virginia
# 1442    0.000208   Chalak, Karim  Fullname     USA  Univ Virginia
# 1614    0.000207   Troyan, Peter  Fullname     USA  Univ Virginia
# 1665    0.000207  Murphy, Daniel  Fullname     USA  Univ Virginia
# 1721    0.000207  Bassok, Daphna  Fullname     USA  Univ Virginia
# --------------------------------------------------
# Int Food Policy Res Inst
# centrality = 0.005000125484392188
#       centrality                name     group country  \
# 805     0.000312      Kosec, Katrina  Fullname     USA
# 1115    0.000211    Heckert, Jessica  Fullname     USA
# 1195    0.000209         Kumar, Neha  Fullname     USA
# 1311    0.000209      Malapit, Hazel  Fullname     USA
# 2629    0.000106  Martinez, Elena M.  Fullname     USA
#
#                   organization
# 805   Int Food Policy Res Inst
# 1115  Int Food Policy Res Inst
# 1195  Int Food Policy Res Inst
# 1311  Int Food Policy Res Inst
# 2629  Int Food Policy Res Inst
# --------------------------------------------------
# Univ Calif San Diego
# centrality = 0.004876351720490121
#       centrality                name     group country          organization
# 650     0.000415  Toda, Alexis Akira  Fullname     USA  Univ Calif San Diego
# 1198    0.000209     Callen, Michael  Fullname     USA  Univ Calif San Diego
# 1253    0.000209       Sadoff, Sally  Fullname     USA  Univ Calif San Diego
# 1359    0.000208         Gneezy, Uri  Fullname     USA  Univ Calif San Diego
# 1398    0.000208  Carson, Richard T.  Fullname     USA  Univ Calif San Diego
# --------------------------------------------------
# Univ Washington
# centrality = 0.004872871232670128
#       centrality                   name     group country     organization
# 628     0.000418        Harford, Jarrad  Fullname     USA  Univ Washington
# 930     0.000309  Turnovsky, Stephen J.  Fullname     USA  Univ Washington
# 943     0.000309         Kim, Chang-Jin  Fullname     USA  Univ Washington
# 1199    0.000209              Zeng, Yao  Fullname     USA  Univ Washington
# 1366    0.000208         Long, James D.  Fullname     USA  Univ Washington
# --------------------------------------------------
# West Virginia Univ
# centrality = 0.004867689244440157
#       centrality                name     group country        organization
# 568     0.000519  Humphreys, Brad R.  Fullname     USA  West Virginia Univ
# 680     0.000413  McCannon, Bryan C.  Fullname     USA  West Virginia Univ
# 779     0.000313  Etienne, Xiaoli L.  Fullname     USA  West Virginia Univ
# 919     0.000310     Hall, Joshua C.  Fullname     USA  West Virginia Univ
# 1223    0.000209         Nowak, Adam  Fullname     USA  West Virginia Univ
# --------------------------------------------------

# %% [markdown]
# ### org ranking

# %%
topk = 10
orgs = df[df['group'] == 'FullOrgName']
orgs.head(topk)
# Out:
#     centrality                 name        group country organization
# 1     0.050982                 NBER  FullOrgName     USA          NaN
# 6     0.021066           World Bank  FullOrgName     USA          NaN
# 10    0.016819    Int Monetary Fund  FullOrgName     USA          NaN
# 12    0.016457        Stanford Univ  FullOrgName     USA          NaN
# 18    0.012755        Univ Illinois  FullOrgName     USA          NaN
# 19    0.012530       Univ Wisconsin  FullOrgName     USA          NaN
# 20    0.012524         Harvard Univ  FullOrgName     USA          NaN
# 21    0.012429                  MIT  FullOrgName     USA          NaN
# 23    0.011997         Univ Chicago  FullOrgName     USA          NaN
# 24    0.011901  Univ Calif Berkeley  FullOrgName     USA          NaN

# %% [markdown]
# ### org ranking by country

# %%
countries = df[df['group'] == 'Country']['name'].tolist()
for country in countries:
    print(country)
    print('centrality = ', df[df['name'] == country]['centrality'].iloc[0], sep='')
    orgs = df[(df['country'] == country) & (df['group'] == 'FullOrgName')]
    print(orgs.sort_values(by='centrality', ascending=False).head())
    print('-'*50)
# Out:
# USA
# centrality = 0.9916481863234224
#     centrality               name        group country organization
# 1     0.050982               NBER  FullOrgName     USA          NaN
# 6     0.021066         World Bank  FullOrgName     USA          NaN
# 10    0.016819  Int Monetary Fund  FullOrgName     USA          NaN
# 12    0.016457      Stanford Univ  FullOrgName     USA          NaN
# 18    0.012755      Univ Illinois  FullOrgName     USA          NaN
# --------------------------------------------------
# Peoples R China
# centrality = 0.004464139862145678
#       centrality                              name        group  \
# 2160    0.000176                       Peking Univ  FullOrgName
# 2165    0.000164          Univ Int Business & Econ  FullOrgName
# 2167    0.000154  Southwestern Univ Finance & Econ  FullOrgName
# 2169    0.000147                 Renmin Univ China  FullOrgName
# 2170    0.000135                     Zhejiang Univ  FullOrgName
#
#               country organization
# 2160  Peoples R China          NaN
# 2165  Peoples R China          NaN
# 2167  Peoples R China          NaN
# 2169  Peoples R China          NaN
# 2170  Peoples R China          NaN
# --------------------------------------------------
# England
# centrality = 0.0021453814397650486
#       centrality             name        group  country organization
# 2164    0.000168      Univ Oxford  FullOrgName  England          NaN
# 2178    0.000117              UCL  FullOrgName  England          NaN
# 2579    0.000106  London Sch Econ  FullOrgName  England          NaN
# 9199    0.000087     Univ Warwick  FullOrgName  England          NaN
# 9206    0.000076  Univ Manchester  FullOrgName  England          NaN
# --------------------------------------------------
# Germany
# centrality = 0.0018273313354522066
#       centrality                name        group  country organization
# 9234    0.000059  European Cent Bank  FullOrgName  Germany          NaN
# 9238    0.000057        Univ Cologne  FullOrgName  Germany          NaN
# 9256    0.000047  Deutsch Bundesbank  FullOrgName  Germany          NaN
# 9263    0.000044    Tech Univ Munich  FullOrgName  Germany          NaN
# 9268    0.000043        Univ Hamburg  FullOrgName  Germany          NaN
# --------------------------------------------------
# Australia
# centrality = 0.0012121006785301115
#       centrality             name        group    country organization
# 2162    0.000173      Monash Univ  FullOrgName  Australia          NaN
# 9194    0.000092  Univ Queensland  FullOrgName  Australia          NaN
# 9200    0.000086   Univ Melbourne  FullOrgName  Australia          NaN
# 9201    0.000084        RMIT Univ  FullOrgName  Australia          NaN
# 9203    0.000081    Griffith Univ  FullOrgName  Australia          NaN
# --------------------------------------------------
# Italy
# centrality = 0.0011423432482987402
#       centrality                name        group country organization
# 9216    0.000069        Univ Bologna  FullOrgName   Italy          NaN
# 9243    0.000055        Bocconi Univ  FullOrgName   Italy          NaN
# 9297    0.000036  Sapienza Univ Rome  FullOrgName   Italy          NaN
# 9298    0.000036          Bank Italy  FullOrgName   Italy          NaN
# 9318    0.000032          Univ Milan  FullOrgName   Italy          NaN
# --------------------------------------------------
# France
# centrality = 0.0008745539713262133
#       centrality                      name        group country organization
# 9254    0.000048  Montpellier Business Sch  FullOrgName  France          NaN
# 9287    0.000039    Univ Toulouse Capitole  FullOrgName  France          NaN
# 9323    0.000031            Paris Sch Econ  FullOrgName  France          NaN
# 9341    0.000028        Aix Marseille Univ  FullOrgName  France          NaN
# 9347    0.000028                      CNRS  FullOrgName  France          NaN
# --------------------------------------------------
# Spain
# centrality = 0.0007479854769063415
#       centrality                     name        group country organization
# 9239    0.000055           Univ Barcelona  FullOrgName   Spain          NaN
# 9294    0.000037            Univ Valencia  FullOrgName   Spain          NaN
# 9312    0.000033  Univ Complutense Madrid  FullOrgName   Spain          NaN
# 9324    0.000031  Univ Autonoma Barcelona  FullOrgName   Spain          NaN
# 9354    0.000028            Univ Zaragoza  FullOrgName   Spain          NaN
# --------------------------------------------------
# Canada
# centrality = 0.0007233817374136798
#       centrality                   name        group country organization
# 9196    0.000090           Univ Toronto  FullOrgName  Canada          NaN
# 9269    0.000042            Bank Canada  FullOrgName  Canada          NaN
# 9275    0.000041            McGill Univ  FullOrgName  Canada          NaN
# 9305    0.000034  Univ British Columbia  FullOrgName  Canada          NaN
# 9314    0.000033           HEC Montreal  FullOrgName  Canada          NaN
# --------------------------------------------------
# Netherlands
# centrality = 0.0005646300091025707
#       centrality                  name        group      country organization
# 9207    0.000075          Erasmus Univ  FullOrgName  Netherlands          NaN
# 9222    0.000065        Univ Groningen  FullOrgName  Netherlands          NaN
# 9231    0.000059        Univ Amsterdam  FullOrgName  Netherlands          NaN
# 9244    0.000055          Tilburg Univ  FullOrgName  Netherlands          NaN
# 9245    0.000055  Vrije Univ Amsterdam  FullOrgName  Netherlands          NaN
# --------------------------------------------------
# South Korea
# centrality = 0.0004462427879230545
#       centrality                          name        group      country  \
# 9255    0.000047               Seoul Natl Univ  FullOrgName  South Korea
# 9293    0.000038  Korea Adv Inst Sci & Technol  FullOrgName  South Korea
# 9310    0.000034             Sungkyunkwan Univ  FullOrgName  South Korea
# 9369    0.000026                   Yonsei Univ  FullOrgName  South Korea
# 9400    0.000023                    Korea Univ  FullOrgName  South Korea
#
#      organization
# 9255          NaN
# 9293          NaN
# 9310          NaN
# 9369          NaN
# 9400          NaN
# --------------------------------------------------
# Japan
# centrality = 0.0004436643767616551
#       centrality                name        group country organization
# 9286    0.000039          Univ Tokyo  FullOrgName   Japan          NaN
# 9291    0.000038           Kobe Univ  FullOrgName   Japan          NaN
# 9359    0.000027   Hitotsubashi Univ  FullOrgName   Japan          NaN
# 9403    0.000023         Waseda Univ  FullOrgName   Japan          NaN
# 9467    0.000018  Kochi Univ Technol  FullOrgName   Japan          NaN
# --------------------------------------------------
# Switzerland
# centrality = 0.00034239837778746814
#       centrality                    name        group      country  \
# 9225    0.000064  Swiss Fed Inst Technol  FullOrgName  Switzerland
# 9227    0.000063             Univ Zurich  FullOrgName  Switzerland
# 9330    0.000030          Univ St Gallen  FullOrgName  Switzerland
# 9351    0.000028             Univ Geneva  FullOrgName  Switzerland
# 9363    0.000026               Univ Bern  FullOrgName  Switzerland
#
#      organization
# 9225          NaN
# 9227          NaN
# 9330          NaN
# 9351          NaN
# 9363          NaN
# --------------------------------------------------
# Sweden
# centrality = 0.00029914672581922143
#       centrality                name        group country organization
# 9220    0.000065           Lund Univ  FullOrgName  Sweden          NaN
# 9328    0.000031      Stockholm Univ  FullOrgName  Sweden          NaN
# 9362    0.000026      Linkoping Univ  FullOrgName  Sweden          NaN
# 9409    0.000023  Stockholm Sch Econ  FullOrgName  Sweden          NaN
# 9425    0.000022        Uppsala Univ  FullOrgName  Sweden          NaN
# --------------------------------------------------
# India
# centrality = 0.0002922130487860089
#       centrality                              name        group country  \
# 9303    0.000035               Indian Inst Technol  FullOrgName   India
# 9487    0.000017            Indian Inst Management  FullOrgName   India
# 9563    0.000014                  Indian Stat Inst  FullOrgName   India
# 9608    0.000012  Indian Inst Management Bangalore  FullOrgName   India
# 9678    0.000010                        Univ Delhi  FullOrgName   India
#
#      organization
# 9303          NaN
# 9487          NaN
# 9563          NaN
# 9608          NaN
# 9678          NaN
# --------------------------------------------------
# Brazil
# centrality = 0.00023462658360413888
#       centrality                           name        group country  \
# 9280    0.000041                 Univ Sao Paulo  FullOrgName  Brazil
# 9658    0.000011  Fed Univ Grande Dourados UFGD  FullOrgName  Brazil
# 9699    0.000010          Univ Fed Juiz de Fora  FullOrgName  Brazil
# 9762    0.000009        Univ Fed Rio de Janeiro  FullOrgName  Brazil
# 9874    0.000007                  Univ Brasilia  FullOrgName  Brazil
#
#      organization
# 9280          NaN
# 9658          NaN
# 9699          NaN
# 9762          NaN
# 9874          NaN
# --------------------------------------------------
# Turkey
# centrality = 0.00021726719132970717
#       centrality                        name        group country organization
# 9486    0.000017                    Koc Univ  FullOrgName  Turkey          NaN
# 9507    0.000016  Eastern Mediterranean Univ  FullOrgName  Turkey          NaN
# 9616    0.000012       Middle East Tech Univ  FullOrgName  Turkey          NaN
# 9653    0.000011              Hacettepe Univ  FullOrgName  Turkey          NaN
# 9698    0.000010     Cent Bank Republ Turkey  FullOrgName  Turkey          NaN
# --------------------------------------------------
# Taiwan
# centrality = 0.0002076484982761116
#       centrality                   name        group country organization
# 9475    0.000018       Natl Taiwan Univ  FullOrgName  Taiwan          NaN
# 9480    0.000018  Natl Sun Yat Sen Univ  FullOrgName  Taiwan          NaN
# 9512    0.000016           Tamkang Univ  FullOrgName  Taiwan          NaN
# 9570    0.000014     Natl Chengchi Univ  FullOrgName  Taiwan          NaN
# 9709    0.000010        Ming Chuan Univ  FullOrgName  Taiwan          NaN
# --------------------------------------------------
# Norway
# centrality = 0.0001976661042487728
#       centrality                          name        group country  \
# 9372    0.000025       Norwegian Univ Life Sci  FullOrgName  Norway
# 9510    0.000016                   Stat Norway  FullOrgName  Norway
# 9540    0.000015  Norwegian Univ Sci & Technol  FullOrgName  Norway
# 9552    0.000014     BI Norwegian Business Sch  FullOrgName  Norway
# 9581    0.000013                     Univ Oslo  FullOrgName  Norway
#
#      organization
# 9372          NaN
# 9510          NaN
# 9540          NaN
# 9552          NaN
# 9581          NaN
# --------------------------------------------------
# New Zealand
# centrality = 0.00018646431803850903
#       centrality                   name        group      country organization
# 9334    0.000030             Univ Otago  FullOrgName  New Zealand          NaN
# 9337    0.000030           Univ Waikato  FullOrgName  New Zealand          NaN
# 9342    0.000028  Auckland Univ Technol  FullOrgName  New Zealand          NaN
# 9368    0.000026          Univ Auckland  FullOrgName  New Zealand          NaN
# 9386    0.000024            Massey Univ  FullOrgName  New Zealand          NaN
# --------------------------------------------------
# Austria
# centrality = 0.00017650285245771063
#       centrality                         name        group  country  \
# 9322    0.000032               Univ Innsbruck  FullOrgName  Austria
# 9373    0.000025                  Univ Vienna  FullOrgName  Austria
# 9439    0.000021    Johannes Kepler Univ Linz  FullOrgName  Austria
# 9478    0.000018      Karl Franzens Univ Graz  FullOrgName  Austria
# 9734    0.000009  Vienna Univ Econ & Business  FullOrgName  Austria
#
#      organization
# 9322          NaN
# 9373          NaN
# 9439          NaN
# 9478          NaN
# 9734          NaN
# --------------------------------------------------
# Belgium
# centrality = 0.0001742889660085881
#       centrality                    name        group  country organization
# 9259    0.000046              Univ Ghent  FullOrgName  Belgium          NaN
# 9292    0.000038  Katholieke Univ Leuven  FullOrgName  Belgium          NaN
# 9456    0.000019    Univ Libre Bruxelles  FullOrgName  Belgium          NaN
# 9565    0.000014   Catholic Univ Louvain  FullOrgName  Belgium          NaN
# 9775    0.000008               UCLouvain  FullOrgName  Belgium          NaN
# --------------------------------------------------
# Singapore
# centrality = 0.0001709980682797199
#        centrality                       name        group    country  \
# 9197     0.000089        Natl Univ Singapore  FullOrgName  Singapore
# 9272     0.000042       Nanyang Technol Univ  FullOrgName  Singapore
# 9375     0.000025  Singapore Management Univ  FullOrgName  Singapore
# 10461    0.000004              Yale NUS Coll  FullOrgName  Singapore
# 12187    0.000003                 TUM CREATE  FullOrgName  Singapore
#
#       organization
# 9197           NaN
# 9272           NaN
# 9375           NaN
# 10461          NaN
# 12187          NaN
# --------------------------------------------------
# Portugal
# centrality = 0.00016054421822340022
#       centrality              name        group   country organization
# 9338    0.000029        Univ Porto  FullOrgName  Portugal          NaN
# 9349    0.000028       Univ Lisbon  FullOrgName  Portugal          NaN
# 9484    0.000018  Univ Nova Lisboa  FullOrgName  Portugal          NaN
# 9508    0.000016        Univ Minho  FullOrgName  Portugal          NaN
# 9806    0.000008               IUL  FullOrgName  Portugal          NaN
# --------------------------------------------------
# Scotland
# centrality = 0.000148877248820203
#       centrality              name        group   country organization
# 9277    0.000041    Univ Edinburgh  FullOrgName  Scotland          NaN
# 9316    0.000032      Univ Glasgow  FullOrgName  Scotland          NaN
# 9521    0.000016     Univ Aberdeen  FullOrgName  Scotland          NaN
# 9536    0.000015     Univ Stirling  FullOrgName  Scotland          NaN
# 9554    0.000014  Univ Strathclyde  FullOrgName  Scotland          NaN
# --------------------------------------------------
# Poland
# centrality = 0.00013511747478716396
#       centrality                        name        group country organization
# 9300    0.000035                 Univ Warsaw  FullOrgName  Poland          NaN
# 9650    0.000011                   Univ Lodz  FullOrgName  Poland          NaN
# 9721    0.000009             Polish Acad Sci  FullOrgName  Poland          NaN
# 9724    0.000009           Wroclaw Univ Econ  FullOrgName  Poland          NaN
# 9738    0.000009  Wroclaw Univ Sci & Technol  FullOrgName  Poland          NaN
# --------------------------------------------------
# Chile
# centrality = 0.00013487168677003462
#       centrality                            name        group country  \
# 9281    0.000040  Pontificia Univ Catolica Chile  FullOrgName   Chile
# 9572    0.000014              Univ Adolfo Ibanez  FullOrgName   Chile
# 9664    0.000011                      Univ Chile  FullOrgName   Chile
# 9685    0.000010                 Cent Bank Chile  FullOrgName   Chile
# 9817    0.000008             Diego Portales Univ  FullOrgName   Chile
#
#      organization
# 9281          NaN
# 9572          NaN
# 9664          NaN
# 9685          NaN
# 9817          NaN
# --------------------------------------------------
# Finland
# centrality = 0.00012425876846010846
#       centrality            name        group  country organization
# 9445    0.000020       Univ Oulu  FullOrgName  Finland          NaN
# 9447    0.000020      Aalto Univ  FullOrgName  Finland          NaN
# 9535    0.000015   Univ Helsinki  FullOrgName  Finland          NaN
# 9566    0.000014  Univ Jyvaskyla  FullOrgName  Finland          NaN
# 9672    0.000011      Univ Vaasa  FullOrgName  Finland          NaN
# --------------------------------------------------
# Israel
# centrality = 0.00011293605617025018
#       centrality                   name        group country organization
# 9407    0.000023  Ben Gurion Univ Negev  FullOrgName  Israel          NaN
# 9452    0.000019          Bar Ilan Univ  FullOrgName  Israel          NaN
# 9469    0.000018  Hebrew Univ Jerusalem  FullOrgName  Israel          NaN
# 9704    0.000010             Univ Haifa  FullOrgName  Israel          NaN
# 9931    0.000007   Western Galilee Coll  FullOrgName  Israel          NaN
# --------------------------------------------------
# Greece
# centrality = 0.00010190282012261076
#       centrality                         name        group country  \
# 9556    0.000014                   Univ Crete  FullOrgName  Greece
# 9631    0.000012  Athens Univ Econ & Business  FullOrgName  Greece
# 9707    0.000010                Univ Ioannina  FullOrgName  Greece
# 9780    0.000008                Univ Thessaly  FullOrgName  Greece
# 9799    0.000008                 Univ Piraeus  FullOrgName  Greece
#
#      organization
# 9556          NaN
# 9631          NaN
# 9707          NaN
# 9780          NaN
# 9799          NaN
# --------------------------------------------------
# South Africa
# centrality = 9.921728242150306e-05
#       centrality               name        group       country organization
# 9353    0.000028     Univ Cape Town  FullOrgName  South Africa          NaN
# 9410    0.000023      Univ Pretoria  FullOrgName  South Africa          NaN
# 9585    0.000013  Stellenbosch Univ  FullOrgName  South Africa          NaN
# 9617    0.000012  Univ Johannesburg  FullOrgName  South Africa          NaN
# 9641    0.000011    North West Univ  FullOrgName  South Africa          NaN
# --------------------------------------------------
# Denmark
# centrality = 8.903110417222168e-05
#        centrality                     name        group  country organization
# 9344     0.000028    Univ Southern Denmark  FullOrgName  Denmark          NaN
# 9346     0.000028  Copenhagen Business Sch  FullOrgName  Denmark          NaN
# 9626     0.000012             Aalborg Univ  FullOrgName  Denmark          NaN
# 9657     0.000011        Tech Univ Denmark  FullOrgName  Denmark          NaN
# 15880    0.000001            Roskilde Univ  FullOrgName  Denmark          NaN
# --------------------------------------------------
# Ireland
# centrality = 7.965060764453962e-05
#        centrality                 name        group  country organization
# 9333     0.000030     Univ Coll Dublin  FullOrgName  Ireland          NaN
# 9466     0.000018  Trinity Coll Dublin  FullOrgName  Ireland          NaN
# 10019    0.000006    Cent Bank Ireland  FullOrgName  Ireland          NaN
# 10334    0.000005     Dublin City Univ  FullOrgName  Ireland          NaN
# 10505    0.000004        Univ Limerick  FullOrgName  Ireland          NaN
# --------------------------------------------------
# Mexico
# centrality = 7.464523211084086e-05
#       centrality                        name        group country organization
# 9722    0.000009                        ITAM  FullOrgName  Mexico          NaN
# 9776    0.000008                Banco Mexico  FullOrgName  Mexico          NaN
# 9813    0.000008  Ctr Invest & Docencia Econ  FullOrgName  Mexico          NaN
# 9849    0.000007                        CIDE  FullOrgName  Mexico          NaN
# 9926    0.000007   Univ Nacl Autonoma Mexico  FullOrgName  Mexico          NaN
# --------------------------------------------------
# U Arab Emirates
# centrality = 7.368120888143246e-05
#        centrality                       name        group          country  \
# 9542     0.000015          Amer Univ Sharjah  FullOrgName  U Arab Emirates
# 9548     0.000014                 Zayed Univ  FullOrgName  U Arab Emirates
# 9623     0.000012                 Univ Dubai  FullOrgName  U Arab Emirates
# 9855     0.000007    New York Univ Abu Dhabi  FullOrgName  U Arab Emirates
# 10141    0.000005  United Arab Emirates Univ  FullOrgName  U Arab Emirates
#
#       organization
# 9542           NaN
# 9548           NaN
# 9623           NaN
# 9855           NaN
# 10141          NaN
# --------------------------------------------------
# Romania
# centrality = 7.199063441513328e-05
#        centrality                                      name        group  \
# 9522     0.000016               Bucharest Univ Econ Studies  FullOrgName
# 9560     0.000014                         Babes Bolyai Univ  FullOrgName
# 9862     0.000007  Univ Med Pharm Sci & Technol Tirgu Mures  FullOrgName
# 9924     0.000007                   Politehn Univ Timisoara  FullOrgName
# 10265    0.000005                       West Univ Timisoara  FullOrgName
#
#        country organization
# 9522   Romania          NaN
# 9560   Romania          NaN
# 9862   Romania          NaN
# 9924   Romania          NaN
# 10265  Romania          NaN
# --------------------------------------------------
# Vietnam
# centrality = 6.740598526022735e-05
#        centrality                        name        group  country  \
# 9610     0.000012          Ton Duc Thang Univ  FullOrgName  Vietnam
# 10175    0.000005           RMIT Univ Vietnam  FullOrgName  Vietnam
# 10314    0.000005  Ho Chi Minh City Open Univ  FullOrgName  Vietnam
# 10391    0.000004            Eastern Int Univ  FullOrgName  Vietnam
# 10733    0.000003  Univ Econ Ho Chi Minh City  FullOrgName  Vietnam
#
#       organization
# 9610           NaN
# 10175          NaN
# 10314          NaN
# 10391          NaN
# 10733          NaN
# --------------------------------------------------
# Colombia
# centrality = 6.415037046768691e-05
#        centrality                       name        group   country  \
# 9742     0.000009               Univ Rosario  FullOrgName  Colombia
# 9796     0.000008           Int Ctr Trop Agr  FullOrgName  Colombia
# 9947     0.000006               Banco Republ  FullOrgName  Colombia
# 10313    0.000005      Banco Republ Colombia  FullOrgName  Colombia
# 10412    0.000004  Pontificia Univ Javeriana  FullOrgName  Colombia
#
#       organization
# 9742           NaN
# 9796           NaN
# 9947           NaN
# 10313          NaN
# 10412          NaN
# --------------------------------------------------
# Czech Republic
# centrality = 5.799064740220118e-05
#        centrality                 name        group         country  \
# 9482     0.000018  Charles Univ Prague  FullOrgName  Czech Republic
# 9718     0.000009         Masaryk Univ  FullOrgName  Czech Republic
# 9990     0.000006       Univ Pardubice  FullOrgName  Czech Republic
# 10752    0.000003             CERGE EI  FullOrgName  Czech Republic
# 10913    0.000003     Univ Econ Prague  FullOrgName  Czech Republic
#
#       organization
# 9482           NaN
# 9718           NaN
# 9990           NaN
# 10752          NaN
# 10913          NaN
# --------------------------------------------------
# Pakistan
# centrality = 5.371023447029428e-05
#        centrality                        name        group   country  \
# 9732     0.000009  Lahore Univ Management Sci  FullOrgName  Pakistan
# 10089    0.000005             Lahore Sch Econ  FullOrgName  Pakistan
# 10244    0.000005            Univ Cent Punjab  FullOrgName  Pakistan
# 11034    0.000003      COMSATS Univ Islamabad  FullOrgName  Pakistan
# 12133    0.000003                 Univ Lahore  FullOrgName  Pakistan
#
#       organization
# 9732           NaN
# 10089          NaN
# 10244          NaN
# 11034          NaN
# 12133          NaN
# --------------------------------------------------
# Hungary
# centrality = 5.066143317290507e-05
#        centrality                              name        group  country  \
# 9433     0.000021            Corvinus Univ Budapest  FullOrgName  Hungary
# 9963     0.000006  Budapest Univ Technol & Econ BME  FullOrgName  Hungary
# 10144    0.000005                Hungarian Acad Sci  FullOrgName  Hungary
# 10676    0.000004                Eotvos Lorand Univ  FullOrgName  Hungary
# 12532    0.000002                         Univ Pecs  FullOrgName  Hungary
#
#       organization
# 9433           NaN
# 9963           NaN
# 10144          NaN
# 10676          NaN
# 12532          NaN
# --------------------------------------------------
# Argentina
# centrality = 4.281750701955744e-05
#        centrality                    name        group    country organization
# 9606     0.000013  Univ Torcuato Di Tella  FullOrgName  Argentina          NaN
# 10190    0.000005         Univ San Andres  FullOrgName  Argentina          NaN
# 10500    0.000004                     UNS  FullOrgName  Argentina          NaN
# 11395    0.000003                    UNSJ  FullOrgName  Argentina          NaN
# 12437    0.000002               Univ CEMA  FullOrgName  Argentina          NaN
# --------------------------------------------------
# Malaysia
# centrality = 4.101683444028122e-05
#        centrality                             name        group   country  \
# 9977     0.000006             Monash Univ Malaysia  FullOrgName  Malaysia
# 10051    0.000006                      Univ Malaya  FullOrgName  Malaysia
# 10294    0.000005  Univ Nottingham Malaysia Campus  FullOrgName  Malaysia
# 10486    0.000004              Univ Putra Malaysia  FullOrgName  Malaysia
# 10549    0.000004              Univ Sains Malaysia  FullOrgName  Malaysia
#
#       organization
# 9977           NaN
# 10051          NaN
# 10294          NaN
# 10486          NaN
# 10549          NaN
# --------------------------------------------------
# Tunisia
# centrality = 3.979964853197239e-05
#        centrality                                               name  \
# 9580     0.000013                                         Univ Tunis
# 10418    0.000004           Inst High Commercial Studies Sousse IHEC
# 10446    0.000004                                        Univ Sousse
# 10550    0.000004                                          Univ Sfax
# 11398    0.000003  Res Lab Econ Management & Quantitat Finance LaREM
#
#              group  country organization
# 9580   FullOrgName  Tunisia          NaN
# 10418  FullOrgName  Tunisia          NaN
# 10446  FullOrgName  Tunisia          NaN
# 10550  FullOrgName  Tunisia          NaN
# 11398  FullOrgName  Tunisia          NaN
# --------------------------------------------------
# Iran
# centrality = 3.9421519239094295e-05
#        centrality                    name        group country organization
# 9863     0.000007        Bu Ali Sina Univ  FullOrgName    Iran          NaN
# 10079    0.000006    Tarbiat Modares Univ  FullOrgName    Iran          NaN
# 10124    0.000005     Sharif Univ Technol  FullOrgName    Iran          NaN
# 10222    0.000005             Univ Tehran  FullOrgName    Iran          NaN
# 10617    0.000004  Imam Khomeini Int Univ  FullOrgName    Iran          NaN
# --------------------------------------------------
# Wales
# centrality = 3.529466432397609e-05
#          centrality           name        group country organization
# 9578   1.335764e-05   Swansea Univ  FullOrgName   Wales          NaN
# 9590   1.297620e-05   Cardiff Univ  FullOrgName   Wales          NaN
# 10108  5.403159e-06    Bangor Univ  FullOrgName   Wales          NaN
# 12870  2.407756e-06   Univ Cardiff  FullOrgName   Wales          NaN
# 24310  4.628490e-07  Off Natl Stat  FullOrgName   Wales          NaN
# --------------------------------------------------
# Luxembourg
# centrality = 3.428496620699564e-05
#        centrality                                 name        group  \
# 9503     0.000017                      Univ Luxembourg  FullOrgName
# 10668    0.000004             European Investment Bank  FullOrgName
# 10704    0.000004  Luxembourg Inst Socioecon Res LISER  FullOrgName
# 12871    0.000002                    SOGETI Luxembourg  FullOrgName
# 13014    0.000002               Luxembourg Sch Finance  FullOrgName
#
#           country organization
# 9503   Luxembourg          NaN
# 10668  Luxembourg          NaN
# 10704  Luxembourg          NaN
# 12871  Luxembourg          NaN
# 13014  Luxembourg          NaN
# --------------------------------------------------
# Kenya
# centrality = 3.4015835228661656e-05
#        centrality                    name        group country organization
# 9673     0.000011            Univ Nairobi  FullOrgName   Kenya          NaN
# 9826     0.000008          Int Potato Ctr  FullOrgName   Kenya          NaN
# 10112    0.000005                    IITA  FullOrgName   Kenya          NaN
# 10217    0.000005  Int Livestock Res Inst  FullOrgName   Kenya          NaN
# 11581    0.000003   Busara Ctr Behav Econ  FullOrgName   Kenya          NaN
# --------------------------------------------------
# Russia
# centrality = 3.284639461485459e-05
#        centrality                                  name        group country  \
# 9712     0.000009         Natl Res Univ Higher Sch Econ  FullOrgName  Russia
# 10413    0.000004                          New Econ Sch  FullOrgName  Russia
# 10419    0.000004  Skolkovo Inst Sci & Technol Skoltech  FullOrgName  Russia
# 10637    0.000004                         Natl Res Univ  FullOrgName  Russia
# 12256    0.000003                      Russian Acad Sci  FullOrgName  Russia
#
#       organization
# 9712           NaN
# 10413          NaN
# 10419          NaN
# 10637          NaN
# 12256          NaN
# --------------------------------------------------
# Ethiopia
# centrality = 2.7453685228376972e-05
#          centrality                     name        group   country  \
# 9726   9.216096e-06   Ethiopian Dev Res Inst  FullOrgName  Ethiopia
# 9864   7.222331e-06                   ICARDA  FullOrgName  Ethiopia
# 10113  5.378319e-06                     EDRI  FullOrgName  Ethiopia
# 10274  4.814391e-06  Amhara Reg Agr Res Inst  FullOrgName  Ethiopia
# 24849  4.331078e-07               Jimma Univ  FullOrgName  Ethiopia
#
#       organization
# 9726           NaN
# 9864           NaN
# 10113          NaN
# 10274          NaN
# 24849          NaN
# --------------------------------------------------
# Thailand
# centrality = 2.6288806336948678e-05
#        centrality                name        group   country organization
# 9756     0.000009  Chulalongkorn Univ  FullOrgName  Thailand          NaN
# 11492    0.000003      Khon Kaen Univ  FullOrgName  Thailand          NaN
# 11891    0.000003      Thammasat Univ  FullOrgName  Thailand          NaN
# 13845    0.000002                MUIC  FullOrgName  Thailand          NaN
# 13846    0.000002                NIDA  FullOrgName  Thailand          NaN
# --------------------------------------------------
# North Ireland
# centrality = 2.459372401489798e-05
#          centrality                              name        group  \
# 9587   1.305703e-05               Queens Univ Belfast  FullOrgName
# 10038  5.747276e-06                       Ulster Univ  FullOrgName
# 10326  4.578556e-06  Agrifood & Biosc Ences Inst AFBI  FullOrgName
# 18719  9.081957e-07           Ulster Univ Jordanstown  FullOrgName
# 26963  3.026695e-07             Ulster Univ Coleraine  FullOrgName
#
#              country organization
# 9587   North Ireland          NaN
# 10038  North Ireland          NaN
# 10326  North Ireland          NaN
# 18719  North Ireland          NaN
# 26963  North Ireland          NaN
# --------------------------------------------------
# Nigeria
# centrality = 2.3627493461031283e-05
#        centrality                  name        group  country organization
# 9881     0.000007  Obafemi Awolowo Univ  FullOrgName  Nigeria          NaN
# 10303    0.000005           Univ Ibadan  FullOrgName  Nigeria          NaN
# 12887    0.000002           Anchor Univ  FullOrgName  Nigeria          NaN
# 13440    0.000002          Univ Nigeria  FullOrgName  Nigeria          NaN
# 17593    0.000001              Univ Uyo  FullOrgName  Nigeria          NaN
# --------------------------------------------------
# Indonesia
# centrality = 2.306723182699403e-05
#        centrality                name        group    country organization
# 10056    0.000006      Univ Indonesia  FullOrgName  Indonesia          NaN
# 10114    0.000005          Univ Jambi  FullOrgName  Indonesia          NaN
# 11824    0.000003  Univ Palangka Raya  FullOrgName  Indonesia          NaN
# 13079    0.000002      SMERU Res Inst  FullOrgName  Indonesia          NaN
# 17372    0.000001      Univ Airlangga  FullOrgName  Indonesia          NaN
# --------------------------------------------------
# Peru
# centrality = 2.0766558403542946e-05
#        centrality                           name        group country  \
# 9937     0.000007                     Univ Piura  FullOrgName    Peru
# 10848    0.000003  Pontificia Univ Catolica Peru  FullOrgName    Peru
# 11826    0.000003                            CIP  FullOrgName    Peru
# 11827    0.000003         Inst Estudios Peruanos  FullOrgName    Peru
# 14538    0.000002                   Grp Anal Dev  FullOrgName    Peru
#
#       organization
# 9937           NaN
# 10848          NaN
# 11826          NaN
# 11827          NaN
# 14538          NaN
# --------------------------------------------------
# Qatar
# centrality = 2.0719607529808307e-05
#          centrality                    name        group country organization
# 9547   1.453522e-05              Qatar Univ  FullOrgName   Qatar          NaN
# 10536  3.898615e-06         Qatar Univ Doha  FullOrgName   Qatar          NaN
# 13853  1.949107e-06  Doha Inst Grad Studies  FullOrgName   Qatar          NaN
# 26381  3.366678e-07   Georgetown Univ Qatar  FullOrgName   Qatar          NaN
# --------------------------------------------------
# Cyprus
# centrality = 2.062816929993071e-05
#          centrality                         name        group country  \
# 9632   1.154055e-05                  Univ Cyprus  FullOrgName  Cyprus
# 11104  2.936200e-06          Cyprus Univ Technol  FullOrgName  Cyprus
# 13017  2.373773e-06  TeleThade DJ Int Consulting  FullOrgName  Cyprus
# 13018  2.373773e-06        Frederick Univ Cyprus  FullOrgName  Cyprus
# 19148  8.700706e-07                 Univ Nicosia  FullOrgName  Cyprus
#
#       organization
# 9632           NaN
# 11104          NaN
# 13017          NaN
# 13018          NaN
# 19148          NaN
# --------------------------------------------------
# Saudi Arabia
# centrality = 2.041892701652851e-05
#        centrality                                          name        group  \
# 9876     0.000007          King Abdullah Petr Studies & Res Ctr  FullOrgName
# 10692    0.000004                           King Abdulaziz Univ  FullOrgName
# 12892    0.000002                            Prince Sultan Univ  FullOrgName
# 15771    0.000001  King Abdullah Petr Studies & Res Ctr KAPSARC  FullOrgName
# 16595    0.000001                                   Najran Univ  FullOrgName
#
#             country organization
# 9876   Saudi Arabia          NaN
# 10692  Saudi Arabia          NaN
# 12892  Saudi Arabia          NaN
# 15771  Saudi Arabia          NaN
# 16595  Saudi Arabia          NaN
# --------------------------------------------------
# Slovenia
# centrality = 1.9444481004178452e-05
#          centrality            name        group   country organization
# 9858   7.284027e-06    Univ Maribor  FullOrgName  Slovenia          NaN
# 9923   6.693964e-06  Univ Ljubljana  FullOrgName  Slovenia          NaN
# 12893  2.406122e-06  Ctr Hlth & Dev  FullOrgName  Slovenia          NaN
# 17889  1.047416e-06  Univ Primorska  FullOrgName  Slovenia          NaN
# 20468  7.039499e-07   Inst Econ Res  FullOrgName  Slovenia          NaN
# --------------------------------------------------
# Ghana
# centrality = 1.841644590757676e-05
#        centrality                              name        group country  \
# 9824     0.000008                        Univ Ghana  FullOrgName   Ghana
# 11837    0.000003                   Univ Cape Coast  FullOrgName   Ghana
# 13405    0.000002  Ghana Inst Management & Publ Adm  FullOrgName   Ghana
# 13468    0.000002                             GIMPA  FullOrgName   Ghana
# 15803    0.000001              Univ Profess Studies  FullOrgName   Ghana
#
#       organization
# 9824           NaN
# 11837          NaN
# 13405          NaN
# 13468          NaN
# 15803          NaN
# --------------------------------------------------
# Liechtenstein
# centrality = 1.691860646425709e-05
#          centrality                name        group        country  \
# 9498   1.681896e-05  Univ Liechtenstein  FullOrgName  Liechtenstein
# 32363  9.964536e-08         LGT Bank AG  FullOrgName  Liechtenstein
# 37955  9.440581e-19  Liechtenstein Inst  FullOrgName  Liechtenstein
#
#       organization
# 9498           NaN
# 32363          NaN
# 37955          NaN
# --------------------------------------------------
# Slovakia
# centrality = 1.6864083973206962e-05
#          centrality                        name        group   country  \
# 10228  4.933950e-06                 Univ Presov  FullOrgName  Slovakia
# 10839  3.264346e-06        Univ Econ Bratislava  FullOrgName  Slovakia
# 13195  2.214246e-06  Council Budget Responsibil  FullOrgName  Slovakia
# 14541  1.717960e-06             Slovak Univ Agr  FullOrgName  Slovakia
# 18342  9.841907e-07               Comenius Univ  FullOrgName  Slovakia
#
#       organization
# 10228          NaN
# 10839          NaN
# 13195          NaN
# 14541          NaN
# 18342          NaN
# --------------------------------------------------
# Philippines
# centrality = 1.594306711663569e-05
#          centrality                   name        group      country  \
# 10176  5.107278e-06       De La Salle Univ  FullOrgName  Philippines
# 10209  5.014323e-06         Asian Dev Bank  FullOrgName  Philippines
# 11832  2.687696e-06      Int Rice Res Inst  FullOrgName  Philippines
# 17726  1.072915e-06  Asian Inst Management  FullOrgName  Philippines
# 20047  7.540463e-07       Univ Philippines  FullOrgName  Philippines
#
#       organization
# 10176          NaN
# 10209          NaN
# 11832          NaN
# 17726          NaN
# 20047          NaN
# --------------------------------------------------
# Egypt
# centrality = 1.5317628477349487e-05
#          centrality                 name        group country organization
# 9840   7.501315e-06           Cairo Univ  FullOrgName   Egypt          NaN
# 10172  5.123703e-06      Amer Univ Cairo  FullOrgName   Egypt          NaN
# 12897  2.405696e-06         British Univ  FullOrgName   Egypt          NaN
# 30418  1.541735e-07                  GUC  FullOrgName   Egypt          NaN
# 33114  7.675499e-08  Menoufia Univ Egypt  FullOrgName   Egypt          NaN
# --------------------------------------------------
# Croatia
# centrality = 1.5202940437360171e-05
#        centrality                        name        group  country  \
# 10106    0.000005                 Univ Zagreb  FullOrgName  Croatia
# 12735    0.000002                  Univ Split  FullOrgName  Croatia
# 13092    0.000002                   Inst Econ  FullOrgName  Croatia
# 17085    0.000001                 Univ Rijeka  FullOrgName  Croatia
# 17411    0.000001  Fac Econ & Business Zagreb  FullOrgName  Croatia
#
#       organization
# 10106          NaN
# 12735          NaN
# 13092          NaN
# 17085          NaN
# 17411          NaN
# --------------------------------------------------
# Uganda
# centrality = 1.439431687802471e-05
#          centrality              name        group country organization
# 9666   1.075347e-05     Makerere Univ  FullOrgName  Uganda          NaN
# 13032  2.355492e-06       Bank Uganda  FullOrgName  Uganda          NaN
# 19263  8.652534e-07       BRAC Uganda  FullOrgName  Uganda          NaN
# 28044  2.460312e-07       Ndejje Univ  FullOrgName  Uganda          NaN
# 29794  1.740708e-07  Cent Bank Uganda  FullOrgName  Uganda          NaN
# --------------------------------------------------
# Lebanon
# centrality = 1.437029834339027e-05
#          centrality                          name        group  country  \
# 9866   7.184689e-06            Lebanese Amer Univ  FullOrgName  Lebanon
# 10561  3.832090e-06              Amer Univ Beirut  FullOrgName  Lebanon
# 12899  2.405605e-06  Holy Spirit Univ Kaslik USEK  FullOrgName  Lebanon
# 25223  4.088350e-07               Ain El Mreisseh  FullOrgName  Lebanon
# 27027  3.002166e-07                 Univ Balamand  FullOrgName  Lebanon
#
#       organization
# 9866           NaN
# 10561          NaN
# 12899          NaN
# 25223          NaN
# 27027          NaN
# --------------------------------------------------
# Serbia
# centrality = 1.2647633629987693e-05
#          centrality                   name        group country organization
# 9758   8.614466e-06          Univ Belgrade  FullOrgName  Serbia          NaN
# 13094  2.292130e-06          Univ Novi Sad  FullOrgName  Serbia          NaN
# 26412  3.353595e-07        Univ Kragujevac  FullOrgName  Serbia          NaN
# 27072  2.976767e-07           EDUCONS Univ  FullOrgName  Serbia          NaN
# 30469  1.529753e-07  Novi Sad Sch Business  FullOrgName  Serbia          NaN
# --------------------------------------------------
# Kuwait
# centrality = 1.2393724104806324e-05
#          centrality                          name        group country  \
# 10325  4.584898e-06       Gulf Univ Sci & Technol  FullOrgName  Kuwait
# 10477  4.078629e-06                   Kuwait Univ  FullOrgName  Kuwait
# 12408  2.482060e-06                 Box Hill Coll  FullOrgName  Kuwait
# 16605  1.248137e-06         Amer Univ Middle East  FullOrgName  Kuwait
# 37607  1.375432e-18  Gulf Univ Sci Econ & Finance  FullOrgName  Kuwait
#
#       organization
# 10325          NaN
# 10477          NaN
# 12408          NaN
# 16605          NaN
# 37607          NaN
# --------------------------------------------------
# Uruguay
# centrality = 1.2095595222200874e-05
#          centrality                   name        group  country organization
# 9711   9.515940e-06         Univ Republica  FullOrgName  Uruguay          NaN
# 14661  1.669892e-06       Univ ORT Uruguay  FullOrgName  Uruguay          NaN
# 26980  3.016434e-07     Banco Cent Uruguay  FullOrgName  Uruguay          NaN
# 29883  1.719534e-07  Univ Catolica Uruguay  FullOrgName  Uruguay          NaN
# 30448  1.533669e-07  CINVE Ctr Invest Econ  FullOrgName  Uruguay          NaN
# --------------------------------------------------
# Lithuania
# centrality = 1.196168724028714e-05
#          centrality                         name        group    country  \
# 10759  3.437131e-06                 Vilnius Univ  FullOrgName  Lithuania
# 11049  2.984566e-06          Kaunas Univ Technol  FullOrgName  Lithuania
# 11886  2.663183e-06  Vilnius Gediminas Tech Univ  FullOrgName  Lithuania
# 18045  1.021641e-06   ISM Univ Management & Econ  FullOrgName  Lithuania
# 20989  6.506436e-07         Mykolas Romeris Univ  FullOrgName  Lithuania
#
#       organization
# 10759          NaN
# 11049          NaN
# 11886          NaN
# 18045          NaN
# 20989          NaN
# --------------------------------------------------
# Bangladesh
# centrality = 1.1012960658228436e-05
#          centrality                  name        group     country  \
# 11839  2.687187e-06   Bangladesh Agr Univ  FullOrgName  Bangladesh
# 12901  2.405253e-06        East West Univ  FullOrgName  Bangladesh
# 12902  2.405253e-06  Cent Bank Bangladesh  FullOrgName  Bangladesh
# 17120  1.153110e-06         Univ Rajshahi  FullOrgName  Bangladesh
# 20026  7.560626e-07            Univ Dhaka  FullOrgName  Bangladesh
#
#       organization
# 11839          NaN
# 12901          NaN
# 12902          NaN
# 17120          NaN
# 20026          NaN
# --------------------------------------------------
# Nepal
# centrality = 9.66445438672756e-06
#          centrality                       name        group country  \
# 10764  3.434994e-06      Mother Infant Res Act  FullOrgName   Nepal
# 11841  2.687048e-06                       NARC  FullOrgName   Nepal
# 11842  2.687048e-06  Int Water Management Inst  FullOrgName   Nepal
# 22708  5.526481e-07             Tribhuwan Univ  FullOrgName   Nepal
# 26961  3.027153e-07                     SAWTEE  FullOrgName   Nepal
#
#       organization
# 10764          NaN
# 11841          NaN
# 11842          NaN
# 22708          NaN
# 26961          NaN
# --------------------------------------------------
# Zimbabwe
# centrality = 8.924776264351774e-06
#        centrality                                       name        group  \
# 10115    0.000005                              Univ Zimbabwe  FullOrgName
# 12905    0.000002                   United Nat Dev Programme  FullOrgName
# 17214    0.000001  Trop Africa Land & Nat Resources Res Inst  FullOrgName
#
#         country organization
# 10115  Zimbabwe          NaN
# 12905  Zimbabwe          NaN
# 17214  Zimbabwe          NaN
# --------------------------------------------------
# Kazakhstan
# centrality = 8.270090551312253e-06
#          centrality                      name        group     country  \
# 9883   7.039500e-06           Nazarbayev Univ  FullOrgName  Kazakhstan
# 22880  5.394141e-07                        NU  FullOrgName  Kazakhstan
# 23165  5.259705e-07  Kazakh British Tech Univ  FullOrgName  Kazakhstan
# 30073  1.652060e-07                KIMEP Univ  FullOrgName  Kazakhstan
# 37565  1.435664e-18    Natl Analyt Ctr Analyt  FullOrgName  Kazakhstan
#
#       organization
# 9883           NaN
# 22880          NaN
# 23165          NaN
# 30073          NaN
# 37565          NaN
# --------------------------------------------------
# Ecuador
# centrality = 8.059362198528824e-06
#          centrality                             name        group  country  \
# 11844  2.686883e-06              ESPOL Polytech Univ  FullOrgName  Ecuador
# 13097  2.289438e-06             Inst Nacl Invest Agr  FullOrgName  Ecuador
# 17732  1.072100e-06               Banco Cent Ecuador  FullOrgName  Ecuador
# 19818  7.854837e-07                   Univ Nacl Loja  FullOrgName  Ecuador
# 22712  5.524860e-07  Corp Estudios Desarrollo CORDES  FullOrgName  Ecuador
#
#       organization
# 11844          NaN
# 13097          NaN
# 17732          NaN
# 19818          NaN
# 22712          NaN
# --------------------------------------------------
# Cote Ivoire
# centrality = 7.961168262223033e-06
#          centrality                                     name        group  \
# 11846  2.686876e-06                     African Dev Bank Grp  FullOrgName
# 12906  2.404939e-06                                    CERAP  FullOrgName
# 15778  1.423510e-06  Ecole Natl Super Stat & Econ Appl ENSEA  FullOrgName
# 20029  7.555983e-07              Univ Felix Houphouet Boigny  FullOrgName
# 26391  3.358586e-07        Ecole Natl Super Stat & Econ Appl  FullOrgName
#
#            country organization
# 11846  Cote Ivoire          NaN
# 12906  Cote Ivoire          NaN
# 15778  Cote Ivoire          NaN
# 20029  Cote Ivoire          NaN
# 26391  Cote Ivoire          NaN
# --------------------------------------------------
# Estonia
# centrality = 7.301306540380159e-06
#          centrality                  name        group  country organization
# 10387  4.353002e-06  Tallinn Univ Technol  FullOrgName  Estonia          NaN
# 13435  2.105349e-06            Univ Tartu  FullOrgName  Estonia          NaN
# 23508  5.079005e-07          Tallinn Univ  FullOrgName  Estonia          NaN
# 30935  1.397499e-07   Tervise Arengu Inst  FullOrgName  Estonia          NaN
# 31878  1.086855e-07       Baltic Def Coll  FullOrgName  Estonia          NaN
# --------------------------------------------------
# Guatemala
# centrality = 6.9308183528702665e-06
#          centrality                                               name  \
# 10118  5.374087e-06         Ctr Study Equ & Governance Hlth Syst CEGSS
# 15279  1.524051e-06  Wealth Accounting & Valuat Ecosyst Serv WAVES Pro
# 34431  3.268024e-08                Secretaria Integrac Econ Centroamer
#
#              group    country organization
# 10118  FullOrgName  Guatemala          NaN
# 15279  FullOrgName  Guatemala          NaN
# 34431  FullOrgName  Guatemala          NaN
# --------------------------------------------------
# Morocco
# centrality = 6.8642478909485525e-06
#          centrality                  name        group  country organization
# 10277  4.810642e-06         Ibn Zohr Univ  FullOrgName  Morocco          NaN
# ...
# 32496  9.816962e-08                        Sport Life  FullOrgName  Macedonia
# 36104  9.652669e-10         Univ St Cyril & Methodius  FullOrgName  Macedonia
#
#       organization
# 13860          NaN
# 25401          NaN
# 30143          NaN
# 32496          NaN
# 36104          NaN
# --------------------------------------------------
# Bosnia & Herceg
# centrality = 2.5244528336948813e-06
#          centrality                name        group          country  \
# 13148  2.242409e-06      Int Burch Univ  FullOrgName  Bosnia & Herceg
# 31893  1.081930e-07  Pavlov Int Bank Ad  FullOrgName  Bosnia & Herceg
# 32497  9.816160e-08  Univ East Sarajevo  FullOrgName  Bosnia & Herceg
# 33139  7.568896e-08       Univ Sarajevo  FullOrgName  Bosnia & Herceg
#
#       organization
# 13148          NaN
# 31893          NaN
# 32497          NaN
# 33139          NaN
# --------------------------------------------------
# Monaco
# centrality = 2.404365327202029e-06
#        centrality             name        group country organization
# 12907    0.000002  Int Univ Monaco  FullOrgName  Monaco          NaN
# --------------------------------------------------
# Mauritius
# centrality = 2.28608102368851e-06
#          centrality                 name        group    country organization
# 14189  1.824892e-06       Univ Mauritius  FullOrgName  Mauritius          NaN
# 25919  3.643917e-07  Cent Bank Mauritius  FullOrgName  Mauritius          NaN
# 32544  9.679711e-08    Cent Informat Bur  FullOrgName  Mauritius          NaN
# --------------------------------------------------
# Palestine
# centrality = 1.856178044646299e-06
#          centrality                     name        group    country  \
# 16960  1.176329e-06  Palestine Polytech Univ  FullOrgName  Palestine
# 21994  5.817566e-07       An Najah Natl Univ  FullOrgName  Palestine
# 32501  9.809271e-08      Palestine Tech Univ  FullOrgName  Palestine
#
#       organization
# 16960          NaN
# 21994          NaN
# 32501          NaN
# --------------------------------------------------
# Jamaica
# centrality = 1.7942937369535355e-06
#          centrality                   name        group  country organization
# 16278  1.294092e-06       Univ West Indies  FullOrgName  Jamaica          NaN
# 23654  5.002019e-07  Univ West Indies Mona  FullOrgName  Jamaica          NaN
# --------------------------------------------------
# Bolivia
# centrality = 1.6342528217994844e-06
#          centrality                    name        group  country organization
# 14980  1.590844e-06       Cent Bank Bolivia  FullOrgName  Bolivia          NaN
# 34017  4.340883e-08  Univ Privada Boliviana  FullOrgName  Bolivia          NaN
# --------------------------------------------------
# Bulgaria
# centrality = 1.6145412258761344e-06
#          centrality                           name        group   country  \
# 23577  5.035888e-07            Ctr Study Democracy  FullOrgName  Bulgaria
# 26110  3.530057e-07         Univ Natl & World Econ  FullOrgName  Bulgaria
# 27991  2.492372e-07  South West Univ Neofit Rilski  FullOrgName  Bulgaria
# 30160  1.627824e-07                       Med Univ  FullOrgName  Bulgaria
# 30161  1.627823e-07                 Med Univ Sofia  FullOrgName  Bulgaria
#
#       organization
# 23577          NaN
# 26110          NaN
# 27991          NaN
# 30160          NaN
# 30161          NaN
# --------------------------------------------------
# Iceland
# centrality = 1.480899719917656e-06
#          centrality               name        group  country organization
# 17746  1.069170e-06       Univ Iceland  FullOrgName  Iceland          NaN
# 25186  4.117297e-07  Cent Bank Iceland  FullOrgName  Iceland          NaN
# --------------------------------------------------
# Mongolia
# centrality = 1.4235886131713538e-06
#          centrality                name        group   country organization
# 16798  1.207855e-06       Bank Mongolia  FullOrgName  Mongolia          NaN
# 28737  2.157335e-07  Natl Univ Mongolia  FullOrgName  Mongolia          NaN
# --------------------------------------------------
# Malta
# centrality = 1.2818577177499196e-06
#        centrality        name        group country organization
# 16327    0.000001  Univ Malta  FullOrgName   Malta          NaN
# --------------------------------------------------
# Azerbaijan
# centrality = 1.2124218954961777e-06
#          centrality                      name        group     country  \
# 18209  1.006338e-06                  ADA Univ  FullOrgName  Azerbaijan
# 31901  1.080578e-07                 Cent Bank  FullOrgName  Azerbaijan
# 32503  9.802635e-08  Azerbaijan Natl Acad Sci  FullOrgName  Azerbaijan
#
#       organization
# 18209          NaN
# 31901          NaN
# 32503          NaN
# --------------------------------------------------
# Niger
# centrality = 1.1438837772503064e-06
#        centrality   name        group country organization
# 17220    0.000001  UNECA  FullOrgName   Niger          NaN
# --------------------------------------------------
# Armenia
# centrality = 1.1075288606697132e-06
#        centrality               name        group  country organization
# 17403    0.000001  Amer Univ Armenia  FullOrgName  Armenia          NaN
# --------------------------------------------------
# Panama
# centrality = 7.944283084617845e-07
#          centrality                       name        group country  \
# 20154  7.391100e-07  Smithsonian Trop Res Inst  FullOrgName  Panama
# 33667  5.531830e-08      Interamer Ctr Tax Adm  FullOrgName  Panama
#
#       organization
# 20154          NaN
# 33667          NaN
# --------------------------------------------------
# Costa Rica
# centrality = 6.206741807421912e-07
#          centrality                            name        group     country  \
# 25243  4.074177e-07    INCAE Business Sch La Garita  FullOrgName  Costa Rica
# 28796  2.132565e-07                Batalla Abogados  FullOrgName  Costa Rica
# 38413  5.210140e-19                 Univ Costa Rica  FullOrgName  Costa Rica
# 39168  4.016019e-20  Environm Dev Initiat EfD CATIE  FullOrgName  Costa Rica
#
#       organization
# 25243          NaN
# 28796          NaN
# 38413          NaN
# 39168          NaN
# --------------------------------------------------
# Venezuela
# centrality = 5.517805653395893e-07
#          centrality                 name        group    country organization
# 22724  5.517806e-07  Cent Bank Venezuela  FullOrgName  Venezuela          NaN
# 38157  7.404724e-19                 IESA  FullOrgName  Venezuela          NaN
# --------------------------------------------------
# Myanmar
# centrality = 5.322055394355431e-07
#          centrality                    name        group  country organization
# 23052  5.322055e-07  Wisdom Garden Educ Ctr  FullOrgName  Myanmar          NaN
# --------------------------------------------------
# Cambodia
# centrality = 5.107374794643098e-07
#          centrality                                   name        group  \
# 24982  4.247643e-07  Deutsch Gesell Int Zusammenarbeit GIZ  FullOrgName
# 32830  8.597314e-08                Council Agr & Rural Dev  FullOrgName
# 37775  1.153833e-18        Social Hlth Protect Network P4H  FullOrgName
#
#         country organization
# 24982  Cambodia          NaN
# 32830  Cambodia          NaN
# 37775  Cambodia          NaN
# --------------------------------------------------
# Montenegro
# centrality = 4.550525497365238e-07
#          centrality                    name        group     country  \
# 30534  1.514544e-07  Univ Montenegro Jovana  FullOrgName  Montenegro
# 31709  1.135791e-07      Mediterranean Univ  FullOrgName  Montenegro
# 33127  7.646346e-08         Univ Montenegro  FullOrgName  Montenegro
# 34239  3.785189e-08        Montenegrin Univ  FullOrgName  Montenegro
# 34240  3.785188e-08      Deloitte Podgorica  FullOrgName  Montenegro
#
#       organization
# 30534          NaN
# 31709          NaN
# 33127          NaN
# 34239          NaN
# 34240          NaN
# --------------------------------------------------
# Kosovo
# centrality = 4.317534847428405e-07
#          centrality            name        group country organization
# 27827  2.591241e-07  Univ Prishtina  FullOrgName  Kosovo          NaN
# 29853  1.726294e-07        UBT Coll  FullOrgName  Kosovo          NaN
# --------------------------------------------------
# North Korea
# centrality = 3.8652474992603287e-07
#          centrality              name        group      country organization
# 25481  3.865247e-07  Kim II Sung Univ  FullOrgName  North Korea          NaN
# --------------------------------------------------
# Cuba
# centrality = 3.325669413388195e-07
#          centrality            name        group country organization
# 26480  3.325669e-07  Univ La Habana  FullOrgName    Cuba          NaN
# --------------------------------------------------
# Benin
# centrality = 2.989023166459383e-07
#          centrality            name        group country organization
# 27055  2.989023e-07    Univ Parakou  FullOrgName   Benin          NaN
# 38405  5.293788e-19  Sassif Villa 1  FullOrgName   Benin          NaN
# --------------------------------------------------
# Togo
# centrality = 2.9890231664489965e-07
#          centrality       name        group country organization
# 27056  2.989023e-07  Univ Lome  FullOrgName    Togo          NaN
# --------------------------------------------------
# Papua N Guinea
# centrality = 2.0652066536537375e-07
#          centrality                            name        group  \
# 30880  1.415276e-07                Divine Word Univ  FullOrgName
# 33498  6.499311e-08  Papua New Guinea Natl Res Inst  FullOrgName
#
#               country organization
# 30880  Papua N Guinea          NaN
# 33498  Papua N Guinea          NaN
# --------------------------------------------------
# Sierra Leone
# centrality = 1.9269624092292836e-07
#          centrality  name        group       country organization
# 29277  1.926962e-07  WAMA  FullOrgName  Sierra Leone          NaN
# --------------------------------------------------
# Senegal
# centrality = 1.926962409215882e-07
#          centrality                   name        group  country organization
# 29276  1.926962e-07  Univ Cheikh Anta Diop  FullOrgName  Senegal          NaN
# --------------------------------------------------
# Bahrain
# centrality = 1.7281326556598597e-07
#          centrality                     name        group  country  \
# 32508  9.791919e-08             Univ Bahrain  FullOrgName  Bahrain
# 33166  7.489408e-08  Islamic Int Rating Agcy  FullOrgName  Bahrain
#
#       organization
# 32508          NaN
# 33166          NaN
# --------------------------------------------------
# Rep of Georgia
# centrality = 1.6121155106861545e-07
#          centrality                        name        group         country  \
# 30205  1.612116e-07  Tbilisi State Univ Tbilisi  FullOrgName  Rep of Georgia
#
#       organization
# 30205          NaN
# --------------------------------------------------
# Burundi
# centrality = 1.414842249376733e-07
#          centrality          name        group  country organization
# 30884  1.414842e-07  Univ Burundi  FullOrgName  Burundi          NaN
# --------------------------------------------------
# Moldova
# centrality = 9.791146664584652e-08
#          centrality                       name        group  country  \
# 32510  9.791147e-08  Acad Econ Studies Moldova  FullOrgName  Moldova
#
#       organization
# 32510          NaN
# --------------------------------------------------
# Albania
# centrality = 8.633670353868072e-08
#          centrality                           name        group  country  \
# 34032  4.325628e-08                    Univ Tirana  FullOrgName  Albania
# 34053  4.308043e-08          Minist Finance & Econ  FullOrgName  Albania
# 37215  2.542538e-18                Agr Univ Tirana  FullOrgName  Albania
# 38871  1.875110e-19  Minist Finance & Econ Albania  FullOrgName  Albania
#
#       organization
# 34032          NaN
# 34053          NaN
# 37215          NaN
# 38871          NaN
# --------------------------------------------------
# Laos
# centrality = 2.21107876844418e-08
#          centrality            name        group country organization
# 34979  2.211079e-08  Natl Univ Laos  FullOrgName    Laos          NaN
# --------------------------------------------------
# DEM REP CONGO
# centrality = 1.1144341727858348e-08
#          centrality                    name        group        country  \
# 35471  1.114434e-08  Univ Nouveaux Horizons  FullOrgName  DEM REP CONGO
#
#       organization
# 35471          NaN
# --------------------------------------------------
# Iraq
# centrality = 9.102113109189967e-10
#          centrality        name        group country organization
# 36113  9.102113e-10  Univ Anbar  FullOrgName    Iraq          NaN
# --------------------------------------------------
# Dominican Rep
# centrality = 6.970965576682598e-10
#          centrality                                      name        group  \
# 36154  6.970966e-10  Inst Especializado Estudios Super Loyola  FullOrgName
#
#              country organization
# 36154  Dominican Rep          NaN
# --------------------------------------------------
# Lesotho
# centrality = 2.3178730979265256e-18
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# New Caledonia
# centrality = 1.3728062043332248e-18
#          centrality                name        group        country  \
# 38080  8.089097e-19                TEPP  FullOrgName  New Caledonia
# 38817  2.128550e-19  Univ New Caledonia  FullOrgName  New Caledonia
#
#       organization
# 38080          NaN
# 38817          NaN
# --------------------------------------------------
# Botswana
# centrality = 8.175906135266929e-19
#          centrality           name        group   country organization
# 37708  1.233235e-18  Univ Botswana  FullOrgName  Botswana          NaN
# --------------------------------------------------
# Georgia
# centrality = 7.427723710546892e-19
#          centrality                name        group  country organization
# 37453  1.650522e-18  Tbilisi State Univ  FullOrgName  Georgia          NaN
# --------------------------------------------------
# Timor-Leste
# centrality = 7.2366041364536055e-19
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# San Marino
# centrality = 6.1403005155647165e-19
#          centrality                  name        group     country  \
# 38902  1.705912e-19  Banca San Marino SpA  FullOrgName  San Marino
#
#       organization
# 38902          NaN
# --------------------------------------------------
# Algeria
# centrality = 3.5116970264687984e-19
#          centrality   name        group  country organization
# 38628  3.549955e-19  CREAD  FullOrgName  Algeria          NaN
# --------------------------------------------------
# BELARUS
# centrality = 3.2057929082590607e-19
#          centrality                   name        group  country organization
# 37412  1.730349e-18        Kino Mo Belarus  FullOrgName  BELARUS          NaN
# 37650  1.305609e-18  Belarusian State Univ  FullOrgName  BELARUS          NaN
# --------------------------------------------------
# Surinam
# centrality = 8.911713694947943e-20
#          centrality                        name        group  country  \
# 37545  1.461329e-18  Anton de Kom Univ Suriname  FullOrgName  Surinam
#
#       organization
# 37545          NaN
# --------------------------------------------------
# Malawi
# centrality = 7.422330821590851e-20
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------
# North Macedonia
# centrality = 1.8489696367392713e-20
#          centrality               name        group          country  \
# 37335  1.925965e-18  Fac Business Econ  FullOrgName  North Macedonia
#
#       organization
# 37335          NaN
# --------------------------------------------------
# South Sudan
# centrality = 1.51337289816008e-20
# Empty DataFrame
# Columns: [centrality, name, group, country, organization]
# Index: []
# --------------------------------------------------

# %% [markdown]
# ## publication classified by country

# %%
raw_df = pd.read_csv(f'../../data/2021-12-16/csv/{year}.csv')[['Fullname', 'PaperTitle', 'journaltitle']]

# %%
sub_df = df.loc[df['group'] == 'Fullname', ['name', 'country']]
author_country_mapping = dict(zip(sub_df['name'], sub_df['country']))

# %%
stat = defaultdict(lambda: defaultdict(lambda: []))
for g in tqdm(raw_df.groupby('PaperTitle')):
    r = g[1].iloc[0]
    country = author_country_mapping[r['Fullname']]
    title = r['PaperTitle']
    journal = r['journaltitle']
    stat[country][journal].append(title)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=16649.0), HTML(value='')))

# %%
country = 'USA'
res_df = pd.DataFrame([stat[country]])
print(f'journal title : number of paper in {country} in year {year}')
print('-'*20)
for k, v in sorted(stat[country].items(), key=lambda x: len(x[1]), reverse=True):
    print(k, len(v), sep=' : ')
# Out:
# journal title : number of paper in USA in year 2019
# --------------------
# APPLIED ECONOMICS LETTERS : 99
# AMERICAN ECONOMIC REVIEW : 94
# JOURNAL OF ECONOMIC BEHAVIOR & ORGANIZATION : 93
# WORLD DEVELOPMENT : 90
# APPLIED ECONOMICS : 89
# ECONOMICS LETTERS : 83
# JOURNAL OF FINANCIAL ECONOMICS : 83
# REVIEW OF FINANCIAL STUDIES : 73
# REVIEW OF ECONOMIC STUDIES : 58
# GAMES AND ECONOMIC BEHAVIOR : 57
# ENERGY ECONOMICS : 57
# ENVIRONMENTAL & RESOURCE ECONOMICS : 55
# JOURNAL OF FINANCE : 54
# PUBLIC CHOICE : 52
# ECONOMIC INQUIRY : 51
# JOURNAL OF CONSUMER AFFAIRS : 51
# JOURNAL OF POLITICAL ECONOMY : 49
# REVIEW OF ECONOMICS AND STATISTICS : 45
# JOURNAL OF PUBLIC ECONOMICS : 43
# JOURNAL OF DEVELOPMENT STUDIES : 43
# JOURNAL OF FINANCIAL AND QUANTITATIVE ANALYSIS : 42
# JOURNAL OF DEVELOPMENT ECONOMICS : 42
# ECONOMICS OF EDUCATION REVIEW : 42
# JOURNAL OF ECONOMIC THEORY : 41
# JOURNAL OF ENVIRONMENTAL ECONOMICS AND MANAGEMENT : 40
# AMERICAN ECONOMIC JOURNAL-ECONOMIC POLICY : 40
# JOURNAL OF ECONOMIC PERSPECTIVES : 37
# SOUTHERN ECONOMIC JOURNAL : 37
# JOURNAL OF BANKING & FINANCE : 36
# JOURNAL OF TRANSPORT GEOGRAPHY : 36
# JOURNAL OF ACCOUNTING & ECONOMICS : 34
# EUROPEAN ECONOMIC REVIEW : 34
# JOURNAL OF FAMILY AND ECONOMIC ISSUES : 34
# JOURNAL OF THE ASSOCIATION OF ENVIRONMENTAL AND RESOURCE ECONOMISTS : 33
# INDEPENDENT REVIEW : 33
# INTERNATIONAL JOURNAL OF FORECASTING : 32
# AMERICAN ECONOMIC JOURNAL-APPLIED ECONOMICS : 31
# QUARTERLY JOURNAL OF ECONOMICS : 31
# JOURNAL OF MONEY CREDIT AND BANKING : 30
# SMALL BUSINESS ECONOMICS : 30
# JOURNAL OF BEHAVIORAL AND EXPERIMENTAL ECONOMICS : 30
# TRANSPORT POLICY : 30
# JOURNAL OF POLICY ANALYSIS AND MANAGEMENT : 29
# EMPIRICAL ECONOMICS : 28
# JOURNAL OF ECONOMIC EDUCATION : 27
# CONTEMPORARY ECONOMIC POLICY : 27
# QUANTITATIVE ECONOMICS : 27
# JOURNAL OF MONETARY ECONOMICS : 27
# REGIONAL SCIENCE AND URBAN ECONOMICS : 26
# JOURNAL OF LABOR ECONOMICS : 26
# JOURNAL OF ECONOMIC ISSUES : 26
# FUTURES : 25
# REVIEW OF INDUSTRIAL ORGANIZATION : 25
# ECONOMIC MODELLING : 24
# LAND ECONOMICS : 24
# WORLD BANK ECONOMIC REVIEW : 24
# MACROECONOMIC DYNAMICS : 24
# WORLD ECONOMY : 23
# REVIEW OF DEVELOPMENT ECONOMICS : 23
# ECONOMIC DEVELOPMENT QUARTERLY : 23
# JOURNAL OF SPORTS ECONOMICS : 23
# JOURNAL OF HUMAN RESOURCES : 23
# JOURNAL OF APPLIED ECONOMETRICS : 22
# AMERICAN ECONOMIC JOURNAL-MACROECONOMICS : 22
# MANAGERIAL AND DECISION ECONOMICS : 22
# REVIEW OF ECONOMIC DYNAMICS : 22
# JOURNAL OF REAL ESTATE FINANCE AND ECONOMICS : 22
# INTERNATIONAL REVIEW OF ECONOMICS & FINANCE : 22
# INTERNATIONAL REVIEW OF LAW AND ECONOMICS : 22
# JOURNAL OF INTERNATIONAL ECONOMICS : 22
# AMERICAN JOURNAL OF ECONOMICS AND SOCIOLOGY : 21
# AMERICAN ECONOMIC JOURNAL-MICROECONOMICS : 21
# CANADIAN JOURNAL OF ECONOMICS-REVUE CANADIENNE D ECONOMIQUE : 20
# JOURNAL OF REGIONAL SCIENCE : 20
# ECONOMIC JOURNAL : 20
# REAL ESTATE ECONOMICS : 20
# EDUCATION FINANCE AND POLICY : 19
# REVIEW OF RADICAL POLITICAL ECONOMICS : 19
# CAMBRIDGE JOURNAL OF ECONOMICS : 19
# INDUSTRIAL AND CORPORATE CHANGE : 19
# JOURNAL OF MACROECONOMICS : 19
# JOURNAL OF ECONOMICS & MANAGEMENT STRATEGY : 19
# JOURNAL OF LAW & ECONOMICS : 19
# REVIEW OF INTERNATIONAL ECONOMICS : 18
# JOURNAL OF ECONOMIC DYNAMICS & CONTROL : 18
# SOCIO-ECONOMIC REVIEW : 18
# NATIONAL TAX JOURNAL : 17
# B E JOURNAL OF ECONOMIC ANALYSIS & POLICY : 17
# PAPERS IN REGIONAL SCIENCE : 17
# HISTORY OF POLITICAL ECONOMY : 17
# REVIEW OF ENVIRONMENTAL ECONOMICS AND POLICY : 17
# AMERICAN JOURNAL OF HEALTH ECONOMICS : 17
# ECONOMIC THEORY : 17
# NORTH AMERICAN JOURNAL OF ECONOMICS AND FINANCE : 17
# RESOURCE AND ENERGY ECONOMICS : 17
# ANNALS OF REGIONAL SCIENCE : 16
# JOURNAL OF URBAN ECONOMICS : 16
# THEORETICAL ECONOMICS : 16
# JOURNAL OF ECONOMIC PSYCHOLOGY : 16
# LABOUR ECONOMICS : 16
# RAND JOURNAL OF ECONOMICS : 16
# JOURNAL OF REAL ESTATE RESEARCH : 15
# INTERNATIONAL JOURNAL OF INDUSTRIAL ORGANIZATION : 15
# JOURNAL OF AGRARIAN CHANGE : 15
# JOURNAL OF HUMAN CAPITAL : 15
# JOURNAL OF THE EUROPEAN ECONOMIC ASSOCIATION : 15
# JOURNAL OF COMPARATIVE ECONOMICS : 15
# CHINA ECONOMIC REVIEW : 15
# JOURNAL OF RISK AND INSURANCE : 14
# POST-SOVIET AFFAIRS : 14
# JOURNAL OF BEHAVIORAL FINANCE : 14
# ECONOMIC ANALYSIS AND POLICY : 14
# REVIEW OF ECONOMICS OF THE HOUSEHOLD : 14
# EUROPEAN JOURNAL OF POLITICAL ECONOMY : 14
# INTERNATIONAL REVIEW OF ECONOMICS EDUCATION : 14
# JOURNAL OF PENSION ECONOMICS & FINANCE : 14
# ECONOMIC DEVELOPMENT AND CULTURAL CHANGE : 13
# FEDERAL RESERVE BANK OF ST LOUIS REVIEW : 13
# JOURNAL OF EMPIRICAL FINANCE : 13
# EMERGING MARKETS FINANCE AND TRADE : 12
# INTERNATIONAL ECONOMIC REVIEW : 12
# EXPERIMENTAL ECONOMICS : 12
# REVIEW OF INTERNATIONAL POLITICAL ECONOMY : 12
# JOURNAL OF HOUSING ECONOMICS : 12
# JOURNAL OF ECONOMIC LITERATURE : 12
# JOURNAL OF INSTITUTIONAL ECONOMICS : 12
# WORLD TRADE REVIEW : 11
# REGIONAL STUDIES : 11
# DEFENCE AND PEACE ECONOMICS : 11
# JOURNAL OF RISK AND UNCERTAINTY : 11
# TOURISM ECONOMICS : 11
# INTERNATIONAL JOURNAL OF HEALTH ECONOMICS AND MANAGEMENT : 11
# BROOKINGS PAPERS ON ECONOMIC ACTIVITY : 10
# QME-QUANTITATIVE MARKETING AND ECONOMICS : 10
# JOURNAL OF THE ECONOMICS OF AGEING : 10
# INTERNATIONAL FINANCE : 10
# JOURNAL OF POPULATION ECONOMICS : 10
# REVIEW OF FINANCE : 10
# JOURNAL OF LAW ECONOMICS & ORGANIZATION : 10
# EUROPE-ASIA STUDIES : 9
# ACTA OECONOMICA : 9
# ECONOMICS OF TRANSITION : 9
# OPEN ECONOMIES REVIEW : 9
# JOURNAL OF PUBLIC ECONOMIC THEORY : 9
# JOURNAL OF ECONOMIC GEOGRAPHY : 9
# CLIMATE CHANGE ECONOMICS : 9
# OXFORD REVIEW OF ECONOMIC POLICY : 9
# EXPLORATIONS IN ECONOMIC HISTORY : 9
# JAPANESE ECONOMIC REVIEW : 9
# REVIEW OF KEYNESIAN ECONOMICS : 9
# IMF ECONOMIC REVIEW : 9
# JOURNAL OF ECONOMIC HISTORY : 8
# JOURNAL OF APPLIED ECONOMICS : 8
# RESEARCH IN TRANSPORTATION ECONOMICS : 8
# INFORMATION ECONOMICS AND POLICY : 8
# ANNALS OF ECONOMICS AND FINANCE : 8
# ECONOMICS AND PHILOSOPHY : 8
# REVIEW OF INCOME AND WEALTH : 8
# NEW POLITICAL ECONOMY : 8
# JOURNAL OF ECONOMIC SURVEYS : 8
# ECONOMICS & POLITICS : 8
# STRUCTURAL CHANGE AND ECONOMIC DYNAMICS : 8
# JOURNAL OF REGULATORY ECONOMICS : 8
# REVIEW OF INTERNATIONAL ORGANIZATIONS : 8
# SINGAPORE ECONOMIC REVIEW : 7
# AMERICAN LAW AND ECONOMICS REVIEW : 7
# JOURNAL OF COMMODITY MARKETS : 7
# ECONOMICS OF GOVERNANCE : 7
# ECONOMIC HISTORY REVIEW : 7
# FEMINIST ECONOMICS : 7
# JOURNAL OF FORECASTING : 7
# JOURNAL OF AFRICAN ECONOMIES : 7
# GLOBAL ECONOMIC REVIEW : 7
# JOURNAL OF THE JAPANESE AND INTERNATIONAL ECONOMIES : 7
# ECONOMICA : 7
# EUROPEAN JOURNAL OF THE HISTORY OF ECONOMIC THOUGHT : 6
# JOURNAL OF PRODUCTIVITY ANALYSIS : 6
# INTERNATIONAL JOURNAL OF ECONOMIC THEORY : 6
# NBER MACROECONOMICS ANNUAL : 6
# OXFORD ECONOMIC PAPERS-NEW SERIES : 6
# JOURNAL OF THE ASIA PACIFIC ECONOMY : 6
# B E JOURNAL OF MACROECONOMICS : 6
# INDUSTRY AND INNOVATION : 6
# SCANDINAVIAN JOURNAL OF ECONOMICS : 6
# SOCIAL CHOICE AND WELFARE : 6
# LATIN AMERICAN ECONOMIC REVIEW : 6
# JOURNAL OF POST KEYNESIAN ECONOMICS : 6
# INTERNATIONAL TAX AND PUBLIC FINANCE : 6
# KYKLOS : 6
# JOURNAL OF WORLD TRADE : 5
# ECONOMICS OF ENERGY & ENVIRONMENTAL POLICY : 5
# CAMBRIDGE JOURNAL OF REGIONS ECONOMY AND SOCIETY : 5
# ENVIRONMENT AND DEVELOPMENT ECONOMICS : 5
# JOURNAL OF INTERNATIONAL TRADE & ECONOMIC DEVELOPMENT : 5
# JOURNAL OF POLICY MODELING : 5
# ASIA-PACIFIC JOURNAL OF ACCOUNTING & ECONOMICS : 5
# JOURNAL OF INTERNATIONAL FINANCIAL MARKETS INSTITUTIONS & MONEY : 5
# METROECONOMICA : 5
# EUROPEAN REVIEW OF ECONOMIC HISTORY : 5
# BULLETIN OF ECONOMIC RESEARCH : 5
# WORLD BANK RESEARCH OBSERVER : 5
# EUROPEAN JOURNAL OF LAW AND ECONOMICS : 5
# EASTERN EUROPEAN ECONOMICS : 5
# B E JOURNAL OF THEORETICAL ECONOMICS : 5
# SPATIAL ECONOMIC ANALYSIS : 5
# JOURNAL OF EVOLUTIONARY ECONOMICS : 5
# JOURNAL OF FINANCIAL STABILITY : 5
# ECONOMICS-THE OPEN ACCESS OPEN-ASSESSMENT E-JOURNAL : 4
# EUROPEAN JOURNAL OF HEALTH ECONOMICS : 4
# INTERNATIONAL ENVIRONMENTAL AGREEMENTS-POLITICS LAW AND ECONOMICS : 4
# STUDIES IN NONLINEAR DYNAMICS AND ECONOMETRICS : 4
# JOURNAL OF ECONOMICS : 4
# REVIEW OF WORLD ECONOMICS : 4
# EMERGING MARKETS REVIEW : 4
# ECONOMIC POLICY : 4
# CHINA & WORLD ECONOMY : 4
# INTERNATIONAL JOURNAL OF EMERGING MARKETS : 4
# JCMS-JOURNAL OF COMMON MARKET STUDIES : 4
# JOURNAL OF CULTURAL ECONOMY : 4
# ECONOMY AND SOCIETY : 4
# GERMAN ECONOMIC REVIEW : 4
# JOURNAL OF ECONOMIC GROWTH : 4
# JOURNAL OF CONTEMPORARY ACCOUNTING & ECONOMICS : 4
# CLIOMETRICA : 4
# HEALTH ECONOMICS REVIEW : 4
# WORK EMPLOYMENT AND SOCIETY : 4
# JOURNAL OF ECONOMIC INEQUALITY : 4
# ECONOMIC RESEARCH-EKONOMSKA ISTRAZIVANJA : 4
# GENEVA RISK AND INSURANCE REVIEW : 4
# JOURNAL OF INSTITUTIONAL AND THEORETICAL ECONOMICS-ZEITSCHRIFT FUR DIE GESAMTE STAATSWISSENSCHAFT : 4
# JOURNAL OF INDUSTRIAL ECONOMICS : 4
# AUSTRALIAN ECONOMIC PAPERS : 3
# MANCHESTER SCHOOL : 3
# JOURNAL OF THE KNOWLEDGE ECONOMY : 3
# ASIAN-PACIFIC ECONOMIC LITERATURE : 3
# ECONOMICS OF TRANSPORTATION : 3
# JOURNAL OF CULTURAL ECONOMICS : 3
# ECONOMIC SYSTEMS RESEARCH : 3
# TIJDSCHRIFT VOOR ECONOMISCHE EN SOCIALE GEOGRAFIE : 3
# POST-COMMUNIST ECONOMIES : 3
# KOREAN ECONOMIC REVIEW : 3
# CANADIAN PUBLIC POLICY-ANALYSE DE POLITIQUES : 3
# SCOTTISH JOURNAL OF POLITICAL ECONOMY : 3
# TRIMESTRE ECONOMICO : 3
# ECONOMIC AND LABOUR RELATIONS REVIEW : 3
# JOURNAL OF DEMOGRAPHIC ECONOMICS : 3
# THEORY AND DECISION : 3
# JOURNAL OF ASIAN ECONOMICS : 3
# ECONOMICS OF INNOVATION AND NEW TECHNOLOGY : 3
# ANNALS OF PUBLIC AND COOPERATIVE ECONOMICS : 2
# REVISTA DE HISTORIA ECONOMICA : 2
# JOURNAL OF ECONOMIC POLICY REFORM : 2
# JOURNAL OF CHOICE MODELLING : 2
# BORSA ISTANBUL REVIEW : 2
# TRANSFORMATIONS IN BUSINESS & ECONOMICS : 2
# JOURNAL OF COMPETITIVENESS : 2
# ARGUMENTA OECONOMICA : 2
# ECONOMIST-NETHERLANDS : 2
# JOURNAL OF KOREA TRADE : 2
# JAPAN AND THE WORLD ECONOMY : 2
# BULLETIN OF INDONESIAN ECONOMIC STUDIES : 2
# POLITICKA EKONOMIE : 2
# JOURNAL OF ECONOMIC INTERACTION AND COORDINATION : 2
# AUSTRALIAN ECONOMIC HISTORY REVIEW : 2
# EURASIAN BUSINESS REVIEW : 2
# ECONOMIC CHANGE AND RESTRUCTURING : 2
# INTERNATIONAL LABOUR REVIEW : 2
# ASIAN ECONOMIC POLICY REVIEW : 2
# JAHRBUCHER FUR NATIONALOKONOMIE UND STATISTIK : 2
# REVIEW OF NETWORK ECONOMICS : 2
# JOURNAL OF TRANSPORT ECONOMICS AND POLICY : 2
# CEPAL REVIEW : 2
# ECONOMIC GEOGRAPHY : 2
# ASIAN ECONOMIC JOURNAL : 1
# HACIENDA PUBLICA ESPANOLA-REVIEW OF PUBLIC ECONOMICS : 1
# REVIEW OF DERIVATIVES RESEARCH : 1
# PORTUGUESE ECONOMIC JOURNAL : 1
# JOURNAL OF MEDIA ECONOMICS : 1
# EKONOMICKY CASOPIS : 1
# ESTUDIOS DE ECONOMIA : 1
# INVESTIGACION ECONOMICA : 1
# JOURNAL OF COMPETITION LAW & ECONOMICS : 1
# JOURNAL OF NEUROSCIENCE PSYCHOLOGY AND ECONOMICS : 1
# FISCAL STUDIES : 1
# CESIFO ECONOMIC STUDIES : 1
# JOURNAL OF FINANCIAL ECONOMETRICS : 1
# ECONOMIA POLITICA : 1
# ROMANIAN JOURNAL OF ECONOMIC FORECASTING : 1
# HITOTSUBASHI JOURNAL OF ECONOMICS : 1
# DEVELOPING ECONOMIES : 1
# ASIAN ECONOMIC PAPERS : 1
# SERIES-JOURNAL OF THE SPANISH ECONOMIC ASSOCIATION : 1
# PACIFIC ECONOMIC REVIEW : 1
# JOURNAL OF ECONOMIC METHODOLOGY : 1

# %%
data = [[k, len(v)] for k, v in stat[country].items()]
res_df = pd.DataFrame(data, columns=['journal title', 'count'])
res_df['centrality_rank'] = res_df['journal title'].apply(lambda x: journal_rk.loc[journal_rk['name'] == x, ['centrality']].index[0]+1)
res_df['impact-factor_rank'] = res_df['journal title'].apply(lambda x: journal_rk.loc[journal_rk['name'] == x, ['impact_factor_optimal_rank']].values[0][0])
res_df['h-index_rank'] = res_df['journal title'].apply(lambda x: journal_rk.loc[journal_rk['name'] == x, ['h_index_optimal_rank']].values[0][0])
res_df.sort_values(by=['count'], ascending=False)
# Out:
#                                         journal title  count  centrality_rank  \
# 43                          APPLIED ECONOMICS LETTERS     99                7
# 2                            AMERICAN ECONOMIC REVIEW     94                5
# 62        JOURNAL OF ECONOMIC BEHAVIOR & ORGANIZATION     93                3
# 45                                  WORLD DEVELOPMENT     90                1
# 49                                  APPLIED ECONOMICS     89                2
# ..                                                ...    ...              ...
# 247                              ESTUDIOS DE ECONOMIA      1              286
# 267                           CESIFO ECONOMIC STUDIES      1              312
# 264                                    FISCAL STUDIES      1              255
# 262  JOURNAL OF NEUROSCIENCE PSYCHOLOGY AND ECONOMICS      1              221
# 293                   JOURNAL OF ECONOMIC METHODOLOGY      1              304
#
#      impact-factor_rank  h-index_rank
# 43                470.0         210.0
# 2                   8.0           1.0
# 62                117.0          44.0
# 45                112.0          34.0
# 49                 18.0          49.0
# ..                  ...           ...
# 247               819.0         726.0
# 267               188.0         285.0
# 264               205.0         255.0
# 262                 NaN           NaN
# 293               589.0         484.0
#
# [294 rows x 5 columns]
